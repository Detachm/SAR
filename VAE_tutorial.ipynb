# %% [markdown]
# <a href="https://colab.research.google.com/github/Detachm/SAR/blob/main/VAE_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports and utilities

# %%
# imports for SAR
# !pip install stable-baselines3==1.7.0
# !pip install joblib
# !pip install scikit-learn
# !pip install tqdm
# !pip install matplotlib
# !pip install gymnasium
# !pip install git+https://github.com/facebookresearch/myosuite.git
# !pip install stable-baselines3
# !pip install numpy
# !apt install fonts-lmodern
# Out:
# Collecting stable-baselines3==1.7.0
#   Using cached stable_baselines3-1.7.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting gym==0.21 (from stable-baselines3==1.7.0)
#   Using cached gym-0.21.0.tar.gz (1.5 MB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (1.4.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.13.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# Collecting git+https://github.com/facebookresearch/myosuite.git
#   Cloning https://github.com/facebookresearch/myosuite.git to /tmp/pip-req-build-bsj8giz4
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/myosuite.git /tmp/pip-req-build-bsj8giz4
#   Resolved https://github.com/facebookresearch/myosuite.git to commit 7927eb0153b428812c1db143e0e41144ab57254b
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from MyoSuite==2.8.3) (8.1.8)
# Requirement already satisfied: sk-video in /usr/local/lib/python3.11/dist-packages (from MyoSuite==2.8.3) (1.1.10)
# Requirement already satisfied: gymnasium==0.29.1 in /usr/local/lib/python3.11/dist-packages (from MyoSuite==2.8.3) (0.29.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from MyoSuite==2.8.3) (3.0.1)
# Requirement already satisfied: flatten_dict in /usr/local/lib/python3.11/dist-packages (from MyoSuite==2.8.3) (0.4.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from MyoSuite==2.8.3) (3.13.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from MyoSuite==2.8.3) (2.0.2)
# Requirement already satisfied: mujoco==3.1.2 in /usr/local/lib/python3.11/dist-packages (from MyoSuite==2.8.3) (3.1.2)
# Requirement already satisfied: dm-control==1.0.16 in /usr/local/lib/python3.11/dist-packages (from MyoSuite==2.8.3) (1.0.16)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from MyoSuite==2.8.3) (11.1.0)
# Requirement already satisfied: pink-noise-rl in /usr/local/lib/python3.11/dist-packages (from MyoSuite==2.8.3) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from MyoSuite==2.8.3) (24.2)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.11/dist-packages (from MyoSuite==2.8.3) (3.1.44)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from dm-control==1.0.16->MyoSuite==2.8.3) (1.4.0)
# Requirement already satisfied: dm-env in /usr/local/lib/python3.11/dist-packages (from dm-control==1.0.16->MyoSuite==2.8.3) (1.6)
# Requirement already satisfied: dm-tree!=0.1.2 in /usr/local/lib/python3.11/dist-packages (from dm-control==1.0.16->MyoSuite==2.8.3) (0.1.9)
# Requirement already satisfied: glfw in /usr/local/lib/python3.11/dist-packages (from dm-control==1.0.16->MyoSuite==2.8.3) (2.8.0)
# Requirement already satisfied: labmaze in /usr/local/lib/python3.11/dist-packages (from dm-control==1.0.16->MyoSuite==2.8.3) (1.0.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from dm-control==1.0.16->MyoSuite==2.8.3) (5.3.1)
# Requirement already satisfied: protobuf>=3.19.4 in /usr/local/lib/python3.11/dist-packages (from dm-control==1.0.16->MyoSuite==2.8.3) (5.29.4)
# Requirement already satisfied: pyopengl>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from dm-control==1.0.16->MyoSuite==2.8.3) (3.1.9)
# Requirement already satisfied: pyparsing>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dm-control==1.0.16->MyoSuite==2.8.3) (3.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from dm-control==1.0.16->MyoSuite==2.8.3) (2.32.3)
# Requirement already satisfied: setuptools!=50.0.0 in /usr/local/lib/python3.11/dist-packages (from dm-control==1.0.16->MyoSuite==2.8.3) (75.2.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from dm-control==1.0.16->MyoSuite==2.8.3) (1.14.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from dm-control==1.0.16->MyoSuite==2.8.3) (4.67.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->MyoSuite==2.8.3) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->MyoSuite==2.8.3) (4.13.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->MyoSuite==2.8.3) (0.0.4)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.11/dist-packages (from mujoco==3.1.2->MyoSuite==2.8.3) (1.12.2)
# Requirement already satisfied: six<2.0,>=1.12 in /usr/local/lib/python3.11/dist-packages (from flatten_dict->MyoSuite==2.8.3) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython->MyoSuite==2.8.3) (4.0.12)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree!=0.1.2->dm-control==1.0.16->MyoSuite==2.8.3) (25.3.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from dm-tree!=0.1.2->dm-control==1.0.16->MyoSuite==2.8.3) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython->MyoSuite==2.8.3) (5.0.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco==3.1.2->MyoSuite==2.8.3) (2025.3.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco==3.1.2->MyoSuite==2.8.3) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco==3.1.2->MyoSuite==2.8.3) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->dm-control==1.0.16->MyoSuite==2.8.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->dm-control==1.0.16->MyoSuite==2.8.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->dm-control==1.0.16->MyoSuite==2.8.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->dm-control==1.0.16->MyoSuite==2.8.3) (2025.1.31)
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.11/dist-packages (2.6.0)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (0.29.1)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.0.2)
# Collecting torch<3.0,>=2.3 (from stable-baselines3)
#   Downloading torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3) (4.13.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Downloading torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl (766.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 2.0 MB/s eta 0:00:00
# Installing collected packages: torch
# Successfully installed torch-2.6.0
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-lmodern is already the newest version (2.004.5-6.1).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cd /content/drive/MyDrive/SAR/myosuite-main/docs/source/tutorials/SAR
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from stable_baselines3 import SAC
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.logger import configure
from stable_baselines3.common.env_util import make_vec_env
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
os.chdir('/content/drive/MyDrive/SAR/myosuite-main/docs/source/tutorials/SAR')
os.environ['MUJOCO_GL'] = 'glfw'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from SAR_tutorial_utils import *
# Out:
# MyoSuite:> Registering Myo Envs

# %% [markdown]
# # VAE core functions

# %% [markdown]
# <div style="display: flex; align-items: flex-start;">
#     <div style="flex: 1;">
#          Next, implement for SAR step by step. The framework follows the basic structure displayed below. Accordingly, we will implement functions that do each of the following:
#         <br>
#         <br>
#         <ol>
#             <li>玩耍阶段训练</li>
#             <li>捕捉玩耍阶段肌肉激活数据</li>
#             <li>使用肌肉激活数据计算SAR</li>
#             <li>使用计算后的SAR训练目标数据</li>
#         </ol>
#         <br>
#         As we implement each of the above, we will also go into more detail about best practices for that step.
#         <br>
#     </div>
# </div>

# %% [markdown]
# ### Step 1: Train a play phase policy

# %%
def train(env_name, policy_name, timesteps, seed):
    # 定义一个训练函数，使用 Stable-Baselines3 的 SAC 算法训练策略。
    # 参数说明：
    # - env_name: 环境名称（字符串）。
    # - policy_name: 策略的唯一标识符（字符串）。
    # - timesteps: 训练的总时间步数（整数）。
    # - seed: 用于区分多个相同参数训练的策略（字符串）。

    env = gym.make(env_name)
    # 创建一个 Gym 环境实例。

    env = Monitor(env)
    # 使用 Monitor 包装环境以记录训练过程中的统计信息。

    env = DummyVecEnv([lambda: env])
    # 使用 DummyVecEnv 将环境包装为向量化环境，以便与 Stable-Baselines3 兼容。

    env = VecNormalize(env, norm_obs=True, norm_reward=False, clip_obs=10.)
    # 使用 VecNormalize 对环境进行归一化处理：
    # - norm_obs=True: 归一化观察值。
    # - norm_reward=False: 不归一化奖励。
    # - clip_obs=10.: 将观察值裁剪到 [-10, 10] 范围。

    net_shape = [400, 300]
    # 定义神经网络的架构，包含两层，分别有 400 和 300 个神经元。

    policy_kwargs = dict(net_arch=dict(pi=net_shape, qf=net_shape))
    # 定义策略网络的参数：
    # - pi: 策略网络的架构。
    # - qf: Q 函数网络的架构。

    model = SAC('MlpPolicy', env, learning_rate=linear_schedule(.001), buffer_size=int(3e5),
            learning_starts=1000, batch_size=256, tau=.02, gamma=.98, train_freq=(1, "episode"),
            gradient_steps=-1,policy_kwargs=policy_kwargs, verbose=1)
    # 创建一个 SAC 模型实例：
    # - 'MlpPolicy': 使用多层感知机策略。
    # - env: 使用的环境。
    # - learning_rate: 学习率，使用线性调度函数。
    # - buffer_size: 经验回放缓冲区大小。
    # - learning_starts: 开始训练前的时间步数。
    # - batch_size: 批量大小。
    # - tau: 目标网络软更新系数。
    # - gamma: 折扣因子。
    # - train_freq: 训练频率（每个 episode 训练一次）。
    # - gradient_steps: 每次更新的梯度步数（-1 表示每次更新与 train_freq 相同）。
    # - policy_kwargs: 策略网络的参数。
    # - verbose: 日志输出级别。

    succ_callback = SaveSuccesses(check_freq=1, env_name=env_name+'_'+seed,
                             log_dir=f'{policy_name}_successes_{env_name}_{seed}')
    # 创建一个回调函数 SaveSuccesses，用于保存训练成功的统计信息：
    # - check_freq: 检查频率（每 1 个时间步检查一次）。
    # - env_name: 保存成功统计信息的环境名称。
    # - log_dir: 保存日志的目录。

    model.set_logger(configure(f'{policy_name}_results_{env_name}_{seed}'))
    # 配置模型的日志记录器，日志将保存到指定目录。

    model.learn(total_timesteps=int(timesteps), callback=succ_callback, log_interval=4)
    # 开始训练模型：
    # - total_timesteps: 总训练时间步数。
    # - callback: 使用 SaveSuccesses 回调函数。
    # - log_interval: 日志记录间隔。

    model.save(f"{policy_name}_model_{env_name}_{seed}")
    # 保存训练好的模型到文件。

    env.save(f'{policy_name}_env_{env_name}_{seed}')
    # 保存归一化环境的状态到文件。

# %% [markdown]
# ### Step 2: Roll out play phase policy to capture muscle activations over time

# %%
def get_activations(name, env_name, seed, episodes=2000, percentile=80):
    """
    Returns muscle activation data from N runs of a trained policy.

    name: str; policy name (see train())
    env_name: str; name of the gym environment
    seed: str; seed of the trained policy
    episodes: int; optional; how many rollouts?
    percentile: int; optional; percentile to set the reward threshold for considering an episode as successful
    """
    # 定义一个函数，用于从训练好的策略中获取肌肉激活数据。
    # 参数说明：
    # - name: 策略名称（字符串）。
    # - env_name: 环境名称（字符串）。
    # - seed: 训练策略时使用的种子（字符串）。
    # - episodes: 可选参数，表示要运行的回合数（整数，默认为 2000）。
    # - percentile: 可选参数，用于设置奖励阈值的百分位数（整数，默认为 80）。

    with gym.make(env_name) as env:
        env.reset()
        # 创建一个 Gym 环境实例，并在上下文管理器中使用，确保资源释放。
        # 调用 `reset()` 方法初始化环境。

        model = SAC.load(f'{name}_model_{env_name}_{seed}')
        # 加载训练好的 SAC 模型，文件名由策略名称、环境名称和种子组成。

        vec = VecNormalize.load(f'{name}_env_{env_name}_{seed}', DummyVecEnv([lambda: env]))
        # 加载归一化环境的状态，并将其包装为 DummyVecEnv 以与模型兼容。

        # Calculate the reward threshold from 100 preview episodes
        preview_rewards = []
        # 初始化一个列表，用于存储预览回合的奖励。

        for _ in range(100):
            env.reset()
            # 重置环境。

            rewards = 0
            # 初始化奖励计数器。

            done = False
            # 初始化回合结束标志。

            while not done:
                o = env.get_obs()
                # 获取当前观察值。

                o = vec.normalize_obs(o)
                # 对观察值进行归一化处理。

                a, __ = model.predict(o, deterministic=False)
                # 使用模型预测动作，`deterministic=False` 表示使用随机策略。

                next_o, r, done, *_, info = env.step(a)
                # 执行动作，获取下一步的观察值、奖励、回合结束标志和其他信息。

                rewards += r
                # 累加奖励。

            preview_rewards.append(rewards)
            # 将当前回合的总奖励添加到预览奖励列表中。

        reward_threshold = np.percentile(preview_rewards, percentile)
        # 根据预览奖励列表计算奖励阈值，使用指定的百分位数。

        # Run the main episode loop
        solved_acts = []
        # 初始化一个列表，用于存储成功回合的激活数据。

        for _ in tqdm(range(episodes)):
            env.reset()
            # 重置环境。

            rewards, acts = 0, []
            # 初始化奖励计数器和动作列表。

            done = False
            # 初始化回合结束标志。

            while not done:
                o = env.get_obs()
                # 获取当前观察值。

                o = vec.normalize_obs(o)
                # 对观察值进行归一化处理。

                a, __ = model.predict(o, deterministic=False)
                # 使用模型预测动作，`deterministic=False` 表示使用随机策略。

                next_o, r, done, *_, info = env.step(a)
                # 执行动作，获取下一步的观察值、奖励、回合结束标志和其他信息。

                acts.append(env.sim.data.act.copy())
                # 将当前的肌肉激活数据复制并添加到动作列表中。

                rewards += r
                # 累加奖励。

            if rewards > reward_threshold:
                solved_acts.extend(acts)
                # 如果当前回合的总奖励超过奖励阈值，将动作列表添加到成功回合的激活数据中。

    return np.array(solved_acts)
    # 将成功回合的激活数据转换为 NumPy 数组并返回。

# %% [markdown]
# ### Step 3: Compute SAR from the activation dataset

# %% [markdown]
# We use linear representations (i.e., PCA, ICA, normalization) to approximate SAR. These representations are based directly on the motor neuroscience literature of representing muscle synergies (c.f., [Tresch et al, 2006](https://journals.physiology.org/doi/epdf/10.1152/jn.00222.2005)). Such representations also have the advantages of being highly interpretable and efficient for use as control signals. We also found in practice that nonlinear representations (such as VAE decoder networks) did not lead to strong performance are were far less efficient for training.
#
# Before computing SAR, we first seek to understand how informative each individual muscle synergy is for explaining the initial muscle activation dataset. `find_synergies` returns a dictionary (and optionally, a plot) that shows variance accounted for (VAF) by N synergies from the original muscle activation data. In general, we find that using a number of synergies where VAF > 80% leads to good performance, though this value should be treated as a hyperparameter.

# %%
# 定义 Variational Autoencoder (VAE) 模型类
class VAE(nn.Module):
    def __init__(self, input_dim=80, latent_dim=10):
        super(VAE, self).__init__()

        # 1. 设备设置
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        # 2. 网络结构
        self.fc1 = nn.Linear(input_dim, 256)
        self.fc3 = nn.Linear(256, 128)
        self.fc4 = nn.Linear(128, 64)
        self.fc5 = nn.Linear(64, 32)
        self.fc4_mean = nn.Linear(32, latent_dim)
        self.fc4_logvar = nn.Linear(32, latent_dim)

        self.fc_decode1 = nn.Linear(latent_dim, 32)
        self.fc_decode2 = nn.Linear(32, 64)
        self.fc_decode3 = nn.Linear(64, 128)
        self.fc_decode4 = nn.Linear(128, 256)
        self.fc_decode6 = nn.Linear(256, input_dim)

        # 3. 将模型放入正确的设备
        self.to(self.device)

    def encode(self, x):
        # 编码器前向传播：生成潜在空间的均值和对数方差
        h = F.relu(self.fc1(x))
        #h = F.relu(self.fc2(h))
        h = F.relu(self.fc3(h))
        h = F.relu(self.fc4(h))
        h = F.relu(self.fc5(h))
        mu = self.fc4_mean(h)       # 潜在均值
        logvar = self.fc4_logvar(h) # 潜在对数方差
        return mu, logvar

    def reparameterize(self, mu, logvar):
        # 重新参数化：从 N(μ, σ^2) 中采样隐变量 z
        std = torch.exp(0.5 * logvar)     # 计算标准差 σ
        eps = torch.randn_like(std)       # 随机噪声 ε ~ N(0, I)
        z = mu + eps * std                # 隐变量 z = μ + σ * ε
        return z

    def decode(self, z):
        # 解码器前向传播：从隐变量重构回原始维度
        h = F.relu(self.fc_decode1(z))
        h = F.relu(self.fc_decode2(h))
        h = F.relu(self.fc_decode3(h))
        h = F.relu(self.fc_decode4(h))
        #h = F.relu(self.fc_decode5(h))
        x_recon = self.fc_decode6(h)      # 输出层（线性层，输出重构结果）
        # 注意：由于输入数据已归一化到 [-1, 1]，这里不使用额外激活函数约束输出
        return x_recon

    def forward(self, x):
        # 完整前向过程：编码 -> 采样 -> 解码
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        x_recon = self.decode(z)
        return x_recon, mu, logvar

# %%
# 定义函数：训练VAE并计算不同潜在维度下的方差解释率 VAF
def find_synergies_vae(acts, latent_dims_list, epochs=100, lr=0.001, batch_size=32, plot=True, device='cpu'):
    # 2. 将输入数据转换为 numpy 数组并进行 MinMax(-1,1) 归一化
    acts = np.array(acts, dtype=np.float32)              # 转换为 numpy 数组
    scaler = MinMaxScaler(feature_range=(-1, 1))
    X_norm = scaler.fit_transform(acts)                  # 对每列特征缩放到 [-1, 1]
    # 转换为 PyTorch 张量并移动到指定设备
    X_tensor = torch.from_numpy(X_norm).float()
    if device == 'cuda' and not torch.cuda.is_available():
        print("警告: CUDA 不可用，自动切换到 CPU。")
        device = 'cpu'
    X_tensor = X_tensor.to(device)

    # 使用 DataLoader 将数据按批划分
    dataset = TensorDataset(X_tensor)
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

    vaf_results = {}  # 字典：存储每个潜在维度对应的 VAF

    # 遍历每个潜在维度，分别训练 VAE 并计算重构的方差解释率
    for latent_dim in latent_dims_list:
        print(f"训练 VAE，潜在维度 = {latent_dim} ...")
        # 3. 初始化VAE模型和优化器
        model = VAE(input_dim=X_tensor.shape[1], latent_dim=latent_dim).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=lr)

        # 训练循环
        for epoch in range(epochs):
            model.train()
            total_loss = 0.0
            for batch_data, in data_loader:
                batch_data = batch_data.to(device)
                # 前向传播计算重构结果、潜在均值和log方差
                recon_batch, mu, logvar = model(batch_data)
                # 1. 计算重构损失 (MSE)
                recon_loss = F.mse_loss(recon_batch, batch_data, reduction='sum') / batch_data.size(0)
                # 计算 KL 散度损失（基于解析表达式）
                kl_loss = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp()) / batch_data.size(0)
                # 4. KL warm-up：前50轮线性增加 KL 损失权重
                kl_weight = (epoch + 1) * 3 / 2000.0 if epoch < 200 else 0.3
                #kl_weight = 0
                # 总损失 = 重构损失 + KL损失 * 权重
                loss = recon_loss + kl_weight * kl_loss
                # 反向传播和参数更新
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss += loss.item() * batch_data.size(0)
            # 打印每轮训练的平均损失（每隔10轮或最后一轮输出一次）
            avg_loss = total_loss / len(dataset)
            if (epoch + 1) % 10 == 0 or epoch == 0 or (epoch + 1) == epochs:
                print(f"  Epoch {epoch+1}/{epochs} - 平均损失: {avg_loss:.4f} "
                      f"(重构: {recon_loss.item():.4f}, KL: {kl_loss.item():.4f}, 权重: {kl_weight:.2f})")

        # 训练结束，利用训练好的模型重构整个数据集以计算 VAF
        model.eval()
        with torch.no_grad():
            # 用编码器获取每个样本的潜在均值作为隐变量（避免随机采样导致不稳定）
            mu, logvar = model.encode(X_tensor)
            z = mu  # 使用均值 mu 代表潜在变量
            X_recon_full = model.decode(z)
        # 将原始数据和重构数据转回 CPU 的 numpy（均为归一化后的数据）
        X_orig = X_tensor.detach().cpu().numpy()
        X_recon = X_recon_full.detach().cpu().numpy()
        # 计算重构误差平方和 (SSE) 和原始数据总平方和 (SST)
        SSE = np.sum((X_orig - X_recon) ** 2)                         # 重构误差的平方和
        SST = np.sum((X_orig - np.mean(X_orig, axis=0)) ** 2)         # 原始数据绕均值的平方和
        # 计算方差解释率 VAF = 1 - SSE/SST
        vaf = 1 - SSE / SST
        vaf_results[latent_dim] = vaf
        print(f"潜在维度 {latent_dim} 的 VAF = {vaf:.4f}")

        # 释放 GPU 显存（如使用GPU，加速垃圾回收）
        del model
        if device == 'cuda':
            torch.cuda.empty_cache()

    # 如果需要绘制 VAF 随潜在维度变化曲线
    if plot:
        dims = list(vaf_results.keys())
        vafs = [vaf_results[d] for d in dims]
        plt.figure(figsize=(6,4))
        plt.plot(dims, vafs, marker='o')
        plt.xlabel("Number of potential dimensions")
        plt.ylabel("VAF")
        plt.grid(True)
        plt.show()

    # 返回字典：latent_dim -> VAF
    return vaf_results

# %%
def compute_VAE_SAR(acts, latent_dim, epochs=100, lr=0.001, batch_size=32, device='cuda'):
    import numpy as np
    import torch
    from torch.utils.data import TensorDataset, DataLoader
    from sklearn.preprocessing import MinMaxScaler
    import torch.nn.functional as F

    acts = np.array(acts, dtype=np.float32)

    # 对原始 muscle 数据做归一化（用于 VAE 输入）
    scaler_input = MinMaxScaler(feature_range=(-1, 1))
    X_norm = scaler_input.fit_transform(acts)
    X_tensor = torch.from_numpy(X_norm).float().to(device)

    if device == 'cuda' and not torch.cuda.is_available():
        print("CUDA 不可用，切换到 CPU。")
        device = 'cpu'

    dataset = TensorDataset(X_tensor)
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

    # 创建 VAE 模型
    model = VAE(input_dim=X_tensor.shape[1], latent_dim=latent_dim).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    mu_list = []

    # 开始训练 VAE
    for epoch in range(epochs):
        model.train()
        total_loss = 0.0

        for batch_data, in data_loader:
            batch_data = batch_data.to(device)
            recon_batch, mu, logvar = model(batch_data)

            recon_loss = F.mse_loss(recon_batch, batch_data, reduction='sum') / batch_data.size(0)
            kl_loss = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp()) / batch_data.size(0)
            #kl_weight = (epoch + 1) / 1000.0 if epoch < 100 else 0.1
            #loss = recon_loss + kl_weight * kl_loss
            kl_weight = 0
            loss = recon_loss

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item() * batch_data.size(0)

        # 最后一轮收集所有 mu 用于训练 latent space 的 normalizer
        if epoch == epochs - 1:
            model.eval()
            with torch.no_grad():
                full_mu = model.encode(X_tensor)[0].cpu().numpy()
                mu_list = full_mu

        avg_loss = total_loss / len(dataset)
        if (epoch + 1) % 10 == 0 or epoch == 0 or (epoch + 1) == epochs:
            print(f"Epoch {epoch+1}/{epochs} | 平均损失: {avg_loss:.4f} | 重构: {recon_loss.item():.4f} | KL: {kl_loss.item():.4f} | 权重: {kl_weight:.2f}")

    # 用 latent 向量训练 scaler_latent，用于 RL 的动作归一化
    scaler_latent = MinMaxScaler(feature_range=(-1, 1))
    scaler_latent.fit(mu_list)

    return model, scaler_latent  # 返回 VAE 模型和 latent space 的 scaler

# %% [markdown]
# ### Step 4: Use computed SAR to train on target task

# %% [markdown]
# In order to train with SAR, we initialize a `SynNoSynWrapper`, which implements the policy architecture presented below.
#
# The policy takes as input $o_t$ and outputs an $O+N$-dimensional action vector, $a_{t}^{O+N}$, where $O$ is the dimensionality of the original action manifold and $N$ is the dimensionality of the synergistic manifold. The first $N$ synergistic actions are passed through $SAR(a_{t}^{N})=a_{t}^{SAR}$ to recover the synergistic muscle activations. The subsequent $O$ task-specific activations are mixed with the task-general activations using a linear blend $\varphi$ to recover the final action $a_t^*$ that steps the environment forward. Note that for the locomotion experiments presented next, it was actually found that purely relying on the synergistic, task-general pathway ($\varphi=1$) was sufficient for learning robust locomotion (see end-to-end example later in the notebook).

# %% [markdown]
# <div style="width:100%;">
#     <img src="./SAR_images/pol_arch.png" alt="Policy Architecture" style="width:850px; display:block; margin-left:auto; margin-right:auto;"/>
# </div>

# %%
class VAESynNoSynWrapper(gym.ActionWrapper):
    def __init__(self, env, vae, normalizer, phi):
        super().__init__(env)

        self.vae = vae.eval()
        self.normalizer = normalizer
        self.weight = phi

        self.device = next(self.vae.parameters()).device

        with torch.no_grad():
            dummy_input = torch.zeros(1, env.action_space.shape[0]).to(self.device)
            z_mean, _ = self.vae.encode(dummy_input)
            self.syn_act_space = z_mean.shape[1]

        self.no_syn_act_space = env.action_space.shape[0]
        self.full_act_space = self.syn_act_space + self.no_syn_act_space

        self.action_space = gym.spaces.Box(
            low=-1., high=1., shape=(self.full_act_space,), dtype=np.float32
        )

    def action(self, act):
        syn_action = act[:self.syn_act_space]
        no_syn_action = act[self.syn_act_space:]

        #latent = self.normalizer.inverse_transform([syn_action])
        latent_tensor = torch.tensor([syn_action], dtype=torch.float32).to(self.device)

        with torch.no_grad():
            decoded_action = self.vae.decode(latent_tensor).cpu().numpy()[0]

        final_action = self.weight * decoded_action + (1 - self.weight) * no_syn_action
        return final_action

# %% [markdown]
# Additionally, we initialize a `SynergyWrapper`, which implements a variation of the above policy architecture that only leverages task-general synergistic activations (i.e., a more efficient implementation for handling the case where $\varphi=1$).

# %%
class VAESynergyWrapper(gym.ActionWrapper):
    def __init__(self, env, encode_fn, decode_fn, normalizer):
        super().__init__(env)

        self.encode_fn = encode_fn
        self.decode_fn = decode_fn
        self.normalizer = normalizer

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        with torch.no_grad():
            dummy_input = torch.zeros(1, env.action_space.shape[0]).to(self.device)
            z_mean, _ = self.encode_fn(dummy_input)
            self.latent_dim = z_mean.shape[1]

        self.action_space = gym.spaces.Box(
            low=-1., high=1., shape=(self.latent_dim,), dtype=np.float32
        )

    def action(self, act):
        latent_np = self.normalizer.inverse_transform([act])
        latent_tensor = torch.tensor(latent_np, dtype=torch.float32).to(self.device)

        with torch.no_grad():
            decoded = self.decode_fn(latent_tensor).cpu().numpy()[0]

        return decoded

# %% [markdown]
# We proceed to train a policy with this architecture using `SAR_RL`. We find that a blend weight $\varphi$=0.66 between the synergistic (task-general) and nonsynergistic (task-specific) activations works best in practice, though this should also be considered a hyperparameter that may require optimization for specific use cases.

# %%
def VAE_RL(env_name, policy_name, timesteps, seed, vae, normalizer, phi=.66, syn_nosyn=False):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # 将 VAE 和 normalizer 都移到 device 上
    vae.to(device)

    if syn_nosyn:
        env = VAESynNoSynWrapper(gym.make(env_name), vae, normalizer, phi)
    else:
        env = VAESynergyWrapper(gym.make(env_name),
                                encode_fn=vae.encode,
                                decode_fn=vae.decode,
                                normalizer=normalizer)

    env = Monitor(env)
    env = DummyVecEnv([lambda: env])
    env = VecNormalize(env, norm_obs=True, norm_reward=False, clip_obs=10.)

    net_shape = [400, 300]
    policy_kwargs = dict(net_arch=dict(pi=net_shape, qf=net_shape))

    '''model = SAC('MlpPolicy', env, learning_rate=3e-4, buffer_size=int(3e5),
                learning_starts=5000, batch_size=256, tau=.02, gamma=.98,
                train_freq=(1, "episode"), gradient_steps=-1,
                policy_kwargs=policy_kwargs, verbose=1)'''

    model = SAC('MlpPolicy', env, learning_rate=linear_schedule(.001), buffer_size=int(3e5),
            learning_starts=5000, batch_size=256, tau=.02, gamma=.98, train_freq=(1, "episode"),
            gradient_steps=-1,policy_kwargs=policy_kwargs, verbose=1)


    model.set_logger(configure(f'{policy_name}_results_{env_name}_{seed}'))
    model.learn(total_timesteps=int(timesteps), log_interval=4)
    model.save(f"{policy_name}_model_{env_name}_{seed}")
    env.save(f'{policy_name}_env_{env_name}_{seed}')

# %% [markdown]
# # SAR 部分

# %%
def find_synergies(acts, plot=True):
    """
    Computed % variance explained in the original muscle activation data with N synergies.

    acts: np.array; rollout data containing the muscle activations
    plot: bool; whether to plot the result
    """
    # 定义一个函数，用于计算原始肌肉激活数据中由 N 个协同作用解释的方差百分比。
    # 参数说明：
    # - acts: 包含肌肉激活数据的 NumPy 数组。
    # - plot: 是否绘制结果图表（布尔值，默认为 True）。

    syn_dict = {}
    # 初始化一个空字典，用于存储每个协同作用数量对应的方差解释比例。

    for i in range(acts.shape[1]):
        # 遍历肌肉激活数据的每个维度（即每个协同作用的数量）。

        pca = PCA(n_components=i+1)
        # 创建一个 PCA（主成分分析）实例，设置主成分数量为 i+1。

        _ = pca.fit_transform(acts)
        # 对输入的肌肉激活数据进行 PCA 转换（降维）。

        syn_dict[i+1] =  round(sum(pca.explained_variance_ratio_), 4)
        # 计算当前协同作用数量解释的总方差比例，并保留 4 位小数。
        # 将结果存储到字典中，键为协同作用数量，值为方差解释比例。

    if plot:
        # 如果 `plot` 参数为 True，则绘制结果图表。

        plt.plot(list(syn_dict.keys()), list(syn_dict.values()))
        # 绘制协同作用数量与方差解释比例的关系曲线。

        plt.title('VAF by N synergies')
        # 设置图表标题。

        plt.xlabel('# synergies')
        # 设置 x 轴标签为协同作用数量。

        plt.ylabel('VAF')
        # 设置 y 轴标签为方差解释比例（VAF）。

        plt.grid()
        # 添加网格线以便于观察。

        plt.show()
        # 显示图表。

    return syn_dict
    # 返回包含协同作用数量与方差解释比例的字典。

# %%
def SAR_RL(env_name, policy_name, timesteps, seed, ica, pca, normalizer, phi=.66, syn_nosyn=True):
    """
    Trains a policy using sb3 implementation of SAC + SynNoSynWrapper.

    env_name: str; name of gym env.
    policy_name: str; choose unique identifier of this policy
    timesteps: int; how long you want to train your policy for
    seed: str (not int); relevant if you want to train multiple policies with the same params
    ica: the ICA object
    pca: the PCA object
    normalizer: the normalizer object
    phi: float; blend parameter between synergistic and nonsynergistic activations
    """
    # 定义一个函数，用于使用 Stable-Baselines3 的 SAC 算法和 SynNoSynWrapper 包装器训练策略。
    # 参数说明：
    # - env_name: 环境名称（字符串）。
    # - policy_name: 策略的唯一标识符（字符串）。
    # - timesteps: 训练的总时间步数（整数）。
    # - seed: 用于区分多个相同参数训练的策略（字符串）。
    # - ica: ICA 模型对象。
    # - pca: PCA 模型对象。
    # - normalizer: 归一化器对象。
    # - phi: 协同作用和非协同作用动作的混合权重参数（浮点数，默认为 0.66）。
    # - syn_nosyn: 是否使用 SynNoSynWrapper 包装器（布尔值，默认为 True）。

    if syn_nosyn:
        env = SynNoSynWrapper(gym.make(env_name), ica, pca, normalizer, phi)
        # 如果 `syn_nosyn` 为 True，则使用 SynNoSynWrapper 包装环境。
    else:
        env = SynergyWrapper(gym.make(env_name), ica, pca, normalizer)
        # 如果 `syn_nosyn` 为 False，则使用 SynergyWrapper 包装环境。

    env = Monitor(env)
    # 使用 Monitor 包装环境以记录训练过程中的统计信息。

    env = DummyVecEnv([lambda: env])
    # 使用 DummyVecEnv 将环境包装为向量化环境，以便与 Stable-Baselines3 兼容。

    env = VecNormalize(env, norm_obs=True, norm_reward=False, clip_obs=10.)
    # 使用 VecNormalize 对环境进行归一化处理：
    # - norm_obs=True: 归一化观察值。
    # - norm_reward=False: 不归一化奖励。
    # - clip_obs=10.: 将观察值裁剪到 [-10, 10] 范围。

    net_shape = [400, 300]
    # 定义神经网络的架构，包含两层，分别有 400 和 300 个神经元。

    policy_kwargs = dict(net_arch=dict(pi=net_shape, qf=net_shape))
    # 定义策略网络的参数：
    # - pi: 策略网络的架构。
    # - qf: Q 函数网络的架构。

    model = SAC('MlpPolicy', env, learning_rate=linear_schedule(.001), buffer_size=int(3e5),
            learning_starts=5000, batch_size=256, tau=.02, gamma=.98, train_freq=(1, "episode"),
            gradient_steps=-1,policy_kwargs=policy_kwargs, verbose=1)
    # 创建一个 SAC 模型实例：
    # - 'MlpPolicy': 使用多层感知机策略。
    # - env: 使用的环境。
    # - learning_rate: 学习率，使用线性调度函数。
    # - buffer_size: 经验回放缓冲区大小。
    # - learning_starts: 开始训练前的时间步数。
    # - batch_size: 批量大小。
    # - tau: 目标网络软更新系数。
    # - gamma: 折扣因子。
    # - train_freq: 训练频率（每个 episode 训练一次）。
    # - gradient_steps: 每次更新的梯度步数（-1 表示每次更新与 train_freq 相同）。
    # - policy_kwargs: 策略网络的参数。
    # - verbose: 日志输出级别。

    succ_callback = SaveSuccesses(check_freq=1, env_name=env_name+'_'+seed,
                             log_dir=f'{policy_name}_successes_{env_name}_{seed}')
    # 创建一个回调函数 SaveSuccesses，用于保存训练成功的统计信息：
    # - check_freq: 检查频率（每 1 个时间步检查一次）。
    # - env_name: 保存成功统计信息的环境名称。
    # - log_dir: 保存日志的目录。

    model.set_logger(configure(f'{policy_name}_results_{env_name}_{seed}'))
    # 配置模型的日志记录器，日志将保存到指定目录。

    model.learn(total_timesteps=int(timesteps), callback=succ_callback, log_interval=4)
    # 开始训练模型：
    # - total_timesteps: 总训练时间步数。
    # - callback: 使用 SaveSuccesses 回调函数。
    # - log_interval: 日志记录间隔。

    model.save(f"{policy_name}_model_{env_name}_{seed}")
    # 保存训练好的模型到文件。

    env.save(f'{policy_name}_env_{env_name}_{seed}')
    # 保存归一化环境的状态到文件。

# %%
class SynNoSynWrapper(gym.ActionWrapper):
    """
    gym.ActionWrapper that reformulates the action space as the combination of a task-general synergy space and a
    task-specific original space, and uses this mix to step the environment in the original action space.
    """
    # 定义一个自定义的 Gym 动作包装器类 `SynNoSynWrapper`。
    # 该包装器将动作空间重新定义为任务通用的协同作用空间和任务特定的原始空间的组合，
    # 并使用这种混合动作来在原始动作空间中执行环境的步进操作。

    def __init__(self, env, ica, pca, scaler, phi):
        super().__init__(env)
        # 初始化父类 `gym.ActionWrapper`，并传入环境实例 `env`。

        self.ica = ica
        # 保存独立成分分析 (ICA) 模型。

        self.pca = pca
        # 保存主成分分析 (PCA) 模型。

        self.scaler = scaler
        # 保存归一化器 (Scaler) 对象。

        self.weight = phi
        # 保存协同作用和非协同作用动作的混合权重参数 `phi`。

        self.syn_act_space = self.pca.components_.shape[0]
        # 协同作用动作空间的维度，等于 PCA 模型的主成分数量。

        self.no_syn_act_space = env.action_space.shape[0]
        # 非协同作用动作空间的维度，等于环境原始动作空间的维度。

        self.full_act_space = self.syn_act_space + self.no_syn_act_space
        # 总动作空间的维度，为协同作用动作空间和非协同作用动作空间的维度之和。

        self.action_space = gym.spaces.Box(low=-1., high=1., shape=(self.full_act_space,), dtype=np.float32)
        # 定义新的动作空间为一个连续的 Box 空间，其范围为 [-1, 1]，维度为总动作空间的维度。

    def action(self, act):
        # 重写 `action` 方法，用于将输入的动作转换为原始动作空间中的动作。

        syn_action = act[:self.syn_act_space]
        # 从输入动作中提取协同作用部分（前 `syn_act_space` 个维度）。

        no_syn_action = act[self.syn_act_space:]
        # 从输入动作中提取非协同作用部分（后 `no_syn_act_space` 个维度）。

        syn_action = self.pca.inverse_transform(
            self.ica.inverse_transform(
                self.scaler.inverse_transform([syn_action])
            )
        )[0]
        # 对协同作用动作依次进行逆归一化、ICA 逆变换和 PCA 逆变换，
        # 将其还原为原始动作空间中的动作。

        final_action = self.weight * syn_action + (1 - self.weight) * no_syn_action
        # 根据权重参数 `phi`，将协同作用动作和非协同作用动作混合，生成最终的动作。

        return final_action
        # 返回最终的动作，用于在环境中执行。

# %%
def compute_SAR(acts, n_syn, save=False):
    """
    Takes activation data and desired n_comp as input and returns/optionally saves the ICA, PCA, and Scaler objects

    acts: np.array; rollout data containing the muscle activations
    n_comp: int; number of synergies to use
    save: bool; whether to save the resulting models to disk
    """
    # 定义一个函数，用于计算肌肉激活数据的协同作用，并返回或保存 ICA、PCA 和归一化对象。
    # 参数说明：
    # - acts: 包含肌肉激活数据的 NumPy 数组。
    # - n_syn: 使用的协同作用数量（整数）。
    # - save: 是否保存结果模型到磁盘（布尔值，默认为 False）。

    pca = PCA(n_components=n_syn)
    # 创建一个 PCA（主成分分析）实例，设置主成分数量为 n_syn。

    pca_act = pca.fit_transform(acts)
    # 对输入的肌肉激活数据进行 PCA 转换（降维），并返回降维后的数据。

    ica = FastICA()
    # 创建一个 FastICA（快速独立成分分析）实例。

    pcaica_act = ica.fit_transform(pca_act)
    # 对 PCA 降维后的数据进行 ICA 转换，提取独立成分。

    normalizer = MinMaxScaler((-1, 1))
    # 创建一个 MinMaxScaler 实例，用于将数据归一化到 [-1, 1] 范围。

    normalizer.fit(pcaica_act)
    # 使用 ICA 转换后的数据拟合归一化器。

    if save:
        # 如果 `save` 参数为 True，则将模型保存到磁盘。

        joblib.dump(ica, 'ica_demo.pkl')
        # 将 ICA 模型保存到文件 `ica_demo.pkl`。

        joblib.dump(pca, 'pca_demo.pkl')
        # 将 PCA 模型保存到文件 `pca_demo.pkl`。

        joblib.dump(normalizer, 'scaler_demo.pkl')
        # 将归一化器保存到文件 `scaler_demo.pkl`。

    return ica, pca, normalizer
    # 返回 ICA、PCA 和归一化器对象。

# %% [markdown]
# 对比 VAE 和 SAR（PCA+ICA）降维后的 latent 分布结构（t-SNE 可视化）

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def plot_tsne_vae_vs_sar(
    muscle_data,
    vae_model,
    pca,
    ica,
    vae_normalizer,
    sar_normalizer,
    n_samples=3000
):
    """
    对比 VAE 和 SAR（PCA+ICA）降维后的 latent 分布结构（t-SNE 可视化），支持各自独立 normalizer。
    """
    # 降采样
    muscle_data = np.array(muscle_data).astype(np.float32)
    if muscle_data.shape[0] > n_samples:
        indices = np.random.choice(muscle_data.shape[0], n_samples, replace=False)
        muscle_data_sampled = muscle_data[indices]
    else:
        muscle_data_sampled = muscle_data

    # ========== VAE latent ==========
    norm_data_vae = vae_normalizer.transform(muscle_data_sampled)
    X_tensor = torch.tensor(norm_data_vae, dtype=torch.float32).to(next(vae_model.parameters()).device)

    vae_model.eval()
    with torch.no_grad():
        mu, _ = vae_model.encode(X_tensor)
        vae_latent = mu.cpu().numpy()

    tsne_vae = TSNE(n_components=2, perplexity=30, random_state=42)
    vae_tsne = tsne_vae.fit_transform(vae_latent)

    # ========== SAR latent ==========
    sar_latent = ica.transform(pca.transform(muscle_data_sampled))         # (3000, 25)
    norm_data_sar = sar_normalizer.transform(sar_latent)                  # 对 25维 latent 做归一化

    tsne_sar = TSNE(n_components=2, perplexity=30, random_state=42)
    sar_tsne = tsne_sar.fit_transform(norm_data_sar)


    # ========== Plot ==========
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))

    axes[0].scatter(vae_tsne[:, 0], vae_tsne[:, 1], s=3, alpha=0.7)
    axes[0].set_title("VAE Latent Space (t-SNE)")
    axes[0].set_xlabel("Dim 1")
    axes[0].set_ylabel("Dim 2")
    axes[0].grid(True)

    axes[1].scatter(sar_tsne[:, 0], sar_tsne[:, 1], s=3, alpha=0.7)
    axes[1].set_title("SAR (PCA+ICA) Latent Space (t-SNE)")
    axes[1].set_xlabel("Dim 1")
    axes[1].set_ylabel("Dim 2")
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# 自动遍历 latent 空间中所有二维组合（dim_i vs dim_j），可视化 decoder 的响应热图

# %%
import itertools
import numpy as np
import torch
import matplotlib.pyplot as plt

def visualize_all_latent_combinations(
    vae_model,
    latent_dim=25,
    muscle_index=0,
    grid_size=30,
    grid_range=2.0,
    mode='muscle',  # 'muscle', 'norm', 'mean'
    max_plots=None  # 限制最多画几张（避免太多图）
):
    """
    遍历所有 latent dim 两两组合，对 decoder 响应进行可视化。
    """
    vae_model.eval()
    device = next(vae_model.parameters()).device

    combinations = list(itertools.combinations(range(latent_dim), 2))
    if max_plots:
        combinations = combinations[:max_plots]

    for (dim_x, dim_y) in combinations:
        x = np.linspace(-grid_range, grid_range, grid_size)
        y = np.linspace(-grid_range, grid_range, grid_size)
        zz = np.zeros((grid_size, grid_size))

        for i, xi in enumerate(x):
            for j, yj in enumerate(y):
                z = np.zeros((1, latent_dim), dtype=np.float32)
                z[0, dim_x] = xi
                z[0, dim_y] = yj
                z_tensor = torch.tensor(z).to(device)
                with torch.no_grad():
                    output = vae_model.decode(z_tensor).cpu().numpy()[0]

                if mode == 'muscle':
                    zz[j, i] = output[muscle_index]
                elif mode == 'norm':
                    zz[j, i] = np.linalg.norm(output)
                elif mode == 'mean':
                    zz[j, i] = np.mean(output)

        plt.figure(figsize=(5, 4))
        plt.imshow(zz, origin='lower', extent=[-grid_range, grid_range, -grid_range, grid_range], aspect='auto')
        plt.colorbar(label=f'Decoded {mode}')
        plt.title(f'Decoder Response: dim {dim_x} vs {dim_y}')
        plt.xlabel(f'Latent dim {dim_x}')
        plt.ylabel(f'Latent dim {dim_y}')
        plt.grid(True)
        plt.tight_layout()
        plt.show()

# %% [markdown]
# # Full training example 1: SAR x physiological locomotion

# %% [markdown]
# Now that we have defined the core functions for implementing SAR, we will now train a locomotion policy using MyoLegs. In this example:
# - a policy is trained on straight flat walking task for 1.5M steps (`myoLegWalk-v0`)
# - after training, we collect muscle activation data from policy rollouts
# - Variance accounted for (VAF) by N synergies is computed. Here, we use 20 synergies from the 80-dimensional leg muscle activations
# - SAR is used to train on:
#     - a hilly terrain walking task (`myoLegHillyTerrainWalk-v0`)
#     - an uneven terrain walking task (`myoLegRoughTerrainWalk-v0`)
#     - a stair climbing task (`myoLegStairTerrainWalk-v0`)
#
# <strong>Note: we also provide the option of using pretrained policies/representations at some of the above steps. Run the code below depending on your preferences.</strong>

# %% [markdown]
# # Step 1.1
#
# First, we acquire our synergistic action representation. We provide two options for this:
#
# <strong>Option A: Get SAR from scratch (i.e., train on `myoLegWalk-v0` as play period → get muscle activations → compute SAR).</strong>
#
# <strong>Option B: Use the precomputed SAR.</strong>

# %% [markdown]
# ## Option 1.1.A: Get SAR from scratch

# %%
train('myoLegWalk-v0', 'play_period', 1.5e6, '0')
# Out:
#     MyoSuite: A contact-rich simulation suite for musculoskeletal motor control
#         Vittorio Caggiano, Huawei Wang, Guillaume Durandau, Massimo Sartori, Vikash Kumar
#         L4DC-2019 | https://sites.google.com/view/myosuite
# /usr/local/lib/python3.11/dist-packages/glfw/__init__.py:917: GLFWError: (65550) b'X11: The DISPLAY environment variable is missing'
#   warnings.warn(message, GLFWError)
# Streaming output truncated to the last 5000 lines.
# |    n_updates       | 888759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 248      |
# |    ep_rew_mean     | 2.17e+03 |
# | time/              |          |
# |    episodes        | 5932     |
# |    fps             | 64       |
# |    time_elapsed    | 13741    |
# |    total_timesteps | 891156   |
# | train/             |          |
# |    actor_loss      | -501     |
# |    critic_loss     | 69.7     |
# |    ent_coef        | 0.0466   |
# |    ent_coef_loss   | 0.0107   |
# |    learning_rate   | 0.000406 |
# |    n_updates       | 889844   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 252      |
# |    ep_rew_mean     | 2.21e+03 |
# | time/              |          |
# |    episodes        | 5936     |
# |    fps             | 64       |
# |    time_elapsed    | 13759    |
# |    total_timesteps | 892284   |
# | train/             |          |
# |    actor_loss      | -500     |
# |    critic_loss     | 71.4     |
# |    ent_coef        | 0.0457   |
# |    ent_coef_loss   | 0.906    |
# |    learning_rate   | 0.000405 |
# |    n_updates       | 891062   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 253      |
# |    ep_rew_mean     | 2.22e+03 |
# | time/              |          |
# |    episodes        | 5940     |
# |    fps             | 64       |
# |    time_elapsed    | 13776    |
# |    total_timesteps | 893498   |
# | train/             |          |
# |    actor_loss      | -499     |
# |    critic_loss     | 73.2     |
# |    ent_coef        | 0.0468   |
# |    ent_coef_loss   | 0.602    |
# |    learning_rate   | 0.000405 |
# |    n_updates       | 892167   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 255      |
# |    ep_rew_mean     | 2.24e+03 |
# | time/              |          |
# |    episodes        | 5944     |
# |    fps             | 64       |
# |    time_elapsed    | 13792    |
# |    total_timesteps | 894417   |
# | train/             |          |
# |    actor_loss      | -500     |
# |    critic_loss     | 74.7     |
# |    ent_coef        | 0.0467   |
# |    ent_coef_loss   | 0.276    |
# |    learning_rate   | 0.000404 |
# |    n_updates       | 893175   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 254      |
# |    ep_rew_mean     | 2.23e+03 |
# | time/              |          |
# |    episodes        | 5948     |
# |    fps             | 64       |
# |    time_elapsed    | 13806    |
# |    total_timesteps | 895259   |
# | train/             |          |
# |    actor_loss      | -503     |
# |    critic_loss     | 73.8     |
# |    ent_coef        | 0.0474   |
# |    ent_coef_loss   | 1.34     |
# |    learning_rate   | 0.000403 |
# |    n_updates       | 894107   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 252      |
# |    ep_rew_mean     | 2.2e+03  |
# | time/              |          |
# |    episodes        | 5952     |
# |    fps             | 64       |
# |    time_elapsed    | 13816    |
# |    total_timesteps | 895987   |
# | train/             |          |
# |    actor_loss      | -504     |
# |    critic_loss     | 74.6     |
# |    ent_coef        | 0.048    |
# |    ent_coef_loss   | -1.68    |
# |    learning_rate   | 0.000403 |
# |    n_updates       | 894790   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 252      |
# |    ep_rew_mean     | 2.21e+03 |
# | time/              |          |
# |    episodes        | 5956     |
# |    fps             | 64       |
# |    time_elapsed    | 13832    |
# |    total_timesteps | 896966   |
# | train/             |          |
# |    actor_loss      | -506     |
# |    critic_loss     | 78.1     |
# |    ent_coef        | 0.0482   |
# |    ent_coef_loss   | 0.999    |
# |    learning_rate   | 0.000402 |
# |    n_updates       | 895789   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 251      |
# |    ep_rew_mean     | 2.2e+03  |
# | time/              |          |
# |    episodes        | 5960     |
# |    fps             | 64       |
# |    time_elapsed    | 13850    |
# |    total_timesteps | 898118   |
# | train/             |          |
# |    actor_loss      | -509     |
# |    critic_loss     | 80.3     |
# |    ent_coef        | 0.049    |
# |    ent_coef_loss   | 1.33     |
# |    learning_rate   | 0.000401 |
# |    n_updates       | 896969   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 249      |
# |    ep_rew_mean     | 2.2e+03  |
# | time/              |          |
# |    episodes        | 5964     |
# |    fps             | 64       |
# |    time_elapsed    | 13862    |
# |    total_timesteps | 898896   |
# | train/             |          |
# |    actor_loss      | -512     |
# |    critic_loss     | 80.3     |
# |    ent_coef        | 0.0484   |
# |    ent_coef_loss   | -0.451   |
# |    learning_rate   | 0.000401 |
# |    n_updates       | 897754   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 246      |
# |    ep_rew_mean     | 2.16e+03 |
# | time/              |          |
# |    episodes        | 5968     |
# |    fps             | 64       |
# |    time_elapsed    | 13875    |
# |    total_timesteps | 899699   |
# | train/             |          |
# |    actor_loss      | -514     |
# |    critic_loss     | 83.2     |
# |    ent_coef        | 0.0493   |
# |    ent_coef_loss   | 0.647    |
# |    learning_rate   | 0.0004   |
# |    n_updates       | 898592   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 244      |
# |    ep_rew_mean     | 2.15e+03 |
# | time/              |          |
# |    episodes        | 5972     |
# |    fps             | 64       |
# |    time_elapsed    | 13887    |
# |    total_timesteps | 900582   |
# | train/             |          |
# |    actor_loss      | -515     |
# |    critic_loss     | 86.5     |
# |    ent_coef        | 0.05     |
# |    ent_coef_loss   | -1       |
# |    learning_rate   | 0.0004   |
# |    n_updates       | 899362   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 238      |
# |    ep_rew_mean     | 2.12e+03 |
# | time/              |          |
# |    episodes        | 5976     |
# |    fps             | 64       |
# |    time_elapsed    | 13898    |
# |    total_timesteps | 901196   |
# | train/             |          |
# |    actor_loss      | -521     |
# |    critic_loss     | 86.3     |
# |    ent_coef        | 0.0505   |
# |    ent_coef_loss   | 1.42     |
# |    learning_rate   | 0.000399 |
# |    n_updates       | 900066   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 232      |
# |    ep_rew_mean     | 2.06e+03 |
# | time/              |          |
# |    episodes        | 5980     |
# |    fps             | 64       |
# |    time_elapsed    | 13906    |
# |    total_timesteps | 901766   |
# | train/             |          |
# |    actor_loss      | -520     |
# |    critic_loss     | 88.5     |
# |    ent_coef        | 0.0506   |
# |    ent_coef_loss   | 1.56     |
# |    learning_rate   | 0.000399 |
# |    n_updates       | 900651   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | 2.01e+03 |
# | time/              |          |
# |    episodes        | 5984     |
# |    fps             | 64       |
# |    time_elapsed    | 13921    |
# |    total_timesteps | 902731   |
# | train/             |          |
# |    actor_loss      | -521     |
# |    critic_loss     | 92.6     |
# |    ent_coef        | 0.0509   |
# |    ent_coef_loss   | -0.528   |
# |    learning_rate   | 0.000398 |
# |    n_updates       | 901556   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 227      |
# |    ep_rew_mean     | 1.96e+03 |
# | time/              |          |
# |    episodes        | 5988     |
# |    fps             | 64       |
# |    time_elapsed    | 13937    |
# |    total_timesteps | 903783   |
# | train/             |          |
# |    actor_loss      | -523     |
# |    critic_loss     | 87.8     |
# |    ent_coef        | 0.0518   |
# |    ent_coef_loss   | -1.27    |
# |    learning_rate   | 0.000398 |
# |    n_updates       | 902602   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 225      |
# |    ep_rew_mean     | 1.92e+03 |
# | time/              |          |
# |    episodes        | 5992     |
# |    fps             | 64       |
# |    time_elapsed    | 13950    |
# |    total_timesteps | 904678   |
# | train/             |          |
# |    actor_loss      | -517     |
# |    critic_loss     | 87.8     |
# |    ent_coef        | 0.05     |
# |    ent_coef_loss   | 0.789    |
# |    learning_rate   | 0.000397 |
# |    n_updates       | 903431   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 225      |
# |    ep_rew_mean     | 1.91e+03 |
# | time/              |          |
# |    episodes        | 5996     |
# |    fps             | 64       |
# |    time_elapsed    | 13963    |
# |    total_timesteps | 905586   |
# | train/             |          |
# |    actor_loss      | -515     |
# |    critic_loss     | 87       |
# |    ent_coef        | 0.0504   |
# |    ent_coef_loss   | -0.329   |
# |    learning_rate   | 0.000397 |
# |    n_updates       | 904247   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 227      |
# |    ep_rew_mean     | 1.94e+03 |
# | time/              |          |
# |    episodes        | 6000     |
# |    fps             | 64       |
# |    time_elapsed    | 13978    |
# |    total_timesteps | 906469   |
# | train/             |          |
# |    actor_loss      | -518     |
# |    critic_loss     | 87.2     |
# |    ent_coef        | 0.0498   |
# |    ent_coef_loss   | -0.184   |
# |    learning_rate   | 0.000396 |
# |    n_updates       | 905273   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | 1.99e+03 |
# | time/              |          |
# |    episodes        | 6004     |
# |    fps             | 64       |
# |    time_elapsed    | 13999    |
# |    total_timesteps | 907895   |
# | train/             |          |
# |    actor_loss      | -515     |
# |    critic_loss     | 85       |
# |    ent_coef        | 0.0498   |
# |    ent_coef_loss   | -0.012   |
# |    learning_rate   | 0.000395 |
# |    n_updates       | 906640   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 239      |
# |    ep_rew_mean     | 2.07e+03 |
# | time/              |          |
# |    episodes        | 6008     |
# |    fps             | 64       |
# |    time_elapsed    | 14020    |
# |    total_timesteps | 909229   |
# | train/             |          |
# |    actor_loss      | -515     |
# |    critic_loss     | 84.9     |
# |    ent_coef        | 0.0487   |
# |    ent_coef_loss   | -0.137   |
# |    learning_rate   | 0.000394 |
# |    n_updates       | 908023   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 241      |
# |    ep_rew_mean     | 2.11e+03 |
# | time/              |          |
# |    episodes        | 6012     |
# |    fps             | 64       |
# |    time_elapsed    | 14036    |
# |    total_timesteps | 910207   |
# | train/             |          |
# |    actor_loss      | -515     |
# |    critic_loss     | 83.5     |
# |    ent_coef        | 0.0491   |
# |    ent_coef_loss   | -0.501   |
# |    learning_rate   | 0.000393 |
# |    n_updates       | 909043   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 244      |
# |    ep_rew_mean     | 2.16e+03 |
# | time/              |          |
# |    episodes        | 6016     |
# |    fps             | 64       |
# |    time_elapsed    | 14052    |
# |    total_timesteps | 911284   |
# | train/             |          |
# |    actor_loss      | -511     |
# |    critic_loss     | 81.5     |
# |    ent_coef        | 0.0489   |
# |    ent_coef_loss   | 0.0465   |
# |    learning_rate   | 0.000393 |
# |    n_updates       | 910085   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 246      |
# |    ep_rew_mean     | 2.18e+03 |
# | time/              |          |
# |    episodes        | 6020     |
# |    fps             | 64       |
# |    time_elapsed    | 14065    |
# |    total_timesteps | 912226   |
# | train/             |          |
# |    actor_loss      | -506     |
# |    critic_loss     | 77.3     |
# |    ent_coef        | 0.048    |
# |    ent_coef_loss   | 0.966    |
# |    learning_rate   | 0.000392 |
# |    n_updates       | 910953   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 242      |
# |    ep_rew_mean     | 2.15e+03 |
# | time/              |          |
# |    episodes        | 6024     |
# |    fps             | 64       |
# |    time_elapsed    | 14081    |
# |    total_timesteps | 913229   |
# | train/             |          |
# |    actor_loss      | -503     |
# |    critic_loss     | 78.3     |
# |    ent_coef        | 0.0477   |
# |    ent_coef_loss   | -0.29    |
# |    learning_rate   | 0.000391 |
# |    n_updates       | 911976   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 243      |
# |    ep_rew_mean     | 2.14e+03 |
# | time/              |          |
# |    episodes        | 6028     |
# |    fps             | 64       |
# |    time_elapsed    | 14100    |
# |    total_timesteps | 914476   |
# | train/             |          |
# |    actor_loss      | -506     |
# |    critic_loss     | 75.5     |
# |    ent_coef        | 0.0479   |
# |    ent_coef_loss   | 0.735    |
# |    learning_rate   | 0.000391 |
# |    n_updates       | 913160   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 241      |
# |    ep_rew_mean     | 2.1e+03  |
# | time/              |          |
# |    episodes        | 6032     |
# |    fps             | 64       |
# |    time_elapsed    | 14113    |
# |    total_timesteps | 915219   |
# | train/             |          |
# |    actor_loss      | -505     |
# |    critic_loss     | 76.2     |
# |    ent_coef        | 0.0483   |
# |    ent_coef_loss   | 0.589    |
# |    learning_rate   | 0.00039  |
# |    n_updates       | 914050   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 238      |
# |    ep_rew_mean     | 2.06e+03 |
# | time/              |          |
# |    episodes        | 6036     |
# |    fps             | 64       |
# |    time_elapsed    | 14127    |
# |    total_timesteps | 916127   |
# | train/             |          |
# |    actor_loss      | -503     |
# |    critic_loss     | 78.8     |
# |    ent_coef        | 0.0483   |
# |    ent_coef_loss   | 0.377    |
# |    learning_rate   | 0.000389 |
# |    n_updates       | 914947   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 236      |
# |    ep_rew_mean     | 2.01e+03 |
# | time/              |          |
# |    episodes        | 6040     |
# |    fps             | 64       |
# |    time_elapsed    | 14142    |
# |    total_timesteps | 917108   |
# | train/             |          |
# |    actor_loss      | -501     |
# |    critic_loss     | 79.2     |
# |    ent_coef        | 0.0479   |
# |    ent_coef_loss   | 0.544    |
# |    learning_rate   | 0.000389 |
# |    n_updates       | 915937   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 241      |
# |    ep_rew_mean     | 2.05e+03 |
# | time/              |          |
# |    episodes        | 6044     |
# |    fps             | 64       |
# |    time_elapsed    | 14162    |
# |    total_timesteps | 918556   |
# | train/             |          |
# |    actor_loss      | -500     |
# |    critic_loss     | 76.2     |
# |    ent_coef        | 0.048    |
# |    ent_coef_loss   | -1.18    |
# |    learning_rate   | 0.000388 |
# |    n_updates       | 917254   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 243      |
# |    ep_rew_mean     | 2.06e+03 |
# | time/              |          |
# |    episodes        | 6048     |
# |    fps             | 64       |
# |    time_elapsed    | 14180    |
# |    total_timesteps | 919579   |
# | train/             |          |
# |    actor_loss      | -499     |
# |    critic_loss     | 76.1     |
# |    ent_coef        | 0.0477   |
# |    ent_coef_loss   | -0.428   |
# |    learning_rate   | 0.000387 |
# |    n_updates       | 918401   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 248      |
# |    ep_rew_mean     | 2.09e+03 |
# | time/              |          |
# |    episodes        | 6052     |
# |    fps             | 64       |
# |    time_elapsed    | 14198    |
# |    total_timesteps | 920776   |
# | train/             |          |
# |    actor_loss      | -498     |
# |    critic_loss     | 73.3     |
# |    ent_coef        | 0.0468   |
# |    ent_coef_loss   | -0.0866  |
# |    learning_rate   | 0.000386 |
# |    n_updates       | 919585   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 248      |
# |    ep_rew_mean     | 2.09e+03 |
# | time/              |          |
# |    episodes        | 6056     |
# |    fps             | 64       |
# |    time_elapsed    | 14214    |
# |    total_timesteps | 921797   |
# | train/             |          |
# |    actor_loss      | -500     |
# |    critic_loss     | 73       |
# |    ent_coef        | 0.0464   |
# |    ent_coef_loss   | 0.209    |
# |    learning_rate   | 0.000386 |
# |    n_updates       | 920614   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 248      |
# |    ep_rew_mean     | 2.1e+03  |
# | time/              |          |
# |    episodes        | 6060     |
# |    fps             | 64       |
# |    time_elapsed    | 14231    |
# |    total_timesteps | 922960   |
# | train/             |          |
# |    actor_loss      | -498     |
# |    critic_loss     | 72.3     |
# |    ent_coef        | 0.0463   |
# |    ent_coef_loss   | 1.51     |
# |    learning_rate   | 0.000385 |
# |    n_updates       | 921737   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 255      |
# |    ep_rew_mean     | 2.15e+03 |
# | time/              |          |
# |    episodes        | 6064     |
# |    fps             | 64       |
# |    time_elapsed    | 14252    |
# |    total_timesteps | 924426   |
# | train/             |          |
# |    actor_loss      | -496     |
# |    critic_loss     | 70.3     |
# |    ent_coef        | 0.0457   |
# |    ent_coef_loss   | -0.23    |
# |    learning_rate   | 0.000384 |
# |    n_updates       | 923104   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 259      |
# |    ep_rew_mean     | 2.21e+03 |
# | time/              |          |
# |    episodes        | 6068     |
# |    fps             | 64       |
# |    time_elapsed    | 14272    |
# |    total_timesteps | 925558   |
# | train/             |          |
# |    actor_loss      | -494     |
# |    critic_loss     | 69.9     |
# |    ent_coef        | 0.0462   |
# |    ent_coef_loss   | 0.244    |
# |    learning_rate   | 0.000383 |
# |    n_updates       | 924441   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 261      |
# |    ep_rew_mean     | 2.25e+03 |
# | time/              |          |
# |    episodes        | 6072     |
# |    fps             | 64       |
# |    time_elapsed    | 14287    |
# |    total_timesteps | 926678   |
# | train/             |          |
# |    actor_loss      | -491     |
# |    critic_loss     | 69.9     |
# |    ent_coef        | 0.0454   |
# |    ent_coef_loss   | -0.738   |
# |    learning_rate   | 0.000382 |
# |    n_updates       | 925341   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 267      |
# |    ep_rew_mean     | 2.3e+03  |
# | time/              |          |
# |    episodes        | 6076     |
# |    fps             | 64       |
# |    time_elapsed    | 14305    |
# |    total_timesteps | 927855   |
# | train/             |          |
# |    actor_loss      | -492     |
# |    critic_loss     | 70.8     |
# |    ent_coef        | 0.0459   |
# |    ent_coef_loss   | 0.434    |
# |    learning_rate   | 0.000382 |
# |    n_updates       | 926530   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 268      |
# |    ep_rew_mean     | 2.33e+03 |
# | time/              |          |
# |    episodes        | 6080     |
# |    fps             | 64       |
# |    time_elapsed    | 14319    |
# |    total_timesteps | 928580   |
# | train/             |          |
# |    actor_loss      | -493     |
# |    critic_loss     | 71.8     |
# |    ent_coef        | 0.0473   |
# |    ent_coef_loss   | 1.31     |
# |    learning_rate   | 0.000381 |
# |    n_updates       | 927457   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 266      |
# |    ep_rew_mean     | 2.31e+03 |
# | time/              |          |
# |    episodes        | 6084     |
# |    fps             | 64       |
# |    time_elapsed    | 14330    |
# |    total_timesteps | 929317   |
# | train/             |          |
# |    actor_loss      | -494     |
# |    critic_loss     | 77.5     |
# |    ent_coef        | 0.0472   |
# |    ent_coef_loss   | -0.499   |
# |    learning_rate   | 0.000381 |
# |    n_updates       | 928188   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 263      |
# |    ep_rew_mean     | 2.26e+03 |
# | time/              |          |
# |    episodes        | 6088     |
# |    fps             | 64       |
# |    time_elapsed    | 14342    |
# |    total_timesteps | 930078   |
# | train/             |          |
# |    actor_loss      | -495     |
# |    critic_loss     | 79       |
# |    ent_coef        | 0.0471   |
# |    ent_coef_loss   | 0.453    |
# |    learning_rate   | 0.00038  |
# |    n_updates       | 928933   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 265      |
# |    ep_rew_mean     | 2.28e+03 |
# | time/              |          |
# |    episodes        | 6092     |
# |    fps             | 64       |
# |    time_elapsed    | 14356    |
# |    total_timesteps | 931150   |
# | train/             |          |
# |    actor_loss      | -493     |
# |    critic_loss     | 74.4     |
# |    ent_coef        | 0.0467   |
# |    ent_coef_loss   | -0.0491  |
# |    learning_rate   | 0.000379 |
# |    n_updates       | 929838   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 267      |
# |    ep_rew_mean     | 2.3e+03  |
# | time/              |          |
# |    episodes        | 6096     |
# |    fps             | 64       |
# |    time_elapsed    | 14372    |
# |    total_timesteps | 932326   |
# | train/             |          |
# |    actor_loss      | -491     |
# |    critic_loss     | 74.3     |
# |    ent_coef        | 0.0457   |
# |    ent_coef_loss   | -0.963   |
# |    learning_rate   | 0.000379 |
# |    n_updates       | 930791   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 265      |
# |    ep_rew_mean     | 2.27e+03 |
# | time/              |          |
# |    episodes        | 6100     |
# |    fps             | 64       |
# |    time_elapsed    | 14386    |
# |    total_timesteps | 932994   |
# | train/             |          |
# |    actor_loss      | -490     |
# |    critic_loss     | 71.4     |
# |    ent_coef        | 0.0455   |
# |    ent_coef_loss   | 0.366    |
# |    learning_rate   | 0.000378 |
# |    n_updates       | 931841   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 261      |
# |    ep_rew_mean     | 2.24e+03 |
# | time/              |          |
# |    episodes        | 6104     |
# |    fps             | 64       |
# |    time_elapsed    | 14402    |
# |    total_timesteps | 934017   |
# | train/             |          |
# |    actor_loss      | -489     |
# |    critic_loss     | 71.1     |
# |    ent_coef        | 0.0454   |
# |    ent_coef_loss   | -0.931   |
# |    learning_rate   | 0.000377 |
# |    n_updates       | 932848   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 258      |
# |    ep_rew_mean     | 2.21e+03 |
# | time/              |          |
# |    episodes        | 6108     |
# |    fps             | 64       |
# |    time_elapsed    | 14416    |
# |    total_timesteps | 935045   |
# | train/             |          |
# |    actor_loss      | -489     |
# |    critic_loss     | 69.3     |
# |    ent_coef        | 0.0457   |
# |    ent_coef_loss   | -1.06    |
# |    learning_rate   | 0.000377 |
# |    n_updates       | 933784   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 262      |
# |    ep_rew_mean     | 2.23e+03 |
# | time/              |          |
# |    episodes        | 6112     |
# |    fps             | 64       |
# |    time_elapsed    | 14436    |
# |    total_timesteps | 936370   |
# | train/             |          |
# |    actor_loss      | -490     |
# |    critic_loss     | 70.4     |
# |    ent_coef        | 0.0455   |
# |    ent_coef_loss   | 0.827    |
# |    learning_rate   | 0.000376 |
# |    n_updates       | 935049   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 264      |
# |    ep_rew_mean     | 2.25e+03 |
# | time/              |          |
# |    episodes        | 6116     |
# |    fps             | 64       |
# |    time_elapsed    | 14456    |
# |    total_timesteps | 937648   |
# | train/             |          |
# |    actor_loss      | -490     |
# |    critic_loss     | 70.2     |
# |    ent_coef        | 0.0448   |
# |    ent_coef_loss   | 0.682    |
# |    learning_rate   | 0.000375 |
# |    n_updates       | 936360   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 269      |
# |    ep_rew_mean     | 2.29e+03 |
# | time/              |          |
# |    episodes        | 6120     |
# |    fps             | 64       |
# |    time_elapsed    | 14479    |
# |    total_timesteps | 939156   |
# | train/             |          |
# |    actor_loss      | -489     |
# |    critic_loss     | 70       |
# |    ent_coef        | 0.0453   |
# |    ent_coef_loss   | 0.557    |
# |    learning_rate   | 0.000374 |
# |    n_updates       | 937821   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 275      |
# |    ep_rew_mean     | 2.36e+03 |
# | time/              |          |
# |    episodes        | 6124     |
# |    fps             | 64       |
# |    time_elapsed    | 14504    |
# |    total_timesteps | 940720   |
# | train/             |          |
# |    actor_loss      | -491     |
# |    critic_loss     | 70.1     |
# |    ent_coef        | 0.0447   |
# |    ent_coef_loss   | -0.516   |
# |    learning_rate   | 0.000373 |
# |    n_updates       | 939434   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 273      |
# |    ep_rew_mean     | 2.34e+03 |
# | time/              |          |
# |    episodes        | 6128     |
# |    fps             | 64       |
# |    time_elapsed    | 14521    |
# |    total_timesteps | 941752   |
# | train/             |          |
# |    actor_loss      | -494     |
# |    critic_loss     | 70.9     |
# |    ent_coef        | 0.0457   |
# |    ent_coef_loss   | 1.8      |
# |    learning_rate   | 0.000372 |
# |    n_updates       | 940599   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 275      |
# |    ep_rew_mean     | 2.34e+03 |
# | time/              |          |
# |    episodes        | 6132     |
# |    fps             | 64       |
# |    time_elapsed    | 14535    |
# |    total_timesteps | 942702   |
# | train/             |          |
# |    actor_loss      | -490     |
# |    critic_loss     | 73.8     |
# |    ent_coef        | 0.0471   |
# |    ent_coef_loss   | 0.843    |
# |    learning_rate   | 0.000372 |
# |    n_updates       | 941478   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 275      |
# |    ep_rew_mean     | 2.36e+03 |
# | time/              |          |
# |    episodes        | 6136     |
# |    fps             | 64       |
# |    time_elapsed    | 14550    |
# |    total_timesteps | 943591   |
# | train/             |          |
# |    actor_loss      | -492     |
# |    critic_loss     | 75       |
# |    ent_coef        | 0.0464   |
# |    ent_coef_loss   | 1.19     |
# |    learning_rate   | 0.000371 |
# |    n_updates       | 942458   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 272      |
# |    ep_rew_mean     | 2.33e+03 |
# | time/              |          |
# |    episodes        | 6140     |
# |    fps             | 64       |
# |    time_elapsed    | 14561    |
# |    total_timesteps | 944283   |
# | train/             |          |
# |    actor_loss      | -493     |
# |    critic_loss     | 77.9     |
# |    ent_coef        | 0.0467   |
# |    ent_coef_loss   | 0.101    |
# |    learning_rate   | 0.000371 |
# |    n_updates       | 943180   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 263      |
# |    ep_rew_mean     | 2.26e+03 |
# | time/              |          |
# |    episodes        | 6144     |
# |    fps             | 64       |
# |    time_elapsed    | 14569    |
# |    total_timesteps | 944816   |
# | train/             |          |
# |    actor_loss      | -496     |
# |    critic_loss     | 75.3     |
# |    ent_coef        | 0.0467   |
# |    ent_coef_loss   | -2.67    |
# |    learning_rate   | 0.00037  |
# |    n_updates       | 943705   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 260      |
# |    ep_rew_mean     | 2.21e+03 |
# | time/              |          |
# |    episodes        | 6148     |
# |    fps             | 64       |
# |    time_elapsed    | 14580    |
# |    total_timesteps | 945539   |
# | train/             |          |
# |    actor_loss      | -490     |
# |    critic_loss     | 76       |
# |    ent_coef        | 0.0466   |
# |    ent_coef_loss   | 0.545    |
# |    learning_rate   | 0.00037  |
# |    n_updates       | 944399   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 257      |
# |    ep_rew_mean     | 2.19e+03 |
# | time/              |          |
# |    episodes        | 6152     |
# |    fps             | 64       |
# |    time_elapsed    | 14592    |
# |    total_timesteps | 946454   |
# | train/             |          |
# |    actor_loss      | -494     |
# |    critic_loss     | 75.8     |
# |    ent_coef        | 0.0461   |
# |    ent_coef_loss   | -0.107   |
# |    learning_rate   | 0.000369 |
# |    n_updates       | 945176   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 255      |
# |    ep_rew_mean     | 2.14e+03 |
# | time/              |          |
# |    episodes        | 6156     |
# |    fps             | 64       |
# |    time_elapsed    | 14606    |
# |    total_timesteps | 947257   |
# | train/             |          |
# |    actor_loss      | -494     |
# |    critic_loss     | 76.7     |
# |    ent_coef        | 0.0461   |
# |    ent_coef_loss   | 0.684    |
# |    learning_rate   | 0.000369 |
# |    n_updates       | 946087   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 251      |
# |    ep_rew_mean     | 2.09e+03 |
# | time/              |          |
# |    episodes        | 6160     |
# |    fps             | 64       |
# |    time_elapsed    | 14619    |
# |    total_timesteps | 948059   |
# | train/             |          |
# |    actor_loss      | -499     |
# |    critic_loss     | 82.1     |
# |    ent_coef        | 0.0468   |
# |    ent_coef_loss   | 0.721    |
# |    learning_rate   | 0.000368 |
# |    n_updates       | 946887   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 243      |
# |    ep_rew_mean     | 2.02e+03 |
# | time/              |          |
# |    episodes        | 6164     |
# |    fps             | 64       |
# |    time_elapsed    | 14629    |
# |    total_timesteps | 948688   |
# | train/             |          |
# |    actor_loss      | -496     |
# |    critic_loss     | 78.7     |
# |    ent_coef        | 0.0463   |
# |    ent_coef_loss   | -0.734   |
# |    learning_rate   | 0.000368 |
# |    n_updates       | 947545   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 239      |
# |    ep_rew_mean     | 1.96e+03 |
# | time/              |          |
# |    episodes        | 6168     |
# |    fps             | 64       |
# |    time_elapsed    | 14639    |
# |    total_timesteps | 949412   |
# | train/             |          |
# |    actor_loss      | -498     |
# |    critic_loss     | 78.5     |
# |    ent_coef        | 0.0464   |
# |    ent_coef_loss   | 1.24     |
# |    learning_rate   | 0.000367 |
# |    n_updates       | 948175   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 238      |
# |    ep_rew_mean     | 1.98e+03 |
# | time/              |          |
# |    episodes        | 6172     |
# |    fps             | 64       |
# |    time_elapsed    | 14655    |
# |    total_timesteps | 950470   |
# | train/             |          |
# |    actor_loss      | -502     |
# |    critic_loss     | 76.6     |
# |    ent_coef        | 0.047    |
# |    ent_coef_loss   | -0.385   |
# |    learning_rate   | 0.000367 |
# |    n_updates       | 949249   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 238      |
# |    ep_rew_mean     | 1.98e+03 |
# | time/              |          |
# |    episodes        | 6176     |
# |    fps             | 64       |
# |    time_elapsed    | 14672    |
# |    total_timesteps | 951645   |
# | train/             |          |
# |    actor_loss      | -502     |
# |    critic_loss     | 75.2     |
# |    ent_coef        | 0.0467   |
# |    ent_coef_loss   | -0.334   |
# |    learning_rate   | 0.000366 |
# |    n_updates       | 950330   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 2.01e+03 |
# | time/              |          |
# |    episodes        | 6180     |
# |    fps             | 64       |
# |    time_elapsed    | 14687    |
# |    total_timesteps | 952537   |
# | train/             |          |
# |    actor_loss      | -503     |
# |    critic_loss     | 74.7     |
# |    ent_coef        | 0.0466   |
# |    ent_coef_loss   | 0.286    |
# |    learning_rate   | 0.000365 |
# |    n_updates       | 951323   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 243      |
# |    ep_rew_mean     | 2.08e+03 |
# | time/              |          |
# |    episodes        | 6184     |
# |    fps             | 64       |
# |    time_elapsed    | 14705    |
# |    total_timesteps | 953642   |
# | train/             |          |
# |    actor_loss      | -501     |
# |    critic_loss     | 74.1     |
# |    ent_coef        | 0.0469   |
# |    ent_coef_loss   | -1.76    |
# |    learning_rate   | 0.000364 |
# |    n_updates       | 952439   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 247      |
# |    ep_rew_mean     | 2.13e+03 |
# | time/              |          |
# |    episodes        | 6188     |
# |    fps             | 64       |
# |    time_elapsed    | 14721    |
# |    total_timesteps | 954750   |
# | train/             |          |
# |    actor_loss      | -501     |
# |    critic_loss     | 78       |
# |    ent_coef        | 0.0472   |
# |    ent_coef_loss   | -0.0889  |
# |    learning_rate   | 0.000364 |
# |    n_updates       | 953533   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 245      |
# |    ep_rew_mean     | 2.12e+03 |
# | time/              |          |
# |    episodes        | 6192     |
# |    fps             | 64       |
# |    time_elapsed    | 14736    |
# |    total_timesteps | 955636   |
# | train/             |          |
# |    actor_loss      | -501     |
# |    critic_loss     | 81.2     |
# |    ent_coef        | 0.0478   |
# |    ent_coef_loss   | 0.846    |
# |    learning_rate   | 0.000363 |
# |    n_updates       | 954495   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 2.09e+03 |
# | time/              |          |
# |    episodes        | 6196     |
# |    fps             | 64       |
# |    time_elapsed    | 14747    |
# |    total_timesteps | 956363   |
# | train/             |          |
# |    actor_loss      | -503     |
# |    critic_loss     | 86.1     |
# |    ent_coef        | 0.0486   |
# |    ent_coef_loss   | 0.104    |
# |    learning_rate   | 0.000363 |
# |    n_updates       | 955219   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 241      |
# |    ep_rew_mean     | 2.09e+03 |
# | time/              |          |
# |    episodes        | 6200     |
# |    fps             | 64       |
# |    time_elapsed    | 14760    |
# |    total_timesteps | 957126   |
# | train/             |          |
# |    actor_loss      | -506     |
# |    critic_loss     | 87.5     |
# |    ent_coef        | 0.0487   |
# |    ent_coef_loss   | -0.54    |
# |    learning_rate   | 0.000362 |
# |    n_updates       | 956020   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 2.07e+03 |
# | time/              |          |
# |    episodes        | 6204     |
# |    fps             | 64       |
# |    time_elapsed    | 14771    |
# |    total_timesteps | 958007   |
# | train/             |          |
# |    actor_loss      | -507     |
# |    critic_loss     | 86.8     |
# |    ent_coef        | 0.0488   |
# |    ent_coef_loss   | 1.17     |
# |    learning_rate   | 0.000362 |
# |    n_updates       | 956750   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 237      |
# |    ep_rew_mean     | 2.01e+03 |
# | time/              |          |
# |    episodes        | 6208     |
# |    fps             | 64       |
# |    time_elapsed    | 14783    |
# |    total_timesteps | 958719   |
# | train/             |          |
# |    actor_loss      | -510     |
# |    critic_loss     | 86.2     |
# |    ent_coef        | 0.0491   |
# |    ent_coef_loss   | 0.726    |
# |    learning_rate   | 0.000361 |
# |    n_updates       | 957526   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | 1.94e+03 |
# | time/              |          |
# |    episodes        | 6212     |
# |    fps             | 64       |
# |    time_elapsed    | 14795    |
# |    total_timesteps | 959398   |
# | train/             |          |
# |    actor_loss      | -510     |
# |    critic_loss     | 83.8     |
# |    ent_coef        | 0.0488   |
# |    ent_coef_loss   | 0.0493   |
# |    learning_rate   | 0.000361 |
# |    n_updates       | 958277   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | 1.94e+03 |
# | time/              |          |
# |    episodes        | 6216     |
# |    fps             | 64       |
# |    time_elapsed    | 14814    |
# |    total_timesteps | 960759   |
# | train/             |          |
# |    actor_loss      | -501     |
# |    critic_loss     | 80.7     |
# |    ent_coef        | 0.0477   |
# |    ent_coef_loss   | -0.643   |
# |    learning_rate   | 0.00036  |
# |    n_updates       | 959449   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | 1.92e+03 |
# | time/              |          |
# |    episodes        | 6220     |
# |    fps             | 64       |
# |    time_elapsed    | 14831    |
# |    total_timesteps | 961766   |
# | train/             |          |
# |    actor_loss      | -500     |
# |    critic_loss     | 78.1     |
# |    ent_coef        | 0.0464   |
# |    ent_coef_loss   | 1.23     |
# |    learning_rate   | 0.000359 |
# |    n_updates       | 960623   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 222      |
# |    ep_rew_mean     | 1.89e+03 |
# | time/              |          |
# |    episodes        | 6224     |
# |    fps             | 64       |
# |    time_elapsed    | 14848    |
# |    total_timesteps | 962940   |
# | train/             |          |
# |    actor_loss      | -498     |
# |    critic_loss     | 77.5     |
# |    ent_coef        | 0.0466   |
# |    ent_coef_loss   | 0.133    |
# |    learning_rate   | 0.000358 |
# |    n_updates       | 961728   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 222      |
# |    ep_rew_mean     | 1.89e+03 |
# | time/              |          |
# |    episodes        | 6228     |
# |    fps             | 64       |
# |    time_elapsed    | 14864    |
# |    total_timesteps | 963957   |
# | train/             |          |
# |    actor_loss      | -500     |
# |    critic_loss     | 78.9     |
# |    ent_coef        | 0.0466   |
# |    ent_coef_loss   | 0.409    |
# |    learning_rate   | 0.000358 |
# |    n_updates       | 962741   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 222      |
# |    ep_rew_mean     | 1.9e+03  |
# | time/              |          |
# |    episodes        | 6232     |
# |    fps             | 64       |
# |    time_elapsed    | 14878    |
# |    total_timesteps | 964878   |
# | train/             |          |
# |    actor_loss      | -506     |
# |    critic_loss     | 81.7     |
# |    ent_coef        | 0.0469   |
# |    ent_coef_loss   | 1.59     |
# |    learning_rate   | 0.000357 |
# |    n_updates       | 963677   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 222      |
# |    ep_rew_mean     | 1.9e+03  |
# | time/              |          |
# |    episodes        | 6236     |
# |    fps             | 64       |
# |    time_elapsed    | 14894    |
# |    total_timesteps | 965823   |
# | train/             |          |
# |    actor_loss      | -507     |
# |    critic_loss     | 85.7     |
# |    ent_coef        | 0.0489   |
# |    ent_coef_loss   | 0.321    |
# |    learning_rate   | 0.000356 |
# |    n_updates       | 964669   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 223      |
# |    ep_rew_mean     | 1.91e+03 |
# | time/              |          |
# |    episodes        | 6240     |
# |    fps             | 64       |
# |    time_elapsed    | 14905    |
# |    total_timesteps | 966608   |
# | train/             |          |
# |    actor_loss      | -510     |
# |    critic_loss     | 86.4     |
# |    ent_coef        | 0.0497   |
# |    ent_coef_loss   | 0.0246   |
# |    learning_rate   | 0.000356 |
# |    n_updates       | 965415   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | 1.93e+03 |
# | time/              |          |
# |    episodes        | 6244     |
# |    fps             | 64       |
# |    time_elapsed    | 14920    |
# |    total_timesteps | 967581   |
# | train/             |          |
# |    actor_loss      | -510     |
# |    critic_loss     | 85.2     |
# |    ent_coef        | 0.0499   |
# |    ent_coef_loss   | -0.0864  |
# |    learning_rate   | 0.000355 |
# |    n_updates       | 966401   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | 1.96e+03 |
# | time/              |          |
# |    episodes        | 6248     |
# |    fps             | 64       |
# |    time_elapsed    | 14935    |
# |    total_timesteps | 968559   |
# | train/             |          |
# |    actor_loss      | -507     |
# |    critic_loss     | 84.4     |
# |    ent_coef        | 0.0496   |
# |    ent_coef_loss   | -0.764   |
# |    learning_rate   | 0.000354 |
# |    n_updates       | 967379   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | 1.95e+03 |
# | time/              |          |
# |    episodes        | 6252     |
# |    fps             | 64       |
# |    time_elapsed    | 14951    |
# |    total_timesteps | 969590   |
# | train/             |          |
# |    actor_loss      | -504     |
# |    critic_loss     | 85.6     |
# |    ent_coef        | 0.0486   |
# |    ent_coef_loss   | -0.0462  |
# |    learning_rate   | 0.000354 |
# |    n_updates       | 968421   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | 1.98e+03 |
# | time/              |          |
# |    episodes        | 6256     |
# |    fps             | 64       |
# |    time_elapsed    | 14964    |
# |    total_timesteps | 970533   |
# | train/             |          |
# |    actor_loss      | -504     |
# |    critic_loss     | 82.3     |
# |    ent_coef        | 0.0483   |
# |    ent_coef_loss   | 0.105    |
# |    learning_rate   | 0.000353 |
# |    n_updates       | 969247   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# ...
# |    fps             | 64       |
# |    time_elapsed    | 22224    |
# |    total_timesteps | 1442558  |
# | train/             |          |
# |    actor_loss      | -428     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.0435   |
# |    ent_coef_loss   | -2.06    |
# |    learning_rate   | 3.85e-05 |
# |    n_updates       | 1441249  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 333      |
# |    ep_rew_mean     | 3.24e+03 |
# | time/              |          |
# |    episodes        | 7892     |
# |    fps             | 64       |
# |    time_elapsed    | 22254    |
# |    total_timesteps | 1444523  |
# | train/             |          |
# |    actor_loss      | -426     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.043    |
# |    ent_coef_loss   | -0.714   |
# |    learning_rate   | 3.73e-05 |
# |    n_updates       | 1443137  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 340      |
# |    ep_rew_mean     | 3.34e+03 |
# | time/              |          |
# |    episodes        | 7896     |
# |    fps             | 64       |
# |    time_elapsed    | 22278    |
# |    total_timesteps | 1446100  |
# | train/             |          |
# |    actor_loss      | -426     |
# |    critic_loss     | 122      |
# |    ent_coef        | 0.0429   |
# |    ent_coef_loss   | 0.61     |
# |    learning_rate   | 3.62e-05 |
# |    n_updates       | 1444701  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 346      |
# |    ep_rew_mean     | 3.44e+03 |
# | time/              |          |
# |    episodes        | 7900     |
# |    fps             | 64       |
# |    time_elapsed    | 22303    |
# |    total_timesteps | 1447855  |
# | train/             |          |
# |    actor_loss      | -425     |
# |    critic_loss     | 120      |
# |    ent_coef        | 0.043    |
# |    ent_coef_loss   | 0.229    |
# |    learning_rate   | 3.52e-05 |
# |    n_updates       | 1446302  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 343      |
# |    ep_rew_mean     | 3.42e+03 |
# | time/              |          |
# |    episodes        | 7904     |
# |    fps             | 64       |
# |    time_elapsed    | 22332    |
# |    total_timesteps | 1449603  |
# | train/             |          |
# |    actor_loss      | -421     |
# |    critic_loss     | 117      |
# |    ent_coef        | 0.0425   |
# |    ent_coef_loss   | 0.0121   |
# |    learning_rate   | 3.38e-05 |
# |    n_updates       | 1448275  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 350      |
# |    ep_rew_mean     | 3.45e+03 |
# | time/              |          |
# |    episodes        | 7908     |
# |    fps             | 64       |
# |    time_elapsed    | 22362    |
# |    total_timesteps | 1451537  |
# | train/             |          |
# |    actor_loss      | -421     |
# |    critic_loss     | 120      |
# |    ent_coef        | 0.0423   |
# |    ent_coef_loss   | -0.311   |
# |    learning_rate   | 3.26e-05 |
# |    n_updates       | 1450190  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 354      |
# |    ep_rew_mean     | 3.52e+03 |
# | time/              |          |
# |    episodes        | 7912     |
# |    fps             | 64       |
# |    time_elapsed    | 22383    |
# |    total_timesteps | 1452991  |
# | train/             |          |
# |    actor_loss      | -421     |
# |    critic_loss     | 118      |
# |    ent_coef        | 0.042    |
# |    ent_coef_loss   | -1.7     |
# |    learning_rate   | 3.16e-05 |
# |    n_updates       | 1451598  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 356      |
# |    ep_rew_mean     | 3.54e+03 |
# | time/              |          |
# |    episodes        | 7916     |
# |    fps             | 64       |
# |    time_elapsed    | 22411    |
# |    total_timesteps | 1454834  |
# | train/             |          |
# |    actor_loss      | -420     |
# |    critic_loss     | 120      |
# |    ent_coef        | 0.0418   |
# |    ent_coef_loss   | -0.281   |
# |    learning_rate   | 3.04e-05 |
# |    n_updates       | 1453377  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 354      |
# |    ep_rew_mean     | 3.55e+03 |
# | time/              |          |
# |    episodes        | 7920     |
# |    fps             | 64       |
# |    time_elapsed    | 22432    |
# |    total_timesteps | 1456143  |
# | train/             |          |
# |    actor_loss      | -419     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.0417   |
# |    ent_coef_loss   | -0.416   |
# |    learning_rate   | 2.95e-05 |
# |    n_updates       | 1454795  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 358      |
# |    ep_rew_mean     | 3.59e+03 |
# | time/              |          |
# |    episodes        | 7924     |
# |    fps             | 64       |
# |    time_elapsed    | 22455    |
# |    total_timesteps | 1457661  |
# | train/             |          |
# |    actor_loss      | -417     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.0417   |
# |    ent_coef_loss   | 0.618    |
# |    learning_rate   | 2.85e-05 |
# |    n_updates       | 1456270  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 362      |
# |    ep_rew_mean     | 3.6e+03  |
# | time/              |          |
# |    episodes        | 7928     |
# |    fps             | 64       |
# |    time_elapsed    | 22482    |
# |    total_timesteps | 1459337  |
# | train/             |          |
# |    actor_loss      | -415     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.0419   |
# |    ent_coef_loss   | 0.858    |
# |    learning_rate   | 2.73e-05 |
# |    n_updates       | 1458018  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 363      |
# |    ep_rew_mean     | 3.65e+03 |
# | time/              |          |
# |    episodes        | 7932     |
# |    fps             | 64       |
# |    time_elapsed    | 22506    |
# |    total_timesteps | 1460862  |
# | train/             |          |
# |    actor_loss      | -414     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.0419   |
# |    ent_coef_loss   | -0.625   |
# |    learning_rate   | 2.63e-05 |
# |    n_updates       | 1459612  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 368      |
# |    ep_rew_mean     | 3.69e+03 |
# | time/              |          |
# |    episodes        | 7936     |
# |    fps             | 64       |
# |    time_elapsed    | 22531    |
# |    total_timesteps | 1462545  |
# | train/             |          |
# |    actor_loss      | -413     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.0418   |
# |    ent_coef_loss   | -1.49    |
# |    learning_rate   | 2.52e-05 |
# |    n_updates       | 1461198  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 371      |
# |    ep_rew_mean     | 3.74e+03 |
# | time/              |          |
# |    episodes        | 7940     |
# |    fps             | 64       |
# |    time_elapsed    | 22553    |
# |    total_timesteps | 1464000  |
# | train/             |          |
# |    actor_loss      | -412     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.0415   |
# |    ent_coef_loss   | -2.2     |
# |    learning_rate   | 2.43e-05 |
# |    n_updates       | 1462614  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 375      |
# |    ep_rew_mean     | 3.77e+03 |
# | time/              |          |
# |    episodes        | 7944     |
# |    fps             | 64       |
# |    time_elapsed    | 22579    |
# |    total_timesteps | 1465615  |
# | train/             |          |
# |    actor_loss      | -410     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.041    |
# |    ent_coef_loss   | -2.55    |
# |    learning_rate   | 2.32e-05 |
# |    n_updates       | 1464296  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 375      |
# |    ep_rew_mean     | 3.77e+03 |
# | time/              |          |
# |    episodes        | 7948     |
# |    fps             | 64       |
# |    time_elapsed    | 22598    |
# |    total_timesteps | 1466859  |
# | train/             |          |
# |    actor_loss      | -410     |
# |    critic_loss     | 120      |
# |    ent_coef        | 0.0407   |
# |    ent_coef_loss   | -2.02    |
# |    learning_rate   | 2.23e-05 |
# |    n_updates       | 1465614  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 376      |
# |    ep_rew_mean     | 3.8e+03  |
# | time/              |          |
# |    episodes        | 7952     |
# |    fps             | 64       |
# |    time_elapsed    | 22620    |
# |    total_timesteps | 1468336  |
# | train/             |          |
# |    actor_loss      | -411     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.0404   |
# |    ent_coef_loss   | -1.36    |
# |    learning_rate   | 2.13e-05 |
# |    n_updates       | 1467019  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 382      |
# |    ep_rew_mean     | 3.9e+03  |
# | time/              |          |
# |    episodes        | 7956     |
# |    fps             | 64       |
# |    time_elapsed    | 22642    |
# |    total_timesteps | 1469776  |
# | train/             |          |
# |    actor_loss      | -407     |
# |    critic_loss     | 120      |
# |    ent_coef        | 0.0402   |
# |    ent_coef_loss   | -1.94    |
# |    learning_rate   | 2.04e-05 |
# |    n_updates       | 1468486  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 387      |
# |    ep_rew_mean     | 3.97e+03 |
# | time/              |          |
# |    episodes        | 7960     |
# |    fps             | 64       |
# |    time_elapsed    | 22665    |
# |    total_timesteps | 1471454  |
# | train/             |          |
# |    actor_loss      | -408     |
# |    critic_loss     | 119      |
# |    ent_coef        | 0.04     |
# |    ent_coef_loss   | -0.836   |
# |    learning_rate   | 1.94e-05 |
# |    n_updates       | 1469939  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 390      |
# |    ep_rew_mean     | 4.03e+03 |
# | time/              |          |
# |    episodes        | 7964     |
# |    fps             | 64       |
# |    time_elapsed    | 22691    |
# |    total_timesteps | 1473001  |
# | train/             |          |
# |    actor_loss      | -407     |
# |    critic_loss     | 123      |
# |    ent_coef        | 0.0399   |
# |    ent_coef_loss   | -0.114   |
# |    learning_rate   | 1.82e-05 |
# |    n_updates       | 1471663  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 396      |
# |    ep_rew_mean     | 4.09e+03 |
# | time/              |          |
# |    episodes        | 7968     |
# |    fps             | 64       |
# |    time_elapsed    | 22722    |
# |    total_timesteps | 1474951  |
# | train/             |          |
# |    actor_loss      | -408     |
# |    critic_loss     | 123      |
# |    ent_coef        | 0.04     |
# |    ent_coef_loss   | 1.61     |
# |    learning_rate   | 1.69e-05 |
# |    n_updates       | 1473715  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 406      |
# |    ep_rew_mean     | 4.18e+03 |
# | time/              |          |
# |    episodes        | 7972     |
# |    fps             | 64       |
# |    time_elapsed    | 22754    |
# |    total_timesteps | 1477151  |
# | train/             |          |
# |    actor_loss      | -405     |
# |    critic_loss     | 125      |
# |    ent_coef        | 0.0402   |
# |    ent_coef_loss   | -0.297   |
# |    learning_rate   | 1.55e-05 |
# |    n_updates       | 1475747  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 409      |
# |    ep_rew_mean     | 4.21e+03 |
# | time/              |          |
# |    episodes        | 7976     |
# |    fps             | 64       |
# |    time_elapsed    | 22780    |
# |    total_timesteps | 1478890  |
# | train/             |          |
# |    actor_loss      | -404     |
# |    critic_loss     | 126      |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | 0.132    |
# |    learning_rate   | 1.44e-05 |
# |    n_updates       | 1477450  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 419      |
# |    ep_rew_mean     | 4.28e+03 |
# | time/              |          |
# |    episodes        | 7980     |
# |    fps             | 64       |
# |    time_elapsed    | 22812    |
# |    total_timesteps | 1481074  |
# | train/             |          |
# |    actor_loss      | -402     |
# |    critic_loss     | 127      |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | -0.306   |
# |    learning_rate   | 1.31e-05 |
# |    n_updates       | 1479427  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 423      |
# |    ep_rew_mean     | 4.34e+03 |
# | time/              |          |
# |    episodes        | 7984     |
# |    fps             | 64       |
# |    time_elapsed    | 22842    |
# |    total_timesteps | 1482866  |
# | train/             |          |
# |    actor_loss      | -400     |
# |    critic_loss     | 126      |
# |    ent_coef        | 0.04     |
# |    ent_coef_loss   | -0.392   |
# |    learning_rate   | 1.17e-05 |
# |    n_updates       | 1481459  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 421      |
# |    ep_rew_mean     | 4.35e+03 |
# | time/              |          |
# |    episodes        | 7988     |
# |    fps             | 64       |
# |    time_elapsed    | 22870    |
# |    total_timesteps | 1484615  |
# | train/             |          |
# |    actor_loss      | -399     |
# |    critic_loss     | 126      |
# |    ent_coef        | 0.04     |
# |    ent_coef_loss   | -0.512   |
# |    learning_rate   | 1.05e-05 |
# |    n_updates       | 1483231  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 420      |
# |    ep_rew_mean     | 4.35e+03 |
# | time/              |          |
# |    episodes        | 7992     |
# |    fps             | 64       |
# |    time_elapsed    | 22899    |
# |    total_timesteps | 1486528  |
# | train/             |          |
# |    actor_loss      | -399     |
# |    critic_loss     | 127      |
# |    ent_coef        | 0.0399   |
# |    ent_coef_loss   | -0.587   |
# |    learning_rate   | 9.26e-06 |
# |    n_updates       | 1485140  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 433      |
# |    ep_rew_mean     | 4.47e+03 |
# | time/              |          |
# |    episodes        | 7996     |
# |    fps             | 64       |
# |    time_elapsed    | 22939    |
# |    total_timesteps | 1489415  |
# | train/             |          |
# |    actor_loss      | -396     |
# |    critic_loss     | 130      |
# |    ent_coef        | 0.0397   |
# |    ent_coef_loss   | -2.64    |
# |    learning_rate   | 7.59e-06 |
# |    n_updates       | 1487649  |
# ---------------------------------

# %%
# 设置虚拟显示
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# 设置环境变量
import os
os.environ["DISPLAY"] = ":0"
os.environ["MUJOCO_GL"] = "osmesa"  # 使用 EGL 渲染

# %%
# 运行代码
video_name = 'walk_play_period_video'
get_vid(name='play_period', env_name='myoLegWalk-v0', seed='0', episodes=10, video_name=video_name)
show_video(f"{video_name}.mp4")
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# FatalError                                Traceback (most recent call last)
# <ipython-input-30-ad1d88af855d> in <cell line: 0>()
#      11 # 运行代码
#      12 video_name = 'walk_play_period_video'
# ---> 13 get_vid(name='play_period', env_name='myoLegWalk-v0', seed='0', episodes=10, video_name=video_name)
#      14 show_video(f"{video_name}.mp4")
#
# /content/drive/MyDrive/SAR/myosuite-main/docs/source/tutorials/SAR/SAR_tutorial_utils.py in get_vid(name, env_name, seed, episodes, video_name, determ, pca, ica, normalizer, phi, is_sar, syn_nosyn)
#     375             a, __ = model.predict(o, deterministic=determ)
#     376
# --> 377             frame = env.unwrapped.sim.renderer.render_offscreen(width=640, height=480,camera_id=camera)
#     378             frames.append(frame)
#     379
#
# /usr/local/lib/python3.11/dist-packages/myosuite/renderer/mj_renderer.py in render_offscreen(self, width, height, rgb, depth, segmentation, camera_id, device_id)
#     105             camera_id = -1
#     106         if self._renderer is None:
# --> 107             self.setup_renderer(self._sim.model.ptr, width=width, height=height)
#     108
#     109         rgb_arr = None; dpt_arr = None; seg_arr = None
#
# /usr/local/lib/python3.11/dist-packages/myosuite/renderer/mj_renderer.py in setup_renderer(self, model, height, width)
#      46
#      47     def setup_renderer(self, model, height, width):
# ---> 48         self._renderer = mujoco.Renderer(model, height=height, width=width)
#      49         self._scene_option = mujoco.MjvOption()
#      50         self._update_renderer_settings(self._scene_option)
#
# /usr/local/lib/python3.11/dist-packages/mujoco/renderer.py in __init__(self, model, height, width, max_geom)
#      81     self._gl_context = gl_context.GLContext(width, height)  # type: ignore
#      82     self._gl_context.make_current()
# ---> 83     self._mjr_context = _render.MjrContext(
#      84         model, _enums.mjtFontScale.mjFONTSCALE_150.value
#      85     )
#
# FatalError: gladLoadGL error

# %%
muscle_data = get_activations(name='play_period', env_name='myoLegWalk-v0', seed='0', episodes=2000)
# 保存到 Google Drive
np.save('/content/drive/MyDrive/SAR/myosuite-main/docs/source/tutorials/SAR/muscle_data.npy', muscle_data)
# Out:
#     MyoSuite: A contact-rich simulation suite for musculoskeletal motor control
#         Vittorio Caggiano, Huawei Wang, Guillaume Durandau, Massimo Sartori, Vikash Kumar
#         L4DC-2019 | https://sites.google.com/view/myosuite
# /usr/local/lib/python3.11/dist-packages/glfw/__init__.py:917: GLFWError: (65550) b'X11: The DISPLAY environment variable is missing'
#   warnings.warn(message, GLFWError)
# /usr/local/lib/python3.11/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.get_obs to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_obs` for environment variables or `env.get_wrapper_attr('get_obs')` that will search the reminding wrappers.
#   logger.warn(
#   0%|          | 0/2000 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.sim to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.sim` for environment variables or `env.get_wrapper_attr('sim')` that will search the reminding wrappers.
#   logger.warn(
# 100%|██████████| 2000/2000 [49:53<00:00,  1.50s/it]

# %%
muscle_data.shape
# Out:
# (316166, 80)

# %%
# 读取数据
muscle_data = np.load('/content/drive/MyDrive/SAR/myosuite-main/docs/source/tutorials/SAR/muscle_data.npy')

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
syn_dict = find_synergies_vae(muscle_data, list(range(5, 81, 5)), epochs=1000, lr=0.001, batch_size=512, plot=True, device=device) #list(range(5, 81, 5))
print("VAF by N synergies:", syn_dict)
# Out:
# 训练 VAE，潜在维度 = 5 ...
#   Epoch 1/1000 - 平均损失: 21.3520 (重构: 17.0222, KL: 54.9544, 权重: 0.00)
#   Epoch 10/1000 - 平均损失: 12.2842 (重构: 12.1440, KL: 19.8039, 权重: 0.01)
#   Epoch 20/1000 - 平均损失: 11.8771 (重构: 10.7892, KL: 17.3006, 权重: 0.03)
#   Epoch 30/1000 - 平均损失: 11.7993 (重构: 10.6350, KL: 15.9962, 权重: 0.04)
#   Epoch 40/1000 - 平均损失: 11.8275 (重构: 11.1842, KL: 15.4520, 权重: 0.06)
#   Epoch 50/1000 - 平均损失: 11.9133 (重构: 11.0089, KL: 14.5495, 权重: 0.07)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-e57fdd123d88> in <cell line: 0>()
#       1 device = 'cuda' if torch.cuda.is_available() else 'cpu'
# ----> 2 syn_dict = find_synergies_vae(muscle_data, list(range(5, 81, 5)), epochs=1000, lr=0.001, batch_size=512, plot=True, device=device) #list(range(5, 81, 5))
#       3 print("VAF by N synergies:", syn_dict)
#
# <ipython-input-65-67a0ec2fbb2f> in find_synergies_vae(acts, latent_dims_list, epochs, lr, batch_size, plot, device)
#      29             model.train()
#      30             total_loss = 0.0
# ---> 31             for batch_data, in data_loader:
#      32                 batch_data = batch_data.to(device)
#      33                 # 前向传播计算重构结果、潜在均值和log方差
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     706                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707                 self._reset()  # type: ignore[call-arg]
# --> 708             data = self._next_data()
#     709             self._num_yielded += 1
#     710             if (
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     762     def _next_data(self):
#     763         index = self._next_index()  # may raise StopIteration
# --> 764         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765         if self._pin_memory:
#     766             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataset.py in __getitem__(self, index)
#     209
#     210     def __getitem__(self, index):
# --> 211         return tuple(tensor[index] for tensor in self.tensors)
#     212
#     213     def __len__(self):
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataset.py in <genexpr>(.0)
#     209
#     210     def __getitem__(self, index):
# --> 211         return tuple(tensor[index] for tensor in self.tensors)
#     212
#     213     def __len__(self):
#
# KeyboardInterrupt:

# %%
syn_dict = find_synergies(muscle_data, plot=True)
print("VAF by N synergies:", syn_dict)

# %%
import joblib
vae_model, normalizer = compute_VAE_SAR(muscle_data, latent_dim=25, epochs=500, batch_size=512)
joblib.dump(normalizer, "normalizer.pkl")
# 保存权重
torch.save(vae_model.state_dict(), "vae_weights.pt")
print("训练完毕，参数已保存")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-f88b25d0f86b> in <cell line: 0>()
#       1 import joblib
# ----> 2 vae_model, normalizer = compute_VAE_SAR(muscle_data, latent_dim=25, epochs=500, batch_size=512)
#       3 joblib.dump(normalizer, "normalizer.pkl")
#       4 # 保存权重
#       5 torch.save(vae_model.state_dict(), "vae_weights.pt")
#
# <ipython-input-8-5a275e5fdfc0> in compute_VAE_SAR(acts, latent_dim, epochs, lr, batch_size, device)
#      22     # 创建 VAE 模型
#      23     model = VAE(input_dim=X_tensor.shape[1], latent_dim=latent_dim).to(device)
# ---> 24     optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#      25
#      26     mu_list = []
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/adam.py in __init__(self, params, lr, betas, eps, weight_decay, amsgrad, foreach, maximize, capturable, differentiable, fused)
#      97             fused=fused,
#      98         )
# ---> 99         super().__init__(params, defaults)
#     100
#     101         if fused:
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py in __init__(self, params, defaults)
#     375
#     376         for param_group in param_groups:
# --> 377             self.add_param_group(cast(dict, param_group))
#     378
#     379         # Allows _cuda_graph_capture_health_check to rig a poor man's TORCH_WARN_ONCE in python,
#
# /usr/local/lib/python3.11/dist-packages/torch/_compile.py in inner(*args, **kwargs)
#      25             disable_fn = getattr(fn, "__dynamo_disable", None)
#      26             if disable_fn is None:
# ---> 27                 import torch._dynamo
#      28
#      29                 disable_fn = torch._dynamo.disable(fn, recursive)
#
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/__init__.py in <module>
#       1 import torch
#       2
# ----> 3 from . import convert_frame, eval_frame, resume_execution
#       4 from .backends.registry import list_backends, lookup_backend, register_backend
#       5 from .callback import callback_handler, on_compile_end, on_compile_start
#
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py in <module>
#      31 from torch._C._dynamo.guards import GlobalStateGuard
#      32 from torch._dynamo.distributed import get_compile_pg
# ---> 33 from torch._dynamo.symbolic_convert import TensorifyState
#      34 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      35 from torch._logging import structured
#
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py in <module>
#      28 from torch._guards import tracing, TracingContext
#      29
# ---> 30 from . import config, exc, logging as torchdynamo_logging, trace_rules, variables
#      31 from .bytecode_analysis import (
#      32     get_indexof,
#
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/trace_rules.py in <module>
#      44 from .resume_execution import TORCH_DYNAMO_RESUME_IN_PREFIX
#      45 from .utils import getfile, hashable, NP_SUPPORTED_MODULES, unwrap_if_wrapper
# ---> 46 from .variables import (
#      47     BuiltinVariable,
#      48     FunctionalCallVariable,
#
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/__init__.py in <module>
#     107     UntypedStorageVariable,
#     108 )
# --> 109 from .torch import TorchCtxManagerClassVariable, TorchInGraphFunctionVariable
#     110 from .user_defined import (
#     111     MutableMappingVariable,
#
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/torch.py in <module>
#     143     torch._C._get_tracing_state: None,
#     144     torch.fx._symbolic_trace.is_fx_tracing: False,
# --> 145     torch.onnx.is_in_onnx_export: False,
#     146     torch._dynamo.external_utils.is_compiling: True,
#     147     torch._utils.is_compiling: True,
#
# /usr/local/lib/python3.11/dist-packages/torch/__init__.py in __getattr__(name)
#    2677         # Lazy modules
#    2678         if name in _lazy_modules:
# -> 2679             return importlib.import_module(f".{name}", __name__)
#    2680
#    2681         raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/local/lib/python3.11/dist-packages/torch/onnx/__init__.py in <module>
#      65 from ._type_utils import JitScalarType
#      66 from .errors import OnnxExporterError
# ---> 67 from .utils import (
#      68     _run_symbolic_function,
#      69     _run_symbolic_method,
#
# /usr/local/lib/python3.11/dist-packages/torch/onnx/utils.py in <module>
#      23 from torch.onnx import _constants, _deprecation, errors, symbolic_helper  # noqa: F401
#      24 from torch.onnx._globals import GLOBALS
# ---> 25 from torch.onnx._internal import diagnostics, jit_utils, onnx_proto_utils, registration
#      26
#      27
#
# /usr/local/lib/python3.11/dist-packages/torch/onnx/_internal/diagnostics/__init__.py in <module>
# ----> 1 from ._diagnostic import (
#       2     create_export_diagnostic_context,
#       3     diagnose,
#       4     engine,
#       5     export_context,
#
# /usr/local/lib/python3.11/dist-packages/torch/onnx/_internal/diagnostics/_diagnostic.py in <module>
#       9
#      10 import torch
# ---> 11 from torch.onnx._internal.diagnostics import infra
#      12 from torch.onnx._internal.diagnostics.infra import formatter, sarif
#      13 from torch.onnx._internal.diagnostics.infra.sarif import version as sarif_version
#
# /usr/local/lib/python3.11/dist-packages/torch/onnx/_internal/diagnostics/infra/__init__.py in <module>
# ----> 1 from ._infra import (
#       2     DiagnosticOptions,
#       3     Graph,
#       4     Invocation,
#       5     Level,
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %%
import joblib

vae_model = VAE(input_dim=80, latent_dim= 25)  # 用与你训练时相同的参数初始化
vae_model.load_state_dict(torch.load("vae_weights.pt", map_location=torch.device('cpu')))
vae_model.eval()
normalizer = joblib.load("normalizer.pkl")

ica = joblib.load("ica_model1.pkl")
pca = joblib.load("pca_model1.pkl")
normalizer1 = joblib.load("normalizer1.pkl")

# %%
print("scaler.min_.shape:", normalizer.min_.shape)
print("scaler.data_min_.shape:", normalizer.data_min_.shape)
print("scaler.feature_range:", normalizer.feature_range)
# Out:
# scaler.min_.shape: (25,)
# scaler.data_min_.shape: (25,)
# scaler.feature_range: (-1, 1)

# %%
plot_tsne_vae_vs_sar(
    muscle_data=muscle_data,
    vae_model=vae_model,
    pca=pca,
    ica=ica,
    vae_normalizer=normalizer,
    sar_normalizer=normalizer1,
    n_samples=3000
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-25521f513be3> in <cell line: 0>()
# ----> 1 plot_tsne_vae_vs_sar(
#       2     muscle_data=muscle_data,
#       3     vae_model=vae_model,
#       4     pca=pca,
#       5     ica=ica,
#
# <ipython-input-21-0bb700998572> in plot_tsne_vae_vs_sar(muscle_data, vae_model, pca, ica, vae_normalizer, sar_normalizer, n_samples)
#      25
#      26     # ========== VAE latent ==========
# ---> 27     norm_data_vae = vae_normalizer.transform(muscle_data_sampled)
#      28     X_tensor = torch.tensor(norm_data_vae, dtype=torch.float32).to(next(vae_model.parameters()).device)
#      29
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_data.py in transform(self, X)
#     530         xp, _ = get_namespace(X)
#     531
# --> 532         X = validate_data(
#     533             self,
#     534             X,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2963
#    2964     if not no_val_X and check_params.get("ensure_2d", True):
# -> 2965         _check_n_features(_estimator, X, reset=reset)
#    2966
#    2967     return out
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in _check_n_features(estimator, X, reset)
#    2827
#    2828     if n_features != estimator.n_features_in_:
# -> 2829         raise ValueError(
#    2830             f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2831             f"is expecting {estimator.n_features_in_} features as input."
#
# ValueError: X has 80 features, but MinMaxScaler is expecting 25 features as input.

# %%
# 遍历所有 latent 维度两两组合，最多画 10 张图，观察 decoder 输出第0个肌肉响应
visualize_all_latent_combinations(
    vae_model=vae_model,
    latent_dim=25,
    muscle_index=0,
    grid_size=30,
    mode='muscle',
    max_plots=None  # 可改为 None 查看全部 300 张
)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# ...
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-2f32d658fcf7> in <cell line: 0>()
#       1 # 遍历所有 latent 维度两两组合，最多画 10 张图，观察 decoder 输出第0个肌肉响应
# ----> 2 visualize_all_latent_combinations(
#       3     vae_model=vae_model,
#       4     latent_dim=25,
#       5     muscle_index=0,
#
# <ipython-input-61-5b14f2ea9188> in visualize_all_latent_combinations(vae_model, latent_dim, muscle_index, grid_size, grid_range, mode, max_plots)
#      52         plt.grid(True)
#      53         plt.tight_layout()
# ---> 54         plt.show()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     612     """
#     613     _warn_if_gui_out_of_main_thread()
# --> 614     return _get_backend_mod().show(*args, **kwargs)
#     615
#     616
#
# /usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2153                 # so that we can inject the orientation
#    2154                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2155                     self.figure.draw(renderer)
#    2156             if bbox_inches:
#    2157                 if bbox_inches == "tight":
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      92     @wraps(draw)
#      93     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94         result = draw(artist, renderer, *args, **kwargs)
#      95         if renderer._rasterizing:
#      96             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3255
#    3256                 self.patch.draw(renderer)
# -> 3257                 mimage._draw_list_compositing_images(
#    3258                     renderer, self, artists, self.suppressComposite)
#    3259
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3143                 artists.remove(spine)
#    3144
# -> 3145         self._update_title_position(renderer)
#    3146
#    3147         if not self.axison:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    3087             if title.get_text():
#    3088                 for ax in axs:
# -> 3089                     ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3090                     if ax.yaxis.offsetText.get_text():
#    3091                         bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1365
#    1366         # go back to just this axis's tick labels
# -> 1367         tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1368
#    1369         self._update_offset_text_position(tlb1, tlb2)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in _get_ticklabel_bboxes(self, ticks, renderer)
#    1341         if renderer is None:
#    1342             renderer = self.get_figure(root=True)._get_renderer()
# -> 1343         return ([tick.label1.get_window_extent(renderer)
#    1344                  for tick in ticks if tick.label1.get_visible()],
#    1345                 [tick.label2.get_window_extent(renderer)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in <listcomp>(.0)
#    1341         if renderer is None:
#    1342             renderer = self.get_figure(root=True)._get_renderer()
# -> 1343         return ([tick.label1.get_window_extent(renderer)
#    1344                  for tick in ticks if tick.label1.get_visible()],
#    1345                 [tick.label2.get_window_extent(renderer)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     949             return Bbox.unit()
#     950
# --> 951         fig = self.get_figure(root=True)
#     952         if dpi is None:
#     953             dpi = fig.dpi
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in get_figure(self, root)
#     721         return self._path_effects
#     722
# --> 723     def get_figure(self, root=False):
#     724         """
#     725         Return the `.Figure` or `.SubFigure` instance the artist belongs to.
#
# KeyboardInterrupt:

# %%
ica,pca,normalizer = compute_SAR(muscle_data, 25, save=False)

# %%
import joblib

joblib.dump(ica, "ica_model1.pkl")
joblib.dump(pca, "pca_model1.pkl")
joblib.dump(normalizer, "normalizer1.pkl")
# Out:
# ['normalizer1.pkl']

# %% [markdown]
# ## Option 1.1.B: Use precomputed SAR

# %%
ica,pca,normalizer = load_locomotion_SAR()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator FastICA from version 1.1.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator PCA from version 1.1.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# # Step 1.2: Train on unseen terrain with synergies (SAR-RL)

# %%
# randomly choose terrain to learn, or manually choose one
#new_terrain = np.random.choice(['Hilly', 'Stair', 'Rough'])
new_terrain = 'Stair'
print(f'myoLeg{new_terrain}TerrainWalk-v0 selected for training.')
# Out:
# myoLegStairTerrainWalk-v0 selected for training.

# %%
print("type of encoder:", type(encoder))
print("type of decoder:", type(decoder))
print("type of normalizer:", type(normalizer))
# Out:
# type of encoder: <class 'function'>
# type of decoder: <class 'function'>
# type of normalizer: <class 'sklearn.preprocessing._data.MinMaxScaler'>

# %%
pip show torch
# Out:
# Name: torch
# Version: 2.6.0
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: filelock, fsspec, jinja2, networkx, nvidia-cublas-cu12, nvidia-cuda-cupti-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-runtime-cu12, nvidia-cudnn-cu12, nvidia-cufft-cu12, nvidia-curand-cu12, nvidia-cusolver-cu12, nvidia-cusparse-cu12, nvidia-cusparselt-cu12, nvidia-nccl-cu12, nvidia-nvjitlink-cu12, nvidia-nvtx-cu12, sympy, triton, typing-extensions
# Required-by: accelerate, fastai, peft, sentence-transformers, stable_baselines3, timm, torchaudio, torchvision

# %%
VAE_RL(env_name=f'myoLeg{new_terrain}TerrainWalk-v0',
       policy_name='vae_policy',
       timesteps=1e6,
       seed='0',
       vae=vae_model,
       normalizer=normalizer)
# Out:
#     MyoSuite: A contact-rich simulation suite for musculoskeletal motor control
#         Vittorio Caggiano, Huawei Wang, Guillaume Durandau, Massimo Sartori, Vikash Kumar
#         L4DC-2019 | https://sites.google.com/view/myosuite
# /usr/local/lib/python3.11/dist-packages/glfw/__init__.py:917: GLFWError: (65550) b'X11: The DISPLAY environment variable is missing'
#   warnings.warn(message, GLFWError)
# 流式输出内容被截断，只能显示最后 5000 行内容。
# |    n_updates       | 696945   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 202      |
# |    ep_rew_mean     | 2.31e+03 |
# | time/              |          |
# |    episodes        | 5484     |
# |    fps             | 62       |
# |    time_elapsed    | 11187    |
# |    total_timesteps | 702977   |
# | train/             |          |
# |    actor_loss      | -362     |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.0416   |
# |    ent_coef_loss   | 0.235    |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 697792   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 202      |
# |    ep_rew_mean     | 2.31e+03 |
# | time/              |          |
# |    episodes        | 5488     |
# |    fps             | 62       |
# |    time_elapsed    | 11200    |
# |    total_timesteps | 703793   |
# | train/             |          |
# |    actor_loss      | -361     |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0416   |
# |    ent_coef_loss   | -0.168   |
# |    learning_rate   | 0.000296 |
# |    n_updates       | 698619   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 202      |
# |    ep_rew_mean     | 2.31e+03 |
# | time/              |          |
# |    episodes        | 5492     |
# |    fps             | 62       |
# |    time_elapsed    | 11213    |
# |    total_timesteps | 704610   |
# | train/             |          |
# |    actor_loss      | -362     |
# |    critic_loss     | 13.4     |
# |    ent_coef        | 0.0412   |
# |    ent_coef_loss   | 0.394    |
# |    learning_rate   | 0.000296 |
# |    n_updates       | 699457   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 202      |
# |    ep_rew_mean     | 2.31e+03 |
# | time/              |          |
# |    episodes        | 5496     |
# |    fps             | 62       |
# |    time_elapsed    | 11226    |
# |    total_timesteps | 705421   |
# | train/             |          |
# |    actor_loss      | -363     |
# |    critic_loss     | 13.5     |
# |    ent_coef        | 0.042    |
# |    ent_coef_loss   | -0.569   |
# |    learning_rate   | 0.000295 |
# |    n_updates       | 700217   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 203      |
# |    ep_rew_mean     | 2.31e+03 |
# | time/              |          |
# |    episodes        | 5500     |
# |    fps             | 62       |
# |    time_elapsed    | 11239    |
# |    total_timesteps | 706272   |
# | train/             |          |
# |    actor_loss      | -363     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.0413   |
# |    ent_coef_loss   | 0.66     |
# |    learning_rate   | 0.000294 |
# |    n_updates       | 701062   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 2.32e+03 |
# | time/              |          |
# |    episodes        | 5504     |
# |    fps             | 62       |
# |    time_elapsed    | 11253    |
# |    total_timesteps | 707176   |
# | train/             |          |
# |    actor_loss      | -363     |
# |    critic_loss     | 13.5     |
# |    ent_coef        | 0.0415   |
# |    ent_coef_loss   | -0.0524  |
# |    learning_rate   | 0.000293 |
# |    n_updates       | 701934   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 2.32e+03 |
# | time/              |          |
# |    episodes        | 5508     |
# |    fps             | 62       |
# |    time_elapsed    | 11267    |
# |    total_timesteps | 708007   |
# | train/             |          |
# |    actor_loss      | -365     |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.041    |
# |    ent_coef_loss   | 0.482    |
# |    learning_rate   | 0.000292 |
# |    n_updates       | 702807   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 2.33e+03 |
# | time/              |          |
# |    episodes        | 5512     |
# |    fps             | 62       |
# |    time_elapsed    | 11281    |
# |    total_timesteps | 708855   |
# | train/             |          |
# |    actor_loss      | -363     |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0414   |
# |    ent_coef_loss   | -0.213   |
# |    learning_rate   | 0.000291 |
# |    n_updates       | 703652   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.34e+03 |
# | time/              |          |
# |    episodes        | 5516     |
# |    fps             | 62       |
# |    time_elapsed    | 11295    |
# |    total_timesteps | 709692   |
# | train/             |          |
# |    actor_loss      | -365     |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.0417   |
# |    ent_coef_loss   | 0.0399   |
# |    learning_rate   | 0.00029  |
# |    n_updates       | 704541   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | 2.33e+03 |
# | time/              |          |
# |    episodes        | 5520     |
# |    fps             | 62       |
# |    time_elapsed    | 11307    |
# |    total_timesteps | 710445   |
# | train/             |          |
# |    actor_loss      | -363     |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0416   |
# |    ent_coef_loss   | 0.169    |
# |    learning_rate   | 0.00029  |
# |    n_updates       | 705284   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 2.32e+03 |
# | time/              |          |
# |    episodes        | 5524     |
# |    fps             | 62       |
# |    time_elapsed    | 11319    |
# |    total_timesteps | 711212   |
# | train/             |          |
# |    actor_loss      | -364     |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.0414   |
# |    ent_coef_loss   | -0.201   |
# |    learning_rate   | 0.000289 |
# |    n_updates       | 706059   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | 2.33e+03 |
# | time/              |          |
# |    episodes        | 5528     |
# |    fps             | 62       |
# |    time_elapsed    | 11333    |
# |    total_timesteps | 712138   |
# | train/             |          |
# |    actor_loss      | -362     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.0415   |
# |    ent_coef_loss   | 0.445    |
# |    learning_rate   | 0.000288 |
# |    n_updates       | 706931   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.34e+03 |
# | time/              |          |
# |    episodes        | 5532     |
# |    fps             | 62       |
# |    time_elapsed    | 11348    |
# |    total_timesteps | 713044   |
# | train/             |          |
# |    actor_loss      | -363     |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0417   |
# |    ent_coef_loss   | -0.473   |
# |    learning_rate   | 0.000287 |
# |    n_updates       | 707856   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.34e+03 |
# | time/              |          |
# |    episodes        | 5536     |
# |    fps             | 62       |
# |    time_elapsed    | 11362    |
# |    total_timesteps | 713899   |
# | train/             |          |
# |    actor_loss      | -363     |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.0409   |
# |    ent_coef_loss   | -0.459   |
# |    learning_rate   | 0.000286 |
# |    n_updates       | 708740   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.35e+03 |
# | time/              |          |
# |    episodes        | 5540     |
# |    fps             | 62       |
# |    time_elapsed    | 11373    |
# |    total_timesteps | 714641   |
# | train/             |          |
# |    actor_loss      | -363     |
# |    critic_loss     | 13.4     |
# |    ent_coef        | 0.0409   |
# |    ent_coef_loss   | 0.394    |
# |    learning_rate   | 0.000286 |
# |    n_updates       | 709451   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | 2.36e+03 |
# | time/              |          |
# |    episodes        | 5544     |
# |    fps             | 62       |
# |    time_elapsed    | 11386    |
# |    total_timesteps | 715453   |
# | train/             |          |
# |    actor_loss      | -366     |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.041    |
# |    ent_coef_loss   | 0.486    |
# |    learning_rate   | 0.000285 |
# |    n_updates       | 710293   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | 2.36e+03 |
# | time/              |          |
# |    episodes        | 5548     |
# |    fps             | 62       |
# |    time_elapsed    | 11399    |
# |    total_timesteps | 716254   |
# | train/             |          |
# |    actor_loss      | -365     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.0411   |
# |    ent_coef_loss   | -0.483   |
# |    learning_rate   | 0.000284 |
# |    n_updates       | 711080   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | 2.36e+03 |
# | time/              |          |
# |    episodes        | 5552     |
# |    fps             | 62       |
# |    time_elapsed    | 11412    |
# |    total_timesteps | 717034   |
# | train/             |          |
# |    actor_loss      | -365     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.0411   |
# |    ent_coef_loss   | 0.193    |
# |    learning_rate   | 0.000283 |
# |    n_updates       | 711906   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.37e+03 |
# | time/              |          |
# |    episodes        | 5556     |
# |    fps             | 62       |
# |    time_elapsed    | 11425    |
# |    total_timesteps | 717915   |
# | train/             |          |
# |    actor_loss      | -364     |
# |    critic_loss     | 13.4     |
# |    ent_coef        | 0.0411   |
# |    ent_coef_loss   | -0.0986  |
# |    learning_rate   | 0.000282 |
# |    n_updates       | 712725   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.36e+03 |
# | time/              |          |
# |    episodes        | 5560     |
# |    fps             | 62       |
# |    time_elapsed    | 11439    |
# |    total_timesteps | 718784   |
# | train/             |          |
# |    actor_loss      | -364     |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | -0.853   |
# |    learning_rate   | 0.000281 |
# |    n_updates       | 713612   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 208      |
# |    ep_rew_mean     | 2.37e+03 |
# | time/              |          |
# |    episodes        | 5564     |
# |    fps             | 62       |
# |    time_elapsed    | 11452    |
# |    total_timesteps | 719575   |
# | train/             |          |
# |    actor_loss      | -365     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.0408   |
# |    ent_coef_loss   | 0.0491   |
# |    learning_rate   | 0.000281 |
# |    n_updates       | 714433   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.36e+03 |
# | time/              |          |
# |    episodes        | 5568     |
# |    fps             | 62       |
# |    time_elapsed    | 11464    |
# |    total_timesteps | 720309   |
# | train/             |          |
# |    actor_loss      | -363     |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.0412   |
# |    ent_coef_loss   | -0.59    |
# |    learning_rate   | 0.00028  |
# |    n_updates       | 715147   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 2.34e+03 |
# | time/              |          |
# |    episodes        | 5572     |
# |    fps             | 62       |
# |    time_elapsed    | 11474    |
# |    total_timesteps | 720960   |
# | train/             |          |
# |    actor_loss      | -364     |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0404   |
# |    ent_coef_loss   | -1.2     |
# |    learning_rate   | 0.000279 |
# |    n_updates       | 715792   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 2.34e+03 |
# | time/              |          |
# |    episodes        | 5576     |
# |    fps             | 62       |
# |    time_elapsed    | 11487    |
# |    total_timesteps | 721756   |
# | train/             |          |
# |    actor_loss      | -366     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | 0.00467  |
# |    learning_rate   | 0.000278 |
# |    n_updates       | 716571   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | 2.34e+03 |
# | time/              |          |
# |    episodes        | 5580     |
# |    fps             | 62       |
# |    time_elapsed    | 11500    |
# |    total_timesteps | 722548   |
# | train/             |          |
# |    actor_loss      | -366     |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.0405   |
# |    ent_coef_loss   | -0.223   |
# |    learning_rate   | 0.000278 |
# |    n_updates       | 717399   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | 2.34e+03 |
# | time/              |          |
# |    episodes        | 5584     |
# |    fps             | 62       |
# |    time_elapsed    | 11512    |
# |    total_timesteps | 723361   |
# | train/             |          |
# |    actor_loss      | -367     |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | 0.366    |
# |    learning_rate   | 0.000277 |
# |    n_updates       | 718190   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | 2.35e+03 |
# | time/              |          |
# |    episodes        | 5588     |
# |    fps             | 62       |
# |    time_elapsed    | 11526    |
# |    total_timesteps | 724238   |
# | train/             |          |
# |    actor_loss      | -368     |
# |    critic_loss     | 13.3     |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | -0.126   |
# |    learning_rate   | 0.000276 |
# |    n_updates       | 719021   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 2.36e+03 |
# | time/              |          |
# |    episodes        | 5592     |
# |    fps             | 62       |
# |    time_elapsed    | 11540    |
# |    total_timesteps | 725120   |
# | train/             |          |
# |    actor_loss      | -367     |
# |    critic_loss     | 13.4     |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | 0.118    |
# |    learning_rate   | 0.000275 |
# |    n_updates       | 719930   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 2.35e+03 |
# | time/              |          |
# |    episodes        | 5596     |
# |    fps             | 62       |
# |    time_elapsed    | 11553    |
# |    total_timesteps | 725917   |
# | train/             |          |
# |    actor_loss      | -368     |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | 0.442    |
# |    learning_rate   | 0.000274 |
# |    n_updates       | 720756   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | 2.35e+03 |
# | time/              |          |
# |    episodes        | 5600     |
# |    fps             | 62       |
# |    time_elapsed    | 11566    |
# |    total_timesteps | 726712   |
# | train/             |          |
# |    actor_loss      | -368     |
# |    critic_loss     | 13.4     |
# |    ent_coef        | 0.0412   |
# |    ent_coef_loss   | -0.573   |
# |    learning_rate   | 0.000273 |
# |    n_updates       | 721546   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | 2.35e+03 |
# | time/              |          |
# |    episodes        | 5604     |
# |    fps             | 62       |
# |    time_elapsed    | 11580    |
# |    total_timesteps | 727570   |
# | train/             |          |
# |    actor_loss      | -368     |
# |    critic_loss     | 13.2     |
# |    ent_coef        | 0.0405   |
# |    ent_coef_loss   | 0.0973   |
# |    learning_rate   | 0.000273 |
# |    n_updates       | 722423   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | 2.35e+03 |
# | time/              |          |
# |    episodes        | 5608     |
# |    fps             | 62       |
# |    time_elapsed    | 11592    |
# |    total_timesteps | 728381   |
# | train/             |          |
# |    actor_loss      | -369     |
# |    critic_loss     | 13.4     |
# |    ent_coef        | 0.0407   |
# |    ent_coef_loss   | -0.145   |
# |    learning_rate   | 0.000272 |
# |    n_updates       | 723183   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 203      |
# |    ep_rew_mean     | 2.35e+03 |
# | time/              |          |
# |    episodes        | 5612     |
# |    fps             | 62       |
# |    time_elapsed    | 11606    |
# |    total_timesteps | 729193   |
# | train/             |          |
# |    actor_loss      | -366     |
# |    critic_loss     | 13.2     |
# |    ent_coef        | 0.0399   |
# |    ent_coef_loss   | 0.0568   |
# |    learning_rate   | 0.000271 |
# |    n_updates       | 724027   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | 2.36e+03 |
# | time/              |          |
# |    episodes        | 5616     |
# |    fps             | 62       |
# |    time_elapsed    | 11622    |
# |    total_timesteps | 730253   |
# | train/             |          |
# |    actor_loss      | -369     |
# |    critic_loss     | 13.5     |
# |    ent_coef        | 0.0407   |
# |    ent_coef_loss   | 0.104    |
# |    learning_rate   | 0.00027  |
# |    n_updates       | 725083   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.37e+03 |
# | time/              |          |
# |    episodes        | 5620     |
# |    fps             | 62       |
# |    time_elapsed    | 11636    |
# |    total_timesteps | 731145   |
# | train/             |          |
# |    actor_loss      | -369     |
# |    critic_loss     | 13.4     |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | -0.0641  |
# |    learning_rate   | 0.000269 |
# |    n_updates       | 725900   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.37e+03 |
# | time/              |          |
# |    episodes        | 5624     |
# |    fps             | 62       |
# |    time_elapsed    | 11649    |
# |    total_timesteps | 731938   |
# | train/             |          |
# |    actor_loss      | -367     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | 0.145    |
# |    learning_rate   | 0.000268 |
# |    n_updates       | 726749   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 208      |
# |    ep_rew_mean     | 2.38e+03 |
# | time/              |          |
# |    episodes        | 5628     |
# |    fps             | 62       |
# |    time_elapsed    | 11665    |
# |    total_timesteps | 732922   |
# | train/             |          |
# |    actor_loss      | -367     |
# |    critic_loss     | 13.5     |
# |    ent_coef        | 0.0413   |
# |    ent_coef_loss   | 0.0906   |
# |    learning_rate   | 0.000267 |
# |    n_updates       | 727711   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.38e+03 |
# | time/              |          |
# |    episodes        | 5632     |
# |    fps             | 62       |
# |    time_elapsed    | 11679    |
# |    total_timesteps | 733786   |
# | train/             |          |
# |    actor_loss      | -367     |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.0404   |
# |    ent_coef_loss   | -0.196   |
# |    learning_rate   | 0.000266 |
# |    n_updates       | 728603   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.37e+03 |
# | time/              |          |
# |    episodes        | 5636     |
# |    fps             | 62       |
# |    time_elapsed    | 11692    |
# |    total_timesteps | 734622   |
# | train/             |          |
# |    actor_loss      | -367     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.0407   |
# |    ent_coef_loss   | -0.711   |
# |    learning_rate   | 0.000266 |
# |    n_updates       | 729378   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 209      |
# |    ep_rew_mean     | 2.38e+03 |
# | time/              |          |
# |    episodes        | 5640     |
# |    fps             | 62       |
# |    time_elapsed    | 11707    |
# |    total_timesteps | 735523   |
# | train/             |          |
# |    actor_loss      | -368     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.0413   |
# |    ent_coef_loss   | 0.351    |
# |    learning_rate   | 0.000265 |
# |    n_updates       | 730324   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | 2.39e+03 |
# | time/              |          |
# |    episodes        | 5644     |
# |    fps             | 62       |
# |    time_elapsed    | 11721    |
# |    total_timesteps | 736433   |
# | train/             |          |
# |    actor_loss      | -368     |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | -0.234   |
# |    learning_rate   | 0.000264 |
# |    n_updates       | 731224   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 2.4e+03  |
# | time/              |          |
# |    episodes        | 5648     |
# |    fps             | 62       |
# |    time_elapsed    | 11735    |
# |    total_timesteps | 737314   |
# | train/             |          |
# |    actor_loss      | -369     |
# |    critic_loss     | 13.4     |
# |    ent_coef        | 0.0408   |
# |    ent_coef_loss   | 0.131    |
# |    learning_rate   | 0.000263 |
# |    n_updates       | 732120   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | 2.41e+03 |
# | time/              |          |
# |    episodes        | 5652     |
# |    fps             | 62       |
# |    time_elapsed    | 11750    |
# |    total_timesteps | 738251   |
# | train/             |          |
# |    actor_loss      | -367     |
# |    critic_loss     | 14.1     |
# |    ent_coef        | 0.0411   |
# |    ent_coef_loss   | 0.225    |
# |    learning_rate   | 0.000262 |
# |    n_updates       | 733030   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 2.4e+03  |
# | time/              |          |
# |    episodes        | 5656     |
# |    fps             | 62       |
# |    time_elapsed    | 11764    |
# |    total_timesteps | 739011   |
# | train/             |          |
# |    actor_loss      | -368     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.0411   |
# |    ent_coef_loss   | 0.0509   |
# |    learning_rate   | 0.000261 |
# |    n_updates       | 733929   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.35e+03 |
# | time/              |          |
# |    episodes        | 5660     |
# |    fps             | 62       |
# |    time_elapsed    | 11772    |
# |    total_timesteps | 739479   |
# | train/             |          |
# |    actor_loss      | -370     |
# |    critic_loss     | 15       |
# |    ent_coef        | 0.0423   |
# |    ent_coef_loss   | 1.11     |
# |    learning_rate   | 0.000261 |
# |    n_updates       | 734397   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 203      |
# |    ep_rew_mean     | 2.28e+03 |
# | time/              |          |
# |    episodes        | 5664     |
# |    fps             | 62       |
# |    time_elapsed    | 11778    |
# |    total_timesteps | 739890   |
# | train/             |          |
# |    actor_loss      | -367     |
# |    critic_loss     | 16.3     |
# |    ent_coef        | 0.0424   |
# |    ent_coef_loss   | -0.978   |
# |    learning_rate   | 0.00026  |
# |    n_updates       | 734817   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 203      |
# |    ep_rew_mean     | 2.27e+03 |
# | time/              |          |
# |    episodes        | 5668     |
# |    fps             | 62       |
# |    time_elapsed    | 11789    |
# |    total_timesteps | 740584   |
# | train/             |          |
# |    actor_loss      | -367     |
# |    critic_loss     | 16       |
# |    ent_coef        | 0.0419   |
# |    ent_coef_loss   | -0.283   |
# |    learning_rate   | 0.00026  |
# |    n_updates       | 735441   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 2.29e+03 |
# | time/              |          |
# |    episodes        | 5672     |
# |    fps             | 62       |
# |    time_elapsed    | 11802    |
# |    total_timesteps | 741430   |
# | train/             |          |
# |    actor_loss      | -369     |
# |    critic_loss     | 15.4     |
# |    ent_coef        | 0.0416   |
# |    ent_coef_loss   | 0.04     |
# |    learning_rate   | 0.000259 |
# |    n_updates       | 736261   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 2.29e+03 |
# | time/              |          |
# |    episodes        | 5676     |
# |    fps             | 62       |
# |    time_elapsed    | 11815    |
# |    total_timesteps | 742281   |
# | train/             |          |
# |    actor_loss      | -366     |
# |    critic_loss     | 15.4     |
# |    ent_coef        | 0.0416   |
# |    ent_coef_loss   | -0.0568  |
# |    learning_rate   | 0.000258 |
# |    n_updates       | 737098   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | 2.3e+03  |
# | time/              |          |
# |    episodes        | 5680     |
# |    fps             | 62       |
# |    time_elapsed    | 11830    |
# |    total_timesteps | 743175   |
# | train/             |          |
# |    actor_loss      | -367     |
# |    critic_loss     | 15.2     |
# |    ent_coef        | 0.0407   |
# |    ent_coef_loss   | 0.201    |
# |    learning_rate   | 0.000257 |
# |    n_updates       | 738058   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.3e+03  |
# | time/              |          |
# |    episodes        | 5684     |
# |    fps             | 62       |
# |    time_elapsed    | 11844    |
# |    total_timesteps | 744045   |
# | train/             |          |
# |    actor_loss      | -368     |
# |    critic_loss     | 15.1     |
# |    ent_coef        | 0.0411   |
# |    ent_coef_loss   | -0.22    |
# |    learning_rate   | 0.000256 |
# |    n_updates       | 738889   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.3e+03  |
# | time/              |          |
# |    episodes        | 5688     |
# |    fps             | 62       |
# |    time_elapsed    | 11857    |
# |    total_timesteps | 744892   |
# | train/             |          |
# |    actor_loss      | -367     |
# |    critic_loss     | 14.8     |
# |    ent_coef        | 0.0408   |
# |    ent_coef_loss   | -0.17    |
# |    learning_rate   | 0.000255 |
# |    n_updates       | 739686   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | 2.29e+03 |
# | time/              |          |
# |    episodes        | 5692     |
# |    fps             | 62       |
# |    time_elapsed    | 11871    |
# |    total_timesteps | 745743   |
# | train/             |          |
# |    actor_loss      | -368     |
# |    critic_loss     | 14.7     |
# |    ent_coef        | 0.0409   |
# |    ent_coef_loss   | 0.29     |
# |    learning_rate   | 0.000254 |
# |    n_updates       | 740591   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.3e+03  |
# | time/              |          |
# |    episodes        | 5696     |
# |    fps             | 62       |
# |    time_elapsed    | 11885    |
# |    total_timesteps | 746605   |
# | train/             |          |
# |    actor_loss      | -369     |
# |    critic_loss     | 15.1     |
# |    ent_coef        | 0.0416   |
# |    ent_coef_loss   | 0.123    |
# |    learning_rate   | 0.000254 |
# |    n_updates       | 741441   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.3e+03  |
# | time/              |          |
# |    episodes        | 5700     |
# |    fps             | 62       |
# |    time_elapsed    | 11897    |
# |    total_timesteps | 747366   |
# | train/             |          |
# |    actor_loss      | -369     |
# |    critic_loss     | 14.7     |
# |    ent_coef        | 0.0412   |
# |    ent_coef_loss   | -0.12    |
# |    learning_rate   | 0.000253 |
# |    n_updates       | 742178   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.31e+03 |
# | time/              |          |
# |    episodes        | 5704     |
# |    fps             | 62       |
# |    time_elapsed    | 11912    |
# |    total_timesteps | 748269   |
# | train/             |          |
# |    actor_loss      | -370     |
# |    critic_loss     | 14.7     |
# |    ent_coef        | 0.0407   |
# |    ent_coef_loss   | 0.128    |
# |    learning_rate   | 0.000252 |
# |    n_updates       | 743090   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.3e+03  |
# | time/              |          |
# |    episodes        | 5708     |
# |    fps             | 62       |
# |    time_elapsed    | 11925    |
# |    total_timesteps | 749035   |
# | train/             |          |
# |    actor_loss      | -369     |
# |    critic_loss     | 14.5     |
# |    ent_coef        | 0.041    |
# |    ent_coef_loss   | -0.304   |
# |    learning_rate   | 0.000251 |
# |    n_updates       | 743911   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.31e+03 |
# | time/              |          |
# |    episodes        | 5712     |
# |    fps             | 62       |
# |    time_elapsed    | 11938    |
# |    total_timesteps | 749863   |
# | train/             |          |
# |    actor_loss      | -369     |
# |    critic_loss     | 14.5     |
# |    ent_coef        | 0.0411   |
# |    ent_coef_loss   | -0.024   |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 744708   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 2.3e+03  |
# | time/              |          |
# |    episodes        | 5716     |
# |    fps             | 62       |
# |    time_elapsed    | 11951    |
# |    total_timesteps | 750708   |
# | train/             |          |
# |    actor_loss      | -370     |
# |    critic_loss     | 14.6     |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | 0.0395   |
# |    learning_rate   | 0.000249 |
# |    n_updates       | 745542   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | 2.3e+03  |
# | time/              |          |
# |    episodes        | 5720     |
# |    fps             | 62       |
# |    time_elapsed    | 11965    |
# |    total_timesteps | 751588   |
# | train/             |          |
# |    actor_loss      | -370     |
# |    critic_loss     | 14.4     |
# |    ent_coef        | 0.041    |
# |    ent_coef_loss   | -0.0294  |
# |    learning_rate   | 0.000249 |
# |    n_updates       | 746361   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.32e+03 |
# | time/              |          |
# |    episodes        | 5724     |
# |    fps             | 62       |
# |    time_elapsed    | 11981    |
# |    total_timesteps | 752600   |
# | train/             |          |
# |    actor_loss      | -370     |
# |    critic_loss     | 14.7     |
# |    ent_coef        | 0.0411   |
# |    ent_coef_loss   | -0.161   |
# |    learning_rate   | 0.000248 |
# |    n_updates       | 747385   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.31e+03 |
# | time/              |          |
# |    episodes        | 5728     |
# |    fps             | 62       |
# |    time_elapsed    | 11997    |
# |    total_timesteps | 753578   |
# | train/             |          |
# |    actor_loss      | -369     |
# |    critic_loss     | 14.7     |
# |    ent_coef        | 0.0418   |
# |    ent_coef_loss   | -0.128   |
# |    learning_rate   | 0.000247 |
# |    n_updates       | 748388   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.32e+03 |
# | time/              |          |
# |    episodes        | 5732     |
# |    fps             | 62       |
# |    time_elapsed    | 12012    |
# |    total_timesteps | 754479   |
# | train/             |          |
# |    actor_loss      | -369     |
# |    critic_loss     | 14.9     |
# |    ent_coef        | 0.0417   |
# |    ent_coef_loss   | -0.289   |
# |    learning_rate   | 0.000246 |
# |    n_updates       | 749283   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.33e+03 |
# | time/              |          |
# |    episodes        | 5736     |
# |    fps             | 62       |
# |    time_elapsed    | 12025    |
# |    total_timesteps | 755310   |
# | train/             |          |
# |    actor_loss      | -370     |
# |    critic_loss     | 14.7     |
# |    ent_coef        | 0.0414   |
# |    ent_coef_loss   | -0.0261  |
# |    learning_rate   | 0.000245 |
# |    n_updates       | 750095   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | 2.32e+03 |
# | time/              |          |
# |    episodes        | 5740     |
# |    fps             | 62       |
# |    time_elapsed    | 12039    |
# |    total_timesteps | 756086   |
# | train/             |          |
# |    actor_loss      | -369     |
# |    critic_loss     | 14.9     |
# |    ent_coef        | 0.0414   |
# |    ent_coef_loss   | -0.0633  |
# |    learning_rate   | 0.000244 |
# |    n_updates       | 750939   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | 2.29e+03 |
# | time/              |          |
# |    episodes        | 5744     |
# |    fps             | 62       |
# |    time_elapsed    | 12050    |
# |    total_timesteps | 756822   |
# | train/             |          |
# |    actor_loss      | -368     |
# |    critic_loss     | 14.4     |
# |    ent_coef        | 0.041    |
# |    ent_coef_loss   | -0.319   |
# |    learning_rate   | 0.000243 |
# |    n_updates       | 751644   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | 2.29e+03 |
# | time/              |          |
# |    episodes        | 5748     |
# |    fps             | 62       |
# |    time_elapsed    | 12063    |
# |    total_timesteps | 757695   |
# | train/             |          |
# |    actor_loss      | -371     |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.0415   |
# |    ent_coef_loss   | 0.359    |
# |    learning_rate   | 0.000243 |
# |    n_updates       | 752446   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 203      |
# |    ep_rew_mean     | 2.29e+03 |
# | time/              |          |
# |    episodes        | 5752     |
# |    fps             | 62       |
# |    time_elapsed    | 12078    |
# |    total_timesteps | 758540   |
# | train/             |          |
# |    actor_loss      | -371     |
# |    critic_loss     | 14.4     |
# |    ent_coef        | 0.041    |
# |    ent_coef_loss   | 0.0183   |
# |    learning_rate   | 0.000242 |
# |    n_updates       | 753326   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | 2.3e+03  |
# | time/              |          |
# |    episodes        | 5756     |
# |    fps             | 62       |
# |    time_elapsed    | 12091    |
# |    total_timesteps | 759366   |
# | train/             |          |
# |    actor_loss      | -372     |
# |    critic_loss     | 14.3     |
# |    ent_coef        | 0.041    |
# |    ent_coef_loss   | 0.334    |
# |    learning_rate   | 0.000241 |
# |    n_updates       | 754148   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.36e+03 |
# | time/              |          |
# |    episodes        | 5760     |
# |    fps             | 62       |
# |    time_elapsed    | 12105    |
# |    total_timesteps | 760197   |
# | train/             |          |
# |    actor_loss      | -374     |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.0403   |
# |    ent_coef_loss   | -0.167   |
# |    learning_rate   | 0.00024  |
# |    n_updates       | 755018   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 2.43e+03 |
# | time/              |          |
# |    episodes        | 5764     |
# |    fps             | 62       |
# |    time_elapsed    | 12117    |
# |    total_timesteps | 760973   |
# | train/             |          |
# |    actor_loss      | -371     |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | -0.348   |
# |    learning_rate   | 0.000239 |
# |    n_updates       | 755808   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | 2.46e+03 |
# | time/              |          |
# |    episodes        | 5768     |
# |    fps             | 62       |
# |    time_elapsed    | 12131    |
# |    total_timesteps | 761826   |
# | train/             |          |
# |    actor_loss      | -370     |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.0404   |
# |    ent_coef_loss   | 0.19     |
# |    learning_rate   | 0.000238 |
# |    n_updates       | 756639   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | 2.45e+03 |
# | time/              |          |
# |    episodes        | 5772     |
# |    fps             | 62       |
# |    time_elapsed    | 12144    |
# |    total_timesteps | 762619   |
# | train/             |          |
# |    actor_loss      | -372     |
# |    critic_loss     | 14.1     |
# |    ent_coef        | 0.0413   |
# |    ent_coef_loss   | -0.13    |
# |    learning_rate   | 0.000238 |
# |    n_updates       | 757454   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 2.45e+03 |
# | time/              |          |
# |    episodes        | 5776     |
# |    fps             | 62       |
# |    time_elapsed    | 12156    |
# |    total_timesteps | 763398   |
# | train/             |          |
# |    actor_loss      | -374     |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0405   |
# |    ent_coef_loss   | 0.273    |
# |    learning_rate   | 0.000237 |
# |    n_updates       | 758238   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | 2.44e+03 |
# | time/              |          |
# |    episodes        | 5780     |
# |    fps             | 62       |
# |    time_elapsed    | 12169    |
# |    total_timesteps | 764198   |
# | train/             |          |
# |    actor_loss      | -374     |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.041    |
# |    ent_coef_loss   | -0.0189  |
# |    learning_rate   | 0.000236 |
# |    n_updates       | 759043   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | 2.44e+03 |
# | time/              |          |
# |    episodes        | 5784     |
# |    fps             | 62       |
# |    time_elapsed    | 12183    |
# |    total_timesteps | 765069   |
# | train/             |          |
# |    actor_loss      | -374     |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0405   |
# |    ent_coef_loss   | 0.0616   |
# |    learning_rate   | 0.000235 |
# |    n_updates       | 759911   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | 2.43e+03 |
# | time/              |          |
# |    episodes        | 5788     |
# |    fps             | 62       |
# |    time_elapsed    | 12196    |
# |    total_timesteps | 765878   |
# | train/             |          |
# |    actor_loss      | -372     |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.0412   |
# |    ent_coef_loss   | -0.367   |
# |    learning_rate   | 0.000234 |
# |    n_updates       | 760710   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 209      |
# |    ep_rew_mean     | 2.43e+03 |
# | time/              |          |
# |    episodes        | 5792     |
# |    fps             | 62       |
# |    time_elapsed    | 12208    |
# |    total_timesteps | 766668   |
# | train/             |          |
# |    actor_loss      | -372     |
# |    critic_loss     | 13.9     |
# |    ent_coef        | 0.0411   |
# |    ent_coef_loss   | -0.257   |
# |    learning_rate   | 0.000234 |
# |    n_updates       | 761506   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 208      |
# |    ep_rew_mean     | 2.43e+03 |
# | time/              |          |
# |    episodes        | 5796     |
# |    fps             | 62       |
# |    time_elapsed    | 12220    |
# |    total_timesteps | 767449   |
# | train/             |          |
# |    actor_loss      | -376     |
# |    critic_loss     | 13.4     |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | 0.0642   |
# |    learning_rate   | 0.000233 |
# |    n_updates       | 762251   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 209      |
# |    ep_rew_mean     | 2.43e+03 |
# | time/              |          |
# |    episodes        | 5800     |
# |    fps             | 62       |
# |    time_elapsed    | 12233    |
# |    total_timesteps | 768231   |
# | train/             |          |
# |    actor_loss      | -374     |
# |    critic_loss     | 14.1     |
# |    ent_coef        | 0.0409   |
# |    ent_coef_loss   | -0.0174  |
# |    learning_rate   | 0.000232 |
# |    n_updates       | 763062   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 2.41e+03 |
# | time/              |          |
# |    episodes        | 5804     |
# |    fps             | 62       |
# |    time_elapsed    | 12245    |
# |    total_timesteps | 768931   |
# | train/             |          |
# |    actor_loss      | -375     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.0411   |
# |    ent_coef_loss   | -0.151   |
# |    learning_rate   | 0.000231 |
# |    n_updates       | 763809   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 208      |
# |    ep_rew_mean     | 2.42e+03 |
# | time/              |          |
# |    episodes        | 5808     |
# |    fps             | 62       |
# |    time_elapsed    | 12258    |
# |    total_timesteps | 769798   |
# | train/             |          |
# |    actor_loss      | -374     |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | 0.388    |
# |    learning_rate   | 0.00023  |
# |    n_updates       | 764625   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 208      |
# ...
# |    fps             | 62       |
# |    time_elapsed    | 14881    |
# |    total_timesteps | 933206   |
# | train/             |          |
# |    actor_loss      | -386     |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | -0.248   |
# |    learning_rate   | 6.7e-05  |
# |    n_updates       | 928014   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | 2.72e+03 |
# | time/              |          |
# |    episodes        | 6552     |
# |    fps             | 62       |
# |    time_elapsed    | 14896    |
# |    total_timesteps | 934184   |
# | train/             |          |
# |    actor_loss      | -385     |
# |    critic_loss     | 14.3     |
# |    ent_coef        | 0.04     |
# |    ent_coef_loss   | -0.177   |
# |    learning_rate   | 6.61e-05 |
# |    n_updates       | 928966   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | 2.72e+03 |
# | time/              |          |
# |    episodes        | 6556     |
# |    fps             | 62       |
# |    time_elapsed    | 14911    |
# |    total_timesteps | 935069   |
# | train/             |          |
# |    actor_loss      | -387     |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0402   |
# |    ent_coef_loss   | 0.546    |
# |    learning_rate   | 6.52e-05 |
# |    n_updates       | 929854   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | 2.7e+03  |
# | time/              |          |
# |    episodes        | 6560     |
# |    fps             | 62       |
# |    time_elapsed    | 14925    |
# |    total_timesteps | 935925   |
# | train/             |          |
# |    actor_loss      | -386     |
# |    critic_loss     | 14.1     |
# |    ent_coef        | 0.0408   |
# |    ent_coef_loss   | 0.508    |
# |    learning_rate   | 6.43e-05 |
# |    n_updates       | 930775   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | 2.7e+03  |
# | time/              |          |
# |    episodes        | 6564     |
# |    fps             | 62       |
# |    time_elapsed    | 14940    |
# |    total_timesteps | 936797   |
# | train/             |          |
# |    actor_loss      | -385     |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.0409   |
# |    ent_coef_loss   | -0.0194  |
# |    learning_rate   | 6.34e-05 |
# |    n_updates       | 931652   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | 2.72e+03 |
# | time/              |          |
# |    episodes        | 6568     |
# |    fps             | 62       |
# |    time_elapsed    | 14954    |
# |    total_timesteps | 937742   |
# | train/             |          |
# |    actor_loss      | -386     |
# |    critic_loss     | 14.4     |
# |    ent_coef        | 0.0405   |
# |    ent_coef_loss   | -0.266   |
# |    learning_rate   | 6.25e-05 |
# |    n_updates       | 932500   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | 2.7e+03  |
# | time/              |          |
# |    episodes        | 6572     |
# |    fps             | 62       |
# |    time_elapsed    | 14970    |
# |    total_timesteps | 938671   |
# | train/             |          |
# |    actor_loss      | -385     |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.0405   |
# |    ent_coef_loss   | -0.0993  |
# |    learning_rate   | 6.15e-05 |
# |    n_updates       | 933500   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | 2.71e+03 |
# | time/              |          |
# |    episodes        | 6576     |
# |    fps             | 62       |
# |    time_elapsed    | 14984    |
# |    total_timesteps | 939555   |
# | train/             |          |
# |    actor_loss      | -385     |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0405   |
# |    ent_coef_loss   | -0.232   |
# |    learning_rate   | 6.07e-05 |
# |    n_updates       | 934361   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | 2.71e+03 |
# | time/              |          |
# |    episodes        | 6580     |
# |    fps             | 62       |
# |    time_elapsed    | 14998    |
# |    total_timesteps | 940404   |
# | train/             |          |
# |    actor_loss      | -385     |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.0405   |
# |    ent_coef_loss   | -0.185   |
# |    learning_rate   | 5.98e-05 |
# |    n_updates       | 935222   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | 2.72e+03 |
# | time/              |          |
# |    episodes        | 6584     |
# |    fps             | 62       |
# |    time_elapsed    | 15012    |
# |    total_timesteps | 941288   |
# | train/             |          |
# |    actor_loss      | -384     |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0403   |
# |    ent_coef_loss   | 0.0387   |
# |    learning_rate   | 5.89e-05 |
# |    n_updates       | 936086   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | 2.72e+03 |
# | time/              |          |
# |    episodes        | 6588     |
# |    fps             | 62       |
# |    time_elapsed    | 15026    |
# |    total_timesteps | 942204   |
# | train/             |          |
# |    actor_loss      | -386     |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | 0.339    |
# |    learning_rate   | 5.8e-05  |
# |    n_updates       | 936986   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | 2.71e+03 |
# | time/              |          |
# |    episodes        | 6592     |
# |    fps             | 62       |
# |    time_elapsed    | 15040    |
# |    total_timesteps | 943038   |
# | train/             |          |
# |    actor_loss      | -385     |
# |    critic_loss     | 13.9     |
# |    ent_coef        | 0.0402   |
# |    ent_coef_loss   | 0.783    |
# |    learning_rate   | 5.72e-05 |
# |    n_updates       | 937859   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | 2.71e+03 |
# | time/              |          |
# |    episodes        | 6596     |
# |    fps             | 62       |
# |    time_elapsed    | 15055    |
# |    total_timesteps | 943955   |
# | train/             |          |
# |    actor_loss      | -385     |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | -0.586   |
# |    learning_rate   | 5.63e-05 |
# |    n_updates       | 938750   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | 2.71e+03 |
# | time/              |          |
# |    episodes        | 6600     |
# |    fps             | 62       |
# |    time_elapsed    | 15070    |
# |    total_timesteps | 944858   |
# | train/             |          |
# |    actor_loss      | -386     |
# |    critic_loss     | 14.1     |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | 0.0561   |
# |    learning_rate   | 5.53e-05 |
# |    n_updates       | 939725   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | 2.69e+03 |
# | time/              |          |
# |    episodes        | 6604     |
# |    fps             | 62       |
# |    time_elapsed    | 15082    |
# |    total_timesteps | 945695   |
# | train/             |          |
# |    actor_loss      | -386     |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | 0.414    |
# |    learning_rate   | 5.46e-05 |
# |    n_updates       | 940434   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | 2.69e+03 |
# | time/              |          |
# |    episodes        | 6608     |
# |    fps             | 62       |
# |    time_elapsed    | 15097    |
# |    total_timesteps | 946582   |
# | train/             |          |
# |    actor_loss      | -385     |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | 0.0671   |
# |    learning_rate   | 5.36e-05 |
# |    n_updates       | 941391   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | 2.69e+03 |
# | time/              |          |
# |    episodes        | 6612     |
# |    fps             | 62       |
# |    time_elapsed    | 15114    |
# |    total_timesteps | 947646   |
# | train/             |          |
# |    actor_loss      | -384     |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | 0.0498   |
# |    learning_rate   | 5.26e-05 |
# |    n_updates       | 942397   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | 2.69e+03 |
# | time/              |          |
# |    episodes        | 6616     |
# |    fps             | 62       |
# |    time_elapsed    | 15130    |
# |    total_timesteps | 948569   |
# | train/             |          |
# |    actor_loss      | -386     |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.0402   |
# |    ent_coef_loss   | -0.00841 |
# |    learning_rate   | 5.16e-05 |
# |    n_updates       | 943395   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | 2.69e+03 |
# | time/              |          |
# |    episodes        | 6620     |
# |    fps             | 62       |
# |    time_elapsed    | 15145    |
# |    total_timesteps | 949500   |
# | train/             |          |
# |    actor_loss      | -384     |
# |    critic_loss     | 14.5     |
# |    ent_coef        | 0.0402   |
# |    ent_coef_loss   | -0.649   |
# |    learning_rate   | 5.07e-05 |
# |    n_updates       | 944334   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | 2.69e+03 |
# | time/              |          |
# |    episodes        | 6624     |
# |    fps             | 62       |
# |    time_elapsed    | 15160    |
# |    total_timesteps | 950469   |
# | train/             |          |
# |    actor_loss      | -384     |
# |    critic_loss     | 14.1     |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | 0.0103   |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 945272   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | 2.69e+03 |
# | time/              |          |
# |    episodes        | 6628     |
# |    fps             | 62       |
# |    time_elapsed    | 15174    |
# |    total_timesteps | 951294   |
# | train/             |          |
# |    actor_loss      | -387     |
# |    critic_loss     | 14.3     |
# |    ent_coef        | 0.0403   |
# |    ent_coef_loss   | 0.0151   |
# |    learning_rate   | 4.89e-05 |
# |    n_updates       | 946132   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 227      |
# |    ep_rew_mean     | 2.68e+03 |
# | time/              |          |
# |    episodes        | 6632     |
# |    fps             | 62       |
# |    time_elapsed    | 15189    |
# |    total_timesteps | 952225   |
# | train/             |          |
# |    actor_loss      | -384     |
# |    critic_loss     | 14.1     |
# |    ent_coef        | 0.0402   |
# |    ent_coef_loss   | -0.185   |
# |    learning_rate   | 4.8e-05  |
# |    n_updates       | 947055   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | 2.69e+03 |
# | time/              |          |
# |    episodes        | 6636     |
# |    fps             | 62       |
# |    time_elapsed    | 15204    |
# |    total_timesteps | 953217   |
# | train/             |          |
# |    actor_loss      | -383     |
# |    critic_loss     | 14.5     |
# |    ent_coef        | 0.0403   |
# |    ent_coef_loss   | -0.635   |
# |    learning_rate   | 4.71e-05 |
# |    n_updates       | 947981   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 227      |
# |    ep_rew_mean     | 2.69e+03 |
# | time/              |          |
# |    episodes        | 6640     |
# |    fps             | 62       |
# |    time_elapsed    | 15220    |
# |    total_timesteps | 954150   |
# | train/             |          |
# |    actor_loss      | -384     |
# |    critic_loss     | 13.9     |
# |    ent_coef        | 0.0402   |
# |    ent_coef_loss   | -0.597   |
# |    learning_rate   | 4.61e-05 |
# |    n_updates       | 948946   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 227      |
# |    ep_rew_mean     | 2.68e+03 |
# | time/              |          |
# |    episodes        | 6644     |
# |    fps             | 62       |
# |    time_elapsed    | 15233    |
# |    total_timesteps | 954972   |
# | train/             |          |
# |    actor_loss      | -384     |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.04     |
# |    ent_coef_loss   | -0.258   |
# |    learning_rate   | 4.52e-05 |
# |    n_updates       | 949788   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 227      |
# |    ep_rew_mean     | 2.68e+03 |
# | time/              |          |
# |    episodes        | 6648     |
# |    fps             | 62       |
# |    time_elapsed    | 15247    |
# |    total_timesteps | 955880   |
# | train/             |          |
# |    actor_loss      | -386     |
# |    critic_loss     | 13.9     |
# |    ent_coef        | 0.0399   |
# |    ent_coef_loss   | -0.445   |
# |    learning_rate   | 4.44e-05 |
# |    n_updates       | 950640   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | 2.67e+03 |
# | time/              |          |
# |    episodes        | 6652     |
# |    fps             | 62       |
# |    time_elapsed    | 15262    |
# |    total_timesteps | 956753   |
# | train/             |          |
# |    actor_loss      | -384     |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0396   |
# |    ent_coef_loss   | -0.501   |
# |    learning_rate   | 4.35e-05 |
# |    n_updates       | 951562   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | 2.66e+03 |
# | time/              |          |
# |    episodes        | 6656     |
# |    fps             | 62       |
# |    time_elapsed    | 15275    |
# |    total_timesteps | 957624   |
# | train/             |          |
# |    actor_loss      | -385     |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0394   |
# |    ent_coef_loss   | -0.00129 |
# |    learning_rate   | 4.26e-05 |
# |    n_updates       | 952385   |
# ---------------------------------

# %%
SAR_RL(env_name=f'myoLeg{new_terrain}TerrainWalk-v0', policy_name='SAR-RL', timesteps=1e6,
       seed='0', ica=ica, pca=pca, normalizer=normalizer, phi=.66, syn_nosyn=False)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# |    n_updates       | 599639   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 275      |
# |    ep_rew_mean     | 2.96e+03 |
# | time/              |          |
# |    episodes        | 3516     |
# |    fps             | 59       |
# |    time_elapsed    | 10189    |
# |    total_timesteps | 606023   |
# | train/             |          |
# |    actor_loss      | -392     |
# |    critic_loss     | 49.5     |
# |    ent_coef        | 0.0631   |
# |    ent_coef_loss   | 0.0839   |
# |    learning_rate   | 0.000394 |
# |    n_updates       | 600728   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 274      |
# |    ep_rew_mean     | 2.97e+03 |
# | time/              |          |
# |    episodes        | 3520     |
# |    fps             | 59       |
# |    time_elapsed    | 10210    |
# |    total_timesteps | 607180   |
# | train/             |          |
# |    actor_loss      | -389     |
# |    critic_loss     | 49.3     |
# |    ent_coef        | 0.0629   |
# |    ent_coef_loss   | 0.204    |
# |    learning_rate   | 0.000393 |
# |    n_updates       | 601998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 275      |
# |    ep_rew_mean     | 2.99e+03 |
# | time/              |          |
# |    episodes        | 3524     |
# |    fps             | 59       |
# |    time_elapsed    | 10228    |
# |    total_timesteps | 608223   |
# | train/             |          |
# |    actor_loss      | -389     |
# |    critic_loss     | 48.5     |
# |    ent_coef        | 0.0623   |
# |    ent_coef_loss   | 0.121    |
# |    learning_rate   | 0.000392 |
# |    n_updates       | 602999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 273      |
# |    ep_rew_mean     | 2.97e+03 |
# | time/              |          |
# |    episodes        | 3528     |
# |    fps             | 59       |
# |    time_elapsed    | 10247    |
# |    total_timesteps | 609377   |
# | train/             |          |
# |    actor_loss      | -390     |
# |    critic_loss     | 49.2     |
# |    ent_coef        | 0.062    |
# |    ent_coef_loss   | 0.28     |
# |    learning_rate   | 0.000391 |
# |    n_updates       | 604110   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 277      |
# |    ep_rew_mean     | 3.01e+03 |
# | time/              |          |
# |    episodes        | 3532     |
# |    fps             | 59       |
# |    time_elapsed    | 10270    |
# |    total_timesteps | 610540   |
# | train/             |          |
# |    actor_loss      | -389     |
# |    critic_loss     | 49.9     |
# |    ent_coef        | 0.0622   |
# |    ent_coef_loss   | -0.146   |
# |    learning_rate   | 0.00039  |
# |    n_updates       | 605405   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 278      |
# |    ep_rew_mean     | 3.02e+03 |
# | time/              |          |
# |    episodes        | 3536     |
# |    fps             | 59       |
# |    time_elapsed    | 10291    |
# |    total_timesteps | 611852   |
# | train/             |          |
# |    actor_loss      | -390     |
# |    critic_loss     | 48.9     |
# |    ent_coef        | 0.0621   |
# |    ent_coef_loss   | -0.446   |
# |    learning_rate   | 0.000388 |
# |    n_updates       | 606648   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 280      |
# |    ep_rew_mean     | 3.05e+03 |
# | time/              |          |
# |    episodes        | 3540     |
# |    fps             | 59       |
# |    time_elapsed    | 10308    |
# |    total_timesteps | 612908   |
# | train/             |          |
# |    actor_loss      | -392     |
# |    critic_loss     | 49.6     |
# |    ent_coef        | 0.0626   |
# |    ent_coef_loss   | -0.0499  |
# |    learning_rate   | 0.000387 |
# |    n_updates       | 607599   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 280      |
# |    ep_rew_mean     | 3.06e+03 |
# | time/              |          |
# |    episodes        | 3544     |
# |    fps             | 59       |
# |    time_elapsed    | 10329    |
# |    total_timesteps | 614135   |
# | train/             |          |
# |    actor_loss      | -392     |
# |    critic_loss     | 48.8     |
# |    ent_coef        | 0.063    |
# |    ent_coef_loss   | 0.106    |
# |    learning_rate   | 0.000386 |
# |    n_updates       | 608763   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 281      |
# |    ep_rew_mean     | 3.08e+03 |
# | time/              |          |
# |    episodes        | 3548     |
# |    fps             | 59       |
# |    time_elapsed    | 10351    |
# |    total_timesteps | 615254   |
# | train/             |          |
# |    actor_loss      | -392     |
# |    critic_loss     | 48.5     |
# |    ent_coef        | 0.0625   |
# |    ent_coef_loss   | -0.311   |
# |    learning_rate   | 0.000385 |
# |    n_updates       | 610071   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 283      |
# |    ep_rew_mean     | 3.11e+03 |
# | time/              |          |
# |    episodes        | 3552     |
# |    fps             | 59       |
# |    time_elapsed    | 10369    |
# |    total_timesteps | 616440   |
# | train/             |          |
# |    actor_loss      | -392     |
# |    critic_loss     | 50.1     |
# |    ent_coef        | 0.0637   |
# |    ent_coef_loss   | -0.232   |
# |    learning_rate   | 0.000384 |
# |    n_updates       | 611080   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 284      |
# |    ep_rew_mean     | 3.11e+03 |
# | time/              |          |
# |    episodes        | 3556     |
# |    fps             | 59       |
# |    time_elapsed    | 10392    |
# |    total_timesteps | 617702   |
# | train/             |          |
# |    actor_loss      | -394     |
# |    critic_loss     | 49.1     |
# |    ent_coef        | 0.0618   |
# |    ent_coef_loss   | -0.288   |
# |    learning_rate   | 0.000383 |
# |    n_updates       | 612412   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 289      |
# |    ep_rew_mean     | 3.17e+03 |
# | time/              |          |
# |    episodes        | 3560     |
# |    fps             | 59       |
# |    time_elapsed    | 10415    |
# |    total_timesteps | 619072   |
# | train/             |          |
# |    actor_loss      | -393     |
# |    critic_loss     | 48.6     |
# |    ent_coef        | 0.062    |
# |    ent_coef_loss   | 0.181    |
# |    learning_rate   | 0.000381 |
# |    n_updates       | 613666   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 295      |
# |    ep_rew_mean     | 3.25e+03 |
# | time/              |          |
# |    episodes        | 3564     |
# |    fps             | 59       |
# |    time_elapsed    | 10443    |
# |    total_timesteps | 620657   |
# | train/             |          |
# |    actor_loss      | -392     |
# |    critic_loss     | 47.8     |
# |    ent_coef        | 0.0623   |
# |    ent_coef_loss   | 0.0949   |
# |    learning_rate   | 0.00038  |
# |    n_updates       | 615258   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 297      |
# |    ep_rew_mean     | 3.29e+03 |
# | time/              |          |
# |    episodes        | 3568     |
# |    fps             | 59       |
# |    time_elapsed    | 10464    |
# |    total_timesteps | 621860   |
# | train/             |          |
# |    actor_loss      | -392     |
# |    critic_loss     | 47.6     |
# |    ent_coef        | 0.0623   |
# |    ent_coef_loss   | 0.106    |
# |    learning_rate   | 0.000379 |
# |    n_updates       | 616510   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 298      |
# |    ep_rew_mean     | 3.31e+03 |
# | time/              |          |
# |    episodes        | 3572     |
# |    fps             | 59       |
# |    time_elapsed    | 10488    |
# |    total_timesteps | 623179   |
# | train/             |          |
# |    actor_loss      | -395     |
# |    critic_loss     | 47.2     |
# |    ent_coef        | 0.0623   |
# |    ent_coef_loss   | -0.306   |
# |    learning_rate   | 0.000377 |
# |    n_updates       | 617916   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 3.29e+03 |
# | time/              |          |
# |    episodes        | 3576     |
# |    fps             | 59       |
# |    time_elapsed    | 10511    |
# |    total_timesteps | 624450   |
# | train/             |          |
# |    actor_loss      | -396     |
# |    critic_loss     | 48.5     |
# |    ent_coef        | 0.0624   |
# |    ent_coef_loss   | -0.461   |
# |    learning_rate   | 0.000376 |
# |    n_updates       | 619235   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 302      |
# |    ep_rew_mean     | 3.32e+03 |
# | time/              |          |
# |    episodes        | 3580     |
# |    fps             | 59       |
# |    time_elapsed    | 10534    |
# |    total_timesteps | 625757   |
# | train/             |          |
# |    actor_loss      | -396     |
# |    critic_loss     | 48.1     |
# |    ent_coef        | 0.0623   |
# |    ent_coef_loss   | 0.599    |
# |    learning_rate   | 0.000374 |
# |    n_updates       | 620572   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 3.31e+03 |
# | time/              |          |
# |    episodes        | 3584     |
# |    fps             | 59       |
# |    time_elapsed    | 10554    |
# |    total_timesteps | 626949   |
# | train/             |          |
# |    actor_loss      | -396     |
# |    critic_loss     | 47.7     |
# |    ent_coef        | 0.0622   |
# |    ent_coef_loss   | 0.288    |
# |    learning_rate   | 0.000373 |
# |    n_updates       | 621717   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 3.31e+03 |
# | time/              |          |
# |    episodes        | 3588     |
# |    fps             | 59       |
# |    time_elapsed    | 10575    |
# |    total_timesteps | 628133   |
# | train/             |          |
# |    actor_loss      | -395     |
# |    critic_loss     | 49.3     |
# |    ent_coef        | 0.0632   |
# |    ent_coef_loss   | 0.00628  |
# |    learning_rate   | 0.000372 |
# |    n_updates       | 622925   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 3.28e+03 |
# | time/              |          |
# |    episodes        | 3592     |
# |    fps             | 59       |
# |    time_elapsed    | 10593    |
# |    total_timesteps | 629139   |
# | train/             |          |
# |    actor_loss      | -393     |
# |    critic_loss     | 49       |
# |    ent_coef        | 0.063    |
# |    ent_coef_loss   | 0.351    |
# |    learning_rate   | 0.000371 |
# |    n_updates       | 623981   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 298      |
# |    ep_rew_mean     | 3.26e+03 |
# | time/              |          |
# |    episodes        | 3596     |
# |    fps             | 59       |
# |    time_elapsed    | 10612    |
# |    total_timesteps | 630332   |
# | train/             |          |
# |    actor_loss      | -393     |
# |    critic_loss     | 48.9     |
# |    ent_coef        | 0.0638   |
# |    ent_coef_loss   | 0.106    |
# |    learning_rate   | 0.00037  |
# |    n_updates       | 625066   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 295      |
# |    ep_rew_mean     | 3.24e+03 |
# | time/              |          |
# |    episodes        | 3600     |
# |    fps             | 59       |
# |    time_elapsed    | 10629    |
# |    total_timesteps | 631251   |
# | train/             |          |
# |    actor_loss      | -393     |
# |    critic_loss     | 48.5     |
# |    ent_coef        | 0.0632   |
# |    ent_coef_loss   | -0.471   |
# |    learning_rate   | 0.000369 |
# |    n_updates       | 626034   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 297      |
# |    ep_rew_mean     | 3.27e+03 |
# | time/              |          |
# |    episodes        | 3604     |
# |    fps             | 59       |
# |    time_elapsed    | 10648    |
# |    total_timesteps | 632385   |
# | train/             |          |
# |    actor_loss      | -394     |
# |    critic_loss     | 48.1     |
# |    ent_coef        | 0.063    |
# |    ent_coef_loss   | 0.446    |
# |    learning_rate   | 0.000368 |
# |    n_updates       | 627120   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 299      |
# |    ep_rew_mean     | 3.31e+03 |
# | time/              |          |
# |    episodes        | 3608     |
# |    fps             | 59       |
# |    time_elapsed    | 10670    |
# |    total_timesteps | 633624   |
# | train/             |          |
# |    actor_loss      | -393     |
# |    critic_loss     | 47.6     |
# |    ent_coef        | 0.0623   |
# |    ent_coef_loss   | -0.208   |
# |    learning_rate   | 0.000367 |
# |    n_updates       | 628365   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 303      |
# |    ep_rew_mean     | 3.34e+03 |
# | time/              |          |
# |    episodes        | 3612     |
# |    fps             | 59       |
# |    time_elapsed    | 10697    |
# |    total_timesteps | 635217   |
# | train/             |          |
# |    actor_loss      | -393     |
# |    critic_loss     | 48.7     |
# |    ent_coef        | 0.0616   |
# |    ent_coef_loss   | -0.024   |
# |    learning_rate   | 0.000365 |
# |    n_updates       | 629904   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 304      |
# |    ep_rew_mean     | 3.35e+03 |
# | time/              |          |
# |    episodes        | 3616     |
# |    fps             | 59       |
# |    time_elapsed    | 10718    |
# |    total_timesteps | 636390   |
# | train/             |          |
# |    actor_loss      | -394     |
# |    critic_loss     | 47.5     |
# |    ent_coef        | 0.0626   |
# |    ent_coef_loss   | 0.198    |
# |    learning_rate   | 0.000364 |
# |    n_updates       | 631094   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 305      |
# |    ep_rew_mean     | 3.37e+03 |
# | time/              |          |
# |    episodes        | 3620     |
# |    fps             | 59       |
# |    time_elapsed    | 10739    |
# |    total_timesteps | 637704   |
# | train/             |          |
# |    actor_loss      | -393     |
# |    critic_loss     | 47.3     |
# |    ent_coef        | 0.062    |
# |    ent_coef_loss   | -0.28    |
# |    learning_rate   | 0.000363 |
# |    n_updates       | 632295   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 305      |
# |    ep_rew_mean     | 3.35e+03 |
# | time/              |          |
# |    episodes        | 3624     |
# |    fps             | 59       |
# |    time_elapsed    | 10758    |
# |    total_timesteps | 638718   |
# | train/             |          |
# |    actor_loss      | -393     |
# |    critic_loss     | 46.8     |
# |    ent_coef        | 0.0617   |
# |    ent_coef_loss   | 0.224    |
# |    learning_rate   | 0.000362 |
# |    n_updates       | 633439   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 304      |
# |    ep_rew_mean     | 3.34e+03 |
# | time/              |          |
# |    episodes        | 3628     |
# |    fps             | 59       |
# |    time_elapsed    | 10777    |
# |    total_timesteps | 639765   |
# | train/             |          |
# |    actor_loss      | -393     |
# |    critic_loss     | 45.9     |
# |    ent_coef        | 0.0611   |
# |    ent_coef_loss   | 0.247    |
# |    learning_rate   | 0.00036  |
# |    n_updates       | 634535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 308      |
# |    ep_rew_mean     | 3.39e+03 |
# | time/              |          |
# |    episodes        | 3632     |
# |    fps             | 59       |
# |    time_elapsed    | 10802    |
# |    total_timesteps | 641359   |
# | train/             |          |
# |    actor_loss      | -394     |
# |    critic_loss     | 46       |
# |    ent_coef        | 0.0621   |
# |    ent_coef_loss   | -0.294   |
# |    learning_rate   | 0.000359 |
# |    n_updates       | 635937   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 307      |
# |    ep_rew_mean     | 3.39e+03 |
# | time/              |          |
# |    episodes        | 3636     |
# |    fps             | 59       |
# |    time_elapsed    | 10826    |
# |    total_timesteps | 642582   |
# | train/             |          |
# |    actor_loss      | -396     |
# |    critic_loss     | 47.4     |
# |    ent_coef        | 0.0613   |
# |    ent_coef_loss   | -0.164   |
# |    learning_rate   | 0.000358 |
# |    n_updates       | 637328   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 308      |
# |    ep_rew_mean     | 3.4e+03  |
# | time/              |          |
# |    episodes        | 3640     |
# |    fps             | 59       |
# |    time_elapsed    | 10845    |
# |    total_timesteps | 643689   |
# | train/             |          |
# |    actor_loss      | -396     |
# |    critic_loss     | 47.5     |
# |    ent_coef        | 0.0622   |
# |    ent_coef_loss   | -0.125   |
# |    learning_rate   | 0.000357 |
# |    n_updates       | 638440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 308      |
# |    ep_rew_mean     | 3.4e+03  |
# | time/              |          |
# |    episodes        | 3644     |
# |    fps             | 59       |
# |    time_elapsed    | 10866    |
# |    total_timesteps | 644936   |
# | train/             |          |
# |    actor_loss      | -396     |
# |    critic_loss     | 47.5     |
# |    ent_coef        | 0.0612   |
# |    ent_coef_loss   | 0.321    |
# |    learning_rate   | 0.000355 |
# |    n_updates       | 639669   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 308      |
# |    ep_rew_mean     | 3.4e+03  |
# | time/              |          |
# |    episodes        | 3648     |
# |    fps             | 59       |
# |    time_elapsed    | 10885    |
# |    total_timesteps | 646012   |
# | train/             |          |
# |    actor_loss      | -397     |
# |    critic_loss     | 46.8     |
# |    ent_coef        | 0.0607   |
# |    ent_coef_loss   | -0.0692  |
# |    learning_rate   | 0.000354 |
# |    n_updates       | 640735   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 307      |
# |    ep_rew_mean     | 3.41e+03 |
# | time/              |          |
# |    episodes        | 3652     |
# |    fps             | 59       |
# |    time_elapsed    | 10906    |
# |    total_timesteps | 647164   |
# | train/             |          |
# |    actor_loss      | -397     |
# |    critic_loss     | 47.2     |
# |    ent_coef        | 0.0625   |
# |    ent_coef_loss   | 0.013    |
# |    learning_rate   | 0.000353 |
# |    n_updates       | 641961   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 304      |
# |    ep_rew_mean     | 3.38e+03 |
# | time/              |          |
# |    episodes        | 3656     |
# |    fps             | 59       |
# |    time_elapsed    | 10923    |
# |    total_timesteps | 648122   |
# | train/             |          |
# |    actor_loss      | -399     |
# |    critic_loss     | 48.1     |
# |    ent_coef        | 0.0614   |
# |    ent_coef_loss   | 0.0155   |
# |    learning_rate   | 0.000352 |
# |    n_updates       | 642947   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 3.36e+03 |
# | time/              |          |
# |    episodes        | 3660     |
# |    fps             | 59       |
# |    time_elapsed    | 10942    |
# |    total_timesteps | 649202   |
# | train/             |          |
# |    actor_loss      | -398     |
# |    critic_loss     | 48.2     |
# |    ent_coef        | 0.0627   |
# |    ent_coef_loss   | -0.879   |
# |    learning_rate   | 0.000351 |
# |    n_updates       | 643983   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 296      |
# |    ep_rew_mean     | 3.32e+03 |
# | time/              |          |
# |    episodes        | 3664     |
# |    fps             | 59       |
# |    time_elapsed    | 10959    |
# |    total_timesteps | 650244   |
# | train/             |          |
# |    actor_loss      | -398     |
# |    critic_loss     | 47.9     |
# |    ent_coef        | 0.062    |
# |    ent_coef_loss   | -0.0146  |
# |    learning_rate   | 0.00035  |
# |    n_updates       | 644992   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 297      |
# |    ep_rew_mean     | 3.32e+03 |
# | time/              |          |
# |    episodes        | 3668     |
# |    fps             | 59       |
# |    time_elapsed    | 10980    |
# |    total_timesteps | 651539   |
# | train/             |          |
# |    actor_loss      | -400     |
# |    critic_loss     | 47.7     |
# |    ent_coef        | 0.0626   |
# |    ent_coef_loss   | -0.111   |
# |    learning_rate   | 0.000349 |
# |    n_updates       | 646152   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 295      |
# |    ep_rew_mean     | 3.31e+03 |
# | time/              |          |
# |    episodes        | 3672     |
# |    fps             | 59       |
# |    time_elapsed    | 11001    |
# |    total_timesteps | 652714   |
# | train/             |          |
# |    actor_loss      | -400     |
# |    critic_loss     | 47.4     |
# |    ent_coef        | 0.0615   |
# |    ent_coef_loss   | 0.123    |
# |    learning_rate   | 0.000348 |
# |    n_updates       | 647358   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 295      |
# |    ep_rew_mean     | 3.35e+03 |
# | time/              |          |
# |    episodes        | 3676     |
# |    fps             | 59       |
# |    time_elapsed    | 11023    |
# |    total_timesteps | 653939   |
# | train/             |          |
# |    actor_loss      | -397     |
# |    critic_loss     | 47.4     |
# |    ent_coef        | 0.0616   |
# |    ent_coef_loss   | -0.0634  |
# |    learning_rate   | 0.000346 |
# |    n_updates       | 648673   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 293      |
# |    ep_rew_mean     | 3.32e+03 |
# | time/              |          |
# |    episodes        | 3680     |
# |    fps             | 59       |
# |    time_elapsed    | 11043    |
# |    total_timesteps | 655074   |
# | train/             |          |
# |    actor_loss      | -397     |
# |    critic_loss     | 46.5     |
# |    ent_coef        | 0.0618   |
# |    ent_coef_loss   | 0.185    |
# |    learning_rate   | 0.000345 |
# |    n_updates       | 649837   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 293      |
# |    ep_rew_mean     | 3.32e+03 |
# | time/              |          |
# |    episodes        | 3684     |
# |    fps             | 59       |
# |    time_elapsed    | 11065    |
# |    total_timesteps | 656200   |
# | train/             |          |
# |    actor_loss      | -397     |
# |    critic_loss     | 47.3     |
# |    ent_coef        | 0.0628   |
# |    ent_coef_loss   | -0.0983  |
# |    learning_rate   | 0.000344 |
# |    n_updates       | 651100   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 295      |
# |    ep_rew_mean     | 3.35e+03 |
# | time/              |          |
# |    episodes        | 3688     |
# |    fps             | 59       |
# |    time_elapsed    | 11087    |
# |    total_timesteps | 657614   |
# | train/             |          |
# |    actor_loss      | -396     |
# |    critic_loss     | 48.1     |
# |    ent_coef        | 0.0629   |
# |    ent_coef_loss   | 0.512    |
# |    learning_rate   | 0.000343 |
# |    n_updates       | 652332   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 298      |
# |    ep_rew_mean     | 3.38e+03 |
# | time/              |          |
# |    episodes        | 3692     |
# |    fps             | 59       |
# |    time_elapsed    | 11109    |
# |    total_timesteps | 658907   |
# | train/             |          |
# |    actor_loss      | -397     |
# |    critic_loss     | 47       |
# |    ent_coef        | 0.0618   |
# |    ent_coef_loss   | 0.0551   |
# |    learning_rate   | 0.000341 |
# |    n_updates       | 653605   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 299      |
# |    ep_rew_mean     | 3.41e+03 |
# | time/              |          |
# |    episodes        | 3696     |
# |    fps             | 59       |
# |    time_elapsed    | 11133    |
# |    total_timesteps | 660263   |
# | train/             |          |
# |    actor_loss      | -395     |
# |    critic_loss     | 47       |
# |    ent_coef        | 0.0625   |
# |    ent_coef_loss   | 0.105    |
# |    learning_rate   | 0.00034  |
# |    n_updates       | 654947   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 3.41e+03 |
# | time/              |          |
# |    episodes        | 3700     |
# |    fps             | 59       |
# |    time_elapsed    | 11152    |
# |    total_timesteps | 661310   |
# | train/             |          |
# |    actor_loss      | -396     |
# |    critic_loss     | 46.9     |
# |    ent_coef        | 0.0628   |
# |    ent_coef_loss   | -0.077   |
# |    learning_rate   | 0.000339 |
# |    n_updates       | 656063   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 3.43e+03 |
# | time/              |          |
# |    episodes        | 3704     |
# |    fps             | 59       |
# |    time_elapsed    | 11170    |
# |    total_timesteps | 662470   |
# | train/             |          |
# |    actor_loss      | -398     |
# |    critic_loss     | 47.1     |
# |    ent_coef        | 0.0622   |
# |    ent_coef_loss   | 0.143    |
# |    learning_rate   | 0.000338 |
# |    n_updates       | 657113   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 3.41e+03 |
# | time/              |          |
# |    episodes        | 3708     |
# |    fps             | 59       |
# |    time_elapsed    | 11192    |
# |    total_timesteps | 663661   |
# | train/             |          |
# |    actor_loss      | -398     |
# |    critic_loss     | 47.3     |
# |    ent_coef        | 0.0616   |
# |    ent_coef_loss   | 0.111    |
# |    learning_rate   | 0.000337 |
# |    n_updates       | 658396   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 299      |
# |    ep_rew_mean     | 3.41e+03 |
# | time/              |          |
# |    episodes        | 3712     |
# |    fps             | 59       |
# |    time_elapsed    | 11217    |
# |    total_timesteps | 665150   |
# | train/             |          |
# |    actor_loss      | -399     |
# |    critic_loss     | 47.3     |
# |    ent_coef        | 0.0626   |
# |    ent_coef_loss   | -0.104   |
# |    learning_rate   | 0.000335 |
# |    n_updates       | 659800   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 304      |
# |    ep_rew_mean     | 3.45e+03 |
# | time/              |          |
# |    episodes        | 3716     |
# |    fps             | 59       |
# |    time_elapsed    | 11245    |
# |    total_timesteps | 666785   |
# | train/             |          |
# |    actor_loss      | -400     |
# |    critic_loss     | 47.6     |
# |    ent_coef        | 0.0618   |
# |    ent_coef_loss   | -0.201   |
# |    learning_rate   | 0.000334 |
# |    n_updates       | 661406   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 302      |
# |    ep_rew_mean     | 3.41e+03 |
# | time/              |          |
# |    episodes        | 3720     |
# |    fps             | 59       |
# |    time_elapsed    | 11264    |
# |    total_timesteps | 667891   |
# | train/             |          |
# |    actor_loss      | -399     |
# |    critic_loss     | 47.7     |
# |    ent_coef        | 0.0622   |
# |    ent_coef_loss   | -0.162   |
# |    learning_rate   | 0.000333 |
# |    n_updates       | 662507   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 305      |
# |    ep_rew_mean     | 3.45e+03 |
# | time/              |          |
# |    episodes        | 3724     |
# |    fps             | 59       |
# |    time_elapsed    | 11288    |
# |    total_timesteps | 669242   |
# | train/             |          |
# |    actor_loss      | -399     |
# |    critic_loss     | 48.1     |
# |    ent_coef        | 0.0621   |
# |    ent_coef_loss   | -0.452   |
# |    learning_rate   | 0.000331 |
# |    n_updates       | 663941   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 307      |
# |    ep_rew_mean     | 3.46e+03 |
# | time/              |          |
# |    episodes        | 3728     |
# |    fps             | 59       |
# |    time_elapsed    | 11309    |
# |    total_timesteps | 670440   |
# | train/             |          |
# |    actor_loss      | -399     |
# |    critic_loss     | 48.2     |
# |    ent_coef        | 0.0619   |
# |    ent_coef_loss   | 0.326    |
# |    learning_rate   | 0.00033  |
# |    n_updates       | 665168   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 3.4e+03  |
# | time/              |          |
# |    episodes        | 3732     |
# |    fps             | 59       |
# |    time_elapsed    | 11328    |
# |    total_timesteps | 671443   |
# | train/             |          |
# |    actor_loss      | -398     |
# |    critic_loss     | 48.2     |
# |    ent_coef        | 0.0616   |
# |    ent_coef_loss   | -0.263   |
# |    learning_rate   | 0.000329 |
# |    n_updates       | 666299   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 3.38e+03 |
# | time/              |          |
# |    episodes        | 3736     |
# |    fps             | 59       |
# |    time_elapsed    | 11347    |
# |    total_timesteps | 672621   |
# | train/             |          |
# |    actor_loss      | -401     |
# |    critic_loss     | 48.8     |
# |    ent_coef        | 0.0621   |
# |    ent_coef_loss   | 0.179    |
# |    learning_rate   | 0.000328 |
# |    n_updates       | 667386   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 3.4e+03  |
# | time/              |          |
# |    episodes        | 3740     |
# |    fps             | 59       |
# |    time_elapsed    | 11367    |
# |    total_timesteps | 673830   |
# | train/             |          |
# |    actor_loss      | -400     |
# |    critic_loss     | 49.9     |
# |    ent_coef        | 0.0631   |
# |    ent_coef_loss   | -0.0718  |
# |    learning_rate   | 0.000327 |
# |    n_updates       | 668519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 3.36e+03 |
# | time/              |          |
# |    episodes        | 3744     |
# |    fps             | 59       |
# |    time_elapsed    | 11386    |
# |    total_timesteps | 674908   |
# | train/             |          |
# |    actor_loss      | -400     |
# |    critic_loss     | 51       |
# |    ent_coef        | 0.0629   |
# |    ent_coef_loss   | 0.657    |
# |    learning_rate   | 0.000325 |
# |    n_updates       | 669673   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 3.35e+03 |
# | time/              |          |
# |    episodes        | 3748     |
# |    fps             | 59       |
# |    time_elapsed    | 11404    |
# |    total_timesteps | 675998   |
# | train/             |          |
# |    actor_loss      | -402     |
# |    critic_loss     | 50.7     |
# |    ent_coef        | 0.0625   |
# |    ent_coef_loss   | -0.134   |
# |    learning_rate   | 0.000324 |
# |    n_updates       | 670689   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 299      |
# |    ep_rew_mean     | 3.32e+03 |
# | time/              |          |
# |    episodes        | 3752     |
# |    fps             | 59       |
# |    time_elapsed    | 11424    |
# |    total_timesteps | 677086   |
# | train/             |          |
# |    actor_loss      | -400     |
# |    critic_loss     | 50.7     |
# |    ent_coef        | 0.0629   |
# |    ent_coef_loss   | -0.271   |
# |    learning_rate   | 0.000323 |
# |    n_updates       | 671936   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 297      |
# |    ep_rew_mean     | 3.29e+03 |
# | time/              |          |
# |    episodes        | 3756     |
# |    fps             | 59       |
# |    time_elapsed    | 11436    |
# |    total_timesteps | 677810   |
# | train/             |          |
# |    actor_loss      | -401     |
# |    critic_loss     | 51.5     |
# |    ent_coef        | 0.0638   |
# |    ent_coef_loss   | 0.257    |
# |    learning_rate   | 0.000322 |
# |    n_updates       | 672600   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 298      |
# |    ep_rew_mean     | 3.26e+03 |
# | time/              |          |
# |    episodes        | 3760     |
# |    fps             | 59       |
# |    time_elapsed    | 11456    |
# |    total_timesteps | 678977   |
# | train/             |          |
# |    actor_loss      | -400     |
# |    critic_loss     | 52.2     |
# |    ent_coef        | 0.0634   |
# |    ent_coef_loss   | -0.0429  |
# |    learning_rate   | 0.000321 |
# |    n_updates       | 673769   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 299      |
# |    ep_rew_mean     | 3.25e+03 |
# | time/              |          |
# |    episodes        | 3764     |
# |    fps             | 59       |
# |    time_elapsed    | 11475    |
# |    total_timesteps | 680125   |
# | train/             |          |
# |    actor_loss      | -398     |
# |    critic_loss     | 51.6     |
# |    ent_coef        | 0.0636   |
# |    ent_coef_loss   | 0.0661   |
# |    learning_rate   | 0.00032  |
# |    n_updates       | 674865   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 299      |
# |    ep_rew_mean     | 3.25e+03 |
# | time/              |          |
# |    episodes        | 3768     |
# |    fps             | 59       |
# |    time_elapsed    | 11497    |
# |    total_timesteps | 681410   |
# | train/             |          |
# |    actor_loss      | -398     |
# |    critic_loss     | 51.2     |
# |    ent_coef        | 0.0641   |
# |    ent_coef_loss   | -0.0302  |
# |    learning_rate   | 0.000319 |
# |    n_updates       | 676135   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 299      |
# |    ep_rew_mean     | 3.25e+03 |
# | time/              |          |
# |    episodes        | 3772     |
# |    fps             | 59       |
# |    time_elapsed    | 11517    |
# |    total_timesteps | 682578   |
# | train/             |          |
# |    actor_loss      | -398     |
# |    critic_loss     | 50.5     |
# |    ent_coef        | 0.0647   |
# |    ent_coef_loss   | 0.109    |
# |    learning_rate   | 0.000318 |
# |    n_updates       | 677345   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 296      |
# |    ep_rew_mean     | 3.22e+03 |
# | time/              |          |
# |    episodes        | 3776     |
# |    fps             | 59       |
# |    time_elapsed    | 11533    |
# |    total_timesteps | 683507   |
# | train/             |          |
# |    actor_loss      | -402     |
# |    critic_loss     | 50.7     |
# |    ent_coef        | 0.0634   |
# |    ent_coef_loss   | -0.196   |
# |    learning_rate   | 0.000317 |
# |    n_updates       | 678233   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 296      |
# |    ep_rew_mean     | 3.25e+03 |
# | time/              |          |
# |    episodes        | 3780     |
# |    fps             | 59       |
# |    time_elapsed    | 11553    |
# |    total_timesteps | 684662   |
# | train/             |          |
# |    actor_loss      | -400     |
# |    critic_loss     | 49.6     |
# |    ent_coef        | 0.0634   |
# |    ent_coef_loss   | -0.034   |
# |    learning_rate   | 0.000316 |
# |    n_updates       | 679421   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 298      |
# |    ep_rew_mean     | 3.27e+03 |
# | time/              |          |
# |    episodes        | 3784     |
# |    fps             | 59       |
# |    time_elapsed    | 11575    |
# |    total_timesteps | 686027   |
# | train/             |          |
# |    actor_loss      | -401     |
# |    critic_loss     | 49.5     |
# |    ent_coef        | 0.0628   |
# |    ent_coef_loss   | 0.325    |
# |    learning_rate   | 0.000314 |
# |    n_updates       | 680661   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 3.3e+03  |
# | time/              |          |
# |    episodes        | 3788     |
# |    fps             | 59       |
# |    time_elapsed    | 11602    |
# |    total_timesteps | 687659   |
# | train/             |          |
# |    actor_loss      | -402     |
# |    critic_loss     | 49.6     |
# |    ent_coef        | 0.0627   |
# |    ent_coef_loss   | -0.0281  |
# |    learning_rate   | 0.000313 |
# |    n_updates       | 682337   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 3.33e+03 |
# | time/              |          |
# |    episodes        | 3792     |
# |    fps             | 59       |
# |    time_elapsed    | 11625    |
# |    total_timesteps | 689031   |
# | train/             |          |
# |    actor_loss      | -402     |
# |    critic_loss     | 49.2     |
# |    ent_coef        | 0.0638   |
# |    ent_coef_loss   | -0.129   |
# |    learning_rate   | 0.000311 |
# |    n_updates       | 683722   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 3.33e+03 |
# | time/              |          |
# |    episodes        | 3796     |
# |    fps             | 59       |
# |    time_elapsed    | 11647    |
# |    total_timesteps | 690339   |
# | train/             |          |
# |    actor_loss      | -402     |
# |    critic_loss     | 49       |
# |    ent_coef        | 0.0642   |
# |    ent_coef_loss   | -0.281   |
# |    learning_rate   | 0.00031  |
# |    n_updates       | 685106   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 303      |
# |    ep_rew_mean     | 3.36e+03 |
# | time/              |          |
# |    episodes        | 3800     |
# |    fps             | 59       |
# |    time_elapsed    | 11666    |
# |    total_timesteps | 691607   |
# | train/             |          |
# |    actor_loss      | -402     |
# |    critic_loss     | 48.3     |
# |    ent_coef        | 0.0644   |
# |    ent_coef_loss   | -0.284   |
# |    learning_rate   | 0.000309 |
# |    n_updates       | 686220   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 307      |
# |    ep_rew_mean     | 3.39e+03 |
# | time/              |          |
# |    episodes        | 3804     |
# |    fps             | 59       |
# |    time_elapsed    | 11690    |
# |    total_timesteps | 693126   |
# | train/             |          |
# |    actor_loss      | -402     |
# |    critic_loss     | 49.4     |
# |    ent_coef        | 0.0641   |
# |    ent_coef_loss   | 0.27     |
# |    learning_rate   | 0.000307 |
# |    n_updates       | 687686   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 307      |
# |    ep_rew_mean     | 3.41e+03 |
# | time/              |          |
# |    episodes        | 3808     |
# |    fps             | 59       |
# |    time_elapsed    | 11713    |
# |    total_timesteps | 694345   |
# | train/             |          |
# |    actor_loss      | -402     |
# |    critic_loss     | 49.4     |
# |    ent_coef        | 0.0631   |
# |    ent_coef_loss   | 0.315    |
# |    learning_rate   | 0.000306 |
# |    n_updates       | 689085   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 305      |
# |    ep_rew_mean     | 3.36e+03 |
# | time/              |          |
# |    episodes        | 3812     |
# |    fps             | 59       |
# |    time_elapsed    | 11731    |
# |    total_timesteps | 695638   |
# | train/             |          |
# |    actor_loss      | -403     |
# |    critic_loss     | 48.5     |
# |    ent_coef        | 0.0627   |
# |    ent_coef_loss   | -0.494   |
# |    learning_rate   | 0.000305 |
# |    n_updates       | 690183   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 302      |
# |    ep_rew_mean     | 3.33e+03 |
# | time/              |          |
# |    episodes        | 3816     |
# |    fps             | 59       |
# |    time_elapsed    | 11754    |
# |    total_timesteps | 696950   |
# | train/             |          |
# |    actor_loss      | -404     |
# |    critic_loss     | 49.4     |
# |    ent_coef        | 0.0635   |
# |    ent_coef_loss   | 0.268    |
# |    learning_rate   | 0.000303 |
# |    n_updates       | 691608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 303      |
# |    ep_rew_mean     | 3.36e+03 |
# | time/              |          |
# |    episodes        | 3820     |
# |    fps             | 59       |
# |    time_elapsed    | 11776    |
# |    total_timesteps | 698224   |
# | train/             |          |
# |    actor_loss      | -401     |
# |    critic_loss     | 49.2     |
# |    ent_coef        | 0.0633   |
# |    ent_coef_loss   | 0.119    |
# |    learning_rate   | 0.000302 |
# |    n_updates       | 692948   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 304      |
# |    ep_rew_mean     | 3.38e+03 |
# | time/              |          |
# |    episodes        | 3824     |
# |    fps             | 59       |
# |    time_elapsed    | 11797    |
# |    total_timesteps | 699642   |
# | train/             |          |
# |    actor_loss      | -405     |
# |    critic_loss     | 49.4     |
# |    ent_coef        | 0.0622   |
# |    ent_coef_loss   | 0.413    |
# |    learning_rate   | 0.000301 |
# |    n_updates       | 694259   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 308      |
# |    ep_rew_mean     | 3.42e+03 |
# | time/              |          |
# |    episodes        | 3828     |
# |    fps             | 59       |
# |    time_elapsed    | 11823    |
# |    total_timesteps | 701200   |
# | train/             |          |
# |    actor_loss      | -403     |
# |    critic_loss     | 49.2     |
# |    ent_coef        | 0.0632   |
# |    ent_coef_loss   | -0.0741  |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 695877   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 313      |
# |    ep_rew_mean     | 3.48e+03 |
# | time/              |          |
# |    episodes        | 3832     |
# |    fps             | 59       |
# |    time_elapsed    | 11848    |
# |    total_timesteps | 702719   |
# | train/             |          |
# |    actor_loss      | -404     |
# |    critic_loss     | 49.1     |
# |    ent_coef        | 0.0628   |
# |    ent_coef_loss   | -0.293   |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 697373   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 314      |
# |    ep_rew_mean     | 3.5e+03  |
# | time/              |          |
# |    episodes        | 3836     |
# |    fps             | 59       |
# |    time_elapsed    | 11871    |
# |    total_timesteps | 704045   |
# | train/             |          |
# |    actor_loss      | -402     |
# |    critic_loss     | 50.1     |
# |    ent_coef        | 0.0621   |
# |    ent_coef_loss   | -0.0367  |
# |    learning_rate   | 0.000296 |
# |    n_updates       | 698812   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 316      |
# |    ep_rew_mean     | 3.52e+03 |
# | time/              |          |
# |    episodes        | 3840     |
# |    fps             | 59       |
# |    time_elapsed    | 11892    |
# |    total_timesteps | 705454   |
# | train/             |          |
# |    actor_loss      | -404     |
# |    critic_loss     | 50.3     |
# |    ent_coef        | 0.0619   |
# |    ent_coef_loss   | -0.279   |
# |    learning_rate   | 0.000295 |
# |    n_updates       | 700140   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 318      |
# |    ep_rew_mean     | 3.55e+03 |
# | time/              |          |
# |    episodes        | 3844     |
# |    fps             | 59       |
# |    time_elapsed    | 11912    |
# |    total_timesteps | 706703   |
# | train/             |          |
# |    actor_loss      | -405     |
# |    critic_loss     | 50.2     |
# |    ent_coef        | 0.0629   |
# |    ent_coef_loss   | 0.0888   |
# ...
# |    fps             | 59       |
# |    time_elapsed    | 15946    |
# |    total_timesteps | 954995   |
# | train/             |          |
# |    actor_loss      | -398     |
# |    critic_loss     | 66       |
# |    ent_coef        | 0.0605   |
# |    ent_coef_loss   | 0.0691   |
# |    learning_rate   | 4.53e-05 |
# |    n_updates       | 949773   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 369      |
# |    ep_rew_mean     | 4.16e+03 |
# | time/              |          |
# |    episodes        | 4584     |
# |    fps             | 59       |
# |    time_elapsed    | 15969    |
# |    total_timesteps | 956694   |
# | train/             |          |
# |    actor_loss      | -399     |
# |    critic_loss     | 65.5     |
# |    ent_coef        | 0.0605   |
# |    ent_coef_loss   | -0.172   |
# |    learning_rate   | 4.39e-05 |
# |    n_updates       | 951111   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 369      |
# |    ep_rew_mean     | 4.18e+03 |
# | time/              |          |
# |    episodes        | 4588     |
# |    fps             | 59       |
# |    time_elapsed    | 15995    |
# |    total_timesteps | 958212   |
# | train/             |          |
# |    actor_loss      | -399     |
# |    critic_loss     | 65.3     |
# |    ent_coef        | 0.0602   |
# |    ent_coef_loss   | -0.0956  |
# |    learning_rate   | 4.22e-05 |
# |    n_updates       | 952808   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 364      |
# |    ep_rew_mean     | 4.15e+03 |
# | time/              |          |
# |    episodes        | 4592     |
# |    fps             | 59       |
# |    time_elapsed    | 16022    |
# |    total_timesteps | 959848   |
# | train/             |          |
# |    actor_loss      | -398     |
# |    critic_loss     | 66       |
# |    ent_coef        | 0.0603   |
# |    ent_coef_loss   | -0.246   |
# |    learning_rate   | 4.06e-05 |
# |    n_updates       | 954470   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 366      |
# |    ep_rew_mean     | 4.15e+03 |
# | time/              |          |
# |    episodes        | 4596     |
# |    fps             | 59       |
# |    time_elapsed    | 16046    |
# |    total_timesteps | 961367   |
# | train/             |          |
# |    actor_loss      | -398     |
# |    critic_loss     | 65.2     |
# |    ent_coef        | 0.0599   |
# |    ent_coef_loss   | 0.188    |
# |    learning_rate   | 3.91e-05 |
# |    n_updates       | 955943   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 372      |
# |    ep_rew_mean     | 4.25e+03 |
# | time/              |          |
# |    episodes        | 4600     |
# |    fps             | 59       |
# |    time_elapsed    | 16075    |
# |    total_timesteps | 963224   |
# | train/             |          |
# |    actor_loss      | -398     |
# |    critic_loss     | 64.6     |
# |    ent_coef        | 0.0597   |
# |    ent_coef_loss   | -0.588   |
# |    learning_rate   | 3.73e-05 |
# |    n_updates       | 957709   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 375      |
# |    ep_rew_mean     | 4.29e+03 |
# | time/              |          |
# |    episodes        | 4604     |
# |    fps             | 59       |
# |    time_elapsed    | 16103    |
# |    total_timesteps | 964811   |
# | train/             |          |
# |    actor_loss      | -399     |
# |    critic_loss     | 64.7     |
# |    ent_coef        | 0.0592   |
# |    ent_coef_loss   | 0.166    |
# |    learning_rate   | 3.55e-05 |
# |    n_updates       | 959542   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 377      |
# |    ep_rew_mean     | 4.34e+03 |
# | time/              |          |
# |    episodes        | 4608     |
# |    fps             | 59       |
# |    time_elapsed    | 16129    |
# |    total_timesteps | 966547   |
# | train/             |          |
# |    actor_loss      | -398     |
# |    critic_loss     | 64       |
# |    ent_coef        | 0.0592   |
# |    ent_coef_loss   | -0.23    |
# |    learning_rate   | 3.39e-05 |
# |    n_updates       | 961105   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 380      |
# |    ep_rew_mean     | 4.39e+03 |
# | time/              |          |
# |    episodes        | 4612     |
# |    fps             | 59       |
# |    time_elapsed    | 16159    |
# |    total_timesteps | 968435   |
# | train/             |          |
# |    actor_loss      | -396     |
# |    critic_loss     | 64.2     |
# |    ent_coef        | 0.0588   |
# |    ent_coef_loss   | -0.047   |
# |    learning_rate   | 3.21e-05 |
# |    n_updates       | 962924   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 381      |
# |    ep_rew_mean     | 4.42e+03 |
# | time/              |          |
# |    episodes        | 4616     |
# |    fps             | 59       |
# |    time_elapsed    | 16188    |
# |    total_timesteps | 970272   |
# | train/             |          |
# |    actor_loss      | -397     |
# |    critic_loss     | 64.1     |
# |    ent_coef        | 0.0588   |
# |    ent_coef_loss   | 0.129    |
# |    learning_rate   | 3.03e-05 |
# |    n_updates       | 964687   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 379      |
# |    ep_rew_mean     | 4.42e+03 |
# | time/              |          |
# |    episodes        | 4620     |
# |    fps             | 59       |
# |    time_elapsed    | 16217    |
# |    total_timesteps | 971893   |
# | train/             |          |
# |    actor_loss      | -397     |
# |    critic_loss     | 63.9     |
# |    ent_coef        | 0.0591   |
# |    ent_coef_loss   | 0.235    |
# |    learning_rate   | 2.85e-05 |
# |    n_updates       | 966547   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 376      |
# |    ep_rew_mean     | 4.4e+03  |
# | time/              |          |
# |    episodes        | 4624     |
# |    fps             | 59       |
# |    time_elapsed    | 16243    |
# |    total_timesteps | 973511   |
# | train/             |          |
# |    actor_loss      | -396     |
# |    critic_loss     | 64       |
# |    ent_coef        | 0.0591   |
# |    ent_coef_loss   | -0.173   |
# |    learning_rate   | 2.68e-05 |
# |    n_updates       | 968191   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 379      |
# |    ep_rew_mean     | 4.45e+03 |
# | time/              |          |
# |    episodes        | 4628     |
# |    fps             | 59       |
# |    time_elapsed    | 16267    |
# |    total_timesteps | 975162   |
# | train/             |          |
# |    actor_loss      | -395     |
# |    critic_loss     | 63.8     |
# |    ent_coef        | 0.0589   |
# |    ent_coef_loss   | -0.133   |
# |    learning_rate   | 2.54e-05 |
# |    n_updates       | 969625   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 378      |
# |    ep_rew_mean     | 4.45e+03 |
# | time/              |          |
# |    episodes        | 4632     |
# |    fps             | 59       |
# |    time_elapsed    | 16292    |
# |    total_timesteps | 976464   |
# | train/             |          |
# |    actor_loss      | -395     |
# |    critic_loss     | 64.7     |
# |    ent_coef        | 0.0583   |
# |    ent_coef_loss   | -0.722   |
# |    learning_rate   | 2.38e-05 |
# |    n_updates       | 971208   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 383      |
# |    ep_rew_mean     | 4.54e+03 |
# | time/              |          |
# |    episodes        | 4636     |
# |    fps             | 59       |
# |    time_elapsed    | 16316    |
# |    total_timesteps | 977954   |
# | train/             |          |
# |    actor_loss      | -395     |
# |    critic_loss     | 64.9     |
# |    ent_coef        | 0.0579   |
# |    ent_coef_loss   | -0.539   |
# |    learning_rate   | 2.23e-05 |
# |    n_updates       | 972712   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 388      |
# |    ep_rew_mean     | 4.6e+03  |
# | time/              |          |
# |    episodes        | 4640     |
# |    fps             | 59       |
# |    time_elapsed    | 16343    |
# |    total_timesteps | 979846   |
# | train/             |          |
# |    actor_loss      | -397     |
# |    critic_loss     | 64       |
# |    ent_coef        | 0.0576   |
# |    ent_coef_loss   | -0.173   |
# |    learning_rate   | 2.07e-05 |
# |    n_updates       | 974294   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | 4.8e+03  |
# | time/              |          |
# |    episodes        | 4644     |
# |    fps             | 59       |
# |    time_elapsed    | 16374    |
# |    total_timesteps | 981753   |
# | train/             |          |
# |    actor_loss      | -395     |
# |    critic_loss     | 65.3     |
# |    ent_coef        | 0.0575   |
# |    ent_coef_loss   | -0.35    |
# |    learning_rate   | 1.88e-05 |
# |    n_updates       | 976268   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 410      |
# |    ep_rew_mean     | 4.97e+03 |
# | time/              |          |
# |    episodes        | 4648     |
# |    fps             | 59       |
# |    time_elapsed    | 16404    |
# |    total_timesteps | 983577   |
# | train/             |          |
# |    actor_loss      | -396     |
# |    critic_loss     | 65.1     |
# |    ent_coef        | 0.0575   |
# |    ent_coef_loss   | 0.271    |
# |    learning_rate   | 1.69e-05 |
# |    n_updates       | 978108   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 408      |
# |    ep_rew_mean     | 4.97e+03 |
# | time/              |          |
# |    episodes        | 4652     |
# |    fps             | 59       |
# |    time_elapsed    | 16429    |
# |    total_timesteps | 985125   |
# | train/             |          |
# |    actor_loss      | -395     |
# |    critic_loss     | 64.8     |
# |    ent_coef        | 0.0576   |
# |    ent_coef_loss   | -0.46    |
# |    learning_rate   | 1.53e-05 |
# |    n_updates       | 979690   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 415      |
# |    ep_rew_mean     | 5.06e+03 |
# | time/              |          |
# |    episodes        | 4656     |
# |    fps             | 59       |
# |    time_elapsed    | 16458    |
# |    total_timesteps | 986918   |
# | train/             |          |
# |    actor_loss      | -394     |
# |    critic_loss     | 65.7     |
# |    ent_coef        | 0.0574   |
# |    ent_coef_loss   | -0.191   |
# |    learning_rate   | 1.36e-05 |
# |    n_updates       | 981443   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 415      |
# |    ep_rew_mean     | 5.05e+03 |
# | time/              |          |
# |    episodes        | 4660     |
# |    fps             | 59       |
# |    time_elapsed    | 16484    |
# |    total_timesteps | 988504   |
# | train/             |          |
# |    actor_loss      | -394     |
# |    critic_loss     | 66.4     |
# |    ent_coef        | 0.0573   |
# |    ent_coef_loss   | -0.0323  |
# |    learning_rate   | 1.2e-05  |
# |    n_updates       | 983072   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 418      |
# |    ep_rew_mean     | 5.1e+03  |
# | time/              |          |
# |    episodes        | 4664     |
# |    fps             | 59       |
# |    time_elapsed    | 16512    |
# |    total_timesteps | 990294   |
# | train/             |          |
# |    actor_loss      | -393     |
# |    critic_loss     | 66.3     |
# |    ent_coef        | 0.0573   |
# |    ent_coef_loss   | 0.19     |
# |    learning_rate   | 1.02e-05 |
# |    n_updates       | 984796   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 416      |
# |    ep_rew_mean     | 5.09e+03 |
# | time/              |          |
# |    episodes        | 4668     |
# |    fps             | 59       |
# |    time_elapsed    | 16539    |
# |    total_timesteps | 991836   |
# | train/             |          |
# |    actor_loss      | -393     |
# |    critic_loss     | 66.1     |
# |    ent_coef        | 0.0573   |
# |    ent_coef_loss   | -0.245   |
# |    learning_rate   | 8.56e-06 |
# |    n_updates       | 986463   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 416      |
# |    ep_rew_mean     | 5.11e+03 |
# | time/              |          |
# |    episodes        | 4672     |
# |    fps             | 59       |
# |    time_elapsed    | 16564    |
# |    total_timesteps | 993508   |
# | train/             |          |
# |    actor_loss      | -391     |
# |    critic_loss     | 66.3     |
# |    ent_coef        | 0.0572   |
# |    ent_coef_loss   | -0.256   |
# |    learning_rate   | 6.99e-06 |
# |    n_updates       | 988032   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 414      |
# |    ep_rew_mean     | 5.09e+03 |
# | time/              |          |
# |    episodes        | 4676     |
# |    fps             | 59       |
# |    time_elapsed    | 16592    |
# |    total_timesteps | 995038   |
# | train/             |          |
# |    actor_loss      | -390     |
# |    critic_loss     | 65.8     |
# |    ent_coef        | 0.0571   |
# |    ent_coef_loss   | -0.528   |
# |    learning_rate   | 5.22e-06 |
# |    n_updates       | 989806   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 417      |
# |    ep_rew_mean     | 5.14e+03 |
# | time/              |          |
# |    episodes        | 4680     |
# |    fps             | 59       |
# |    time_elapsed    | 16616    |
# |    total_timesteps | 996664   |
# | train/             |          |
# |    actor_loss      | -391     |
# |    critic_loss     | 66.2     |
# |    ent_coef        | 0.057    |
# |    ent_coef_loss   | -0.791   |
# |    learning_rate   | 3.75e-06 |
# |    n_updates       | 991274   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 416      |
# |    ep_rew_mean     | 5.13e+03 |
# | time/              |          |
# |    episodes        | 4684     |
# |    fps             | 59       |
# |    time_elapsed    | 16644    |
# |    total_timesteps | 998273   |
# | train/             |          |
# |    actor_loss      | -390     |
# |    critic_loss     | 66.6     |
# |    ent_coef        | 0.0569   |
# |    ent_coef_loss   | -0.624   |
# |    learning_rate   | 2.05e-06 |
# |    n_updates       | 992976   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 417      |
# |    ep_rew_mean     | 5.14e+03 |
# | time/              |          |
# |    episodes        | 4688     |
# |    fps             | 59       |
# |    time_elapsed    | 16668    |
# |    total_timesteps | 999923   |
# | train/             |          |
# |    actor_loss      | -390     |
# |    critic_loss     | 68.2     |
# |    ent_coef        | 0.0569   |
# |    ent_coef_loss   | -0.623   |
# |    learning_rate   | 5.62e-07 |
# |    n_updates       | 994461   |
# ---------------------------------

# %%
video_name = 'walk_SAR-RL_video'

get_vid(name='SAR-RL', env_name='myoLegWalk-v0', seed='0', episodes=5, video_name=video_name,
        determ=False, pca=pca, ica=ica, normalizer=normalizer, phi=.66, is_sar=True, syn_nosyn=False)

show_video(f"{video_name}.mp4")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-6e1b58404dc1> in <cell line: 0>()
#       2
#       3 get_vid(name='SAR-RL', env_name='myoLegWalk-v0', seed='0', episodes=5, video_name=video_name,
# ----> 4         determ=False, pca=pca, ica=ica, normalizer=normalizer, phi=.66, is_sar=True, syn_nosyn=False)
#       5
#       6 show_video(f"{video_name}.mp4")
#
# NameError: name 'pca' is not defined

# %%
gym.make('myoLegWalk-v0')
# Out:
# <TimeLimit<OrderEnforcing<PassiveEnvChecker<WalkEnvV0<myoLegWalk-v0>>>>>

# %% [markdown]
# # Step 1.3 (optional): Train on unseen terrain with end-to-end RL (RL-E2E)

# %%
train('myoLegWalk-v0', 'RL-E2E', 4e6, '0')
# Out:
# Using cpu device
# Logging to RL-E2E_results_myoLegWalk-v0_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.5     |
# |    ep_rew_mean     | 61.8     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 954      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 146      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.5     |
# |    ep_rew_mean     | 56.4     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 978      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 292      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.5     |
# |    ep_rew_mean     | 55.6     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 973      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 438      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.4     |
# |    ep_rew_mean     | 53.9     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 978      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 582      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.1     |
# |    ep_rew_mean     | 55.5     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 982      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 722      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36       |
# |    ep_rew_mean     | 55.5     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 984      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 864      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.2     |
# |    ep_rew_mean     | 57.1     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 983      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1013     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.9     |
# |    ep_rew_mean     | 56.1     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 233      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1150     |
# | train/             |          |
# |    actor_loss      | -174     |
# |    critic_loss     | 521      |
# |    ent_coef        | 0.889    |
# |    ent_coef_loss   | -14.3    |
# |    learning_rate   | 0.000972 |
# |    n_updates       | 143      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.3     |
# |    ep_rew_mean     | 58       |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 148      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1307     |
# | train/             |          |
# |    actor_loss      | -320     |
# |    critic_loss     | 619      |
# |    ent_coef        | 0.78     |
# |    ent_coef_loss   | -25.6    |
# |    learning_rate   | 0.000968 |
# |    n_updates       | 291      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.7     |
# |    ep_rew_mean     | 60.7     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 110      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 1468     |
# | train/             |          |
# |    actor_loss      | -506     |
# |    critic_loss     | 275      |
# |    ent_coef        | 0.685    |
# |    ent_coef_loss   | -33      |
# |    learning_rate   | 0.000964 |
# |    n_updates       | 455      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.4     |
# |    ep_rew_mean     | 59.9     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 93       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 1602     |
# | train/             |          |
# |    actor_loss      | -662     |
# |    critic_loss     | 448      |
# |    ent_coef        | 0.61     |
# |    ent_coef_loss   | -38.7    |
# |    learning_rate   | 0.000961 |
# |    n_updates       | 599      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36       |
# |    ep_rew_mean     | 58       |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 85       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 1728     |
# | train/             |          |
# |    actor_loss      | -757     |
# |    critic_loss     | 406      |
# |    ent_coef        | 0.559    |
# |    ent_coef_loss   | -46.2    |
# |    learning_rate   | 0.000958 |
# |    n_updates       | 715      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.1     |
# |    ep_rew_mean     | 54.6     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 78       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 1877     |
# | train/             |          |
# |    actor_loss      | -886     |
# |    critic_loss     | 350      |
# |    ent_coef        | 0.501    |
# |    ent_coef_loss   | -44.2    |
# |    learning_rate   | 0.000954 |
# |    n_updates       | 864      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.2     |
# |    ep_rew_mean     | 53.1     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 71       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 2029     |
# | train/             |          |
# |    actor_loss      | -992     |
# |    critic_loss     | 401      |
# |    ent_coef        | 0.451    |
# |    ent_coef_loss   | -49.8    |
# |    learning_rate   | 0.00095  |
# |    n_updates       | 1018     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.6      |
# |    ep_rew_mean     | 53.1      |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 66        |
# |    time_elapsed    | 33        |
# |    total_timesteps | 2194      |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 333       |
# |    ent_coef        | 0.406     |
# |    ent_coef_loss   | -50.8     |
# |    learning_rate   | 0.000946  |
# |    n_updates       | 1178      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.5      |
# |    ep_rew_mean     | 57.4      |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 63        |
# |    time_elapsed    | 36        |
# |    total_timesteps | 2335      |
# | train/             |           |
# |    actor_loss      | -1.15e+03 |
# |    critic_loss     | 794       |
# |    ent_coef        | 0.37      |
# |    ent_coef_loss   | -49.5     |
# |    learning_rate   | 0.000943  |
# |    n_updates       | 1325      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.6      |
# |    ep_rew_mean     | 57.5      |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 60        |
# |    time_elapsed    | 40        |
# |    total_timesteps | 2486      |
# | train/             |           |
# |    actor_loss      | -1.19e+03 |
# |    critic_loss     | 594       |
# |    ent_coef        | 0.339     |
# |    ent_coef_loss   | -47.3     |
# |    learning_rate   | 0.000939  |
# |    n_updates       | 1473      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.5      |
# |    ep_rew_mean     | 57.3      |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 58        |
# |    time_elapsed    | 44        |
# |    total_timesteps | 2629      |
# | train/             |           |
# |    actor_loss      | -1.23e+03 |
# |    critic_loss     | 530       |
# |    ent_coef        | 0.313     |
# |    ent_coef_loss   | -47.4     |
# |    learning_rate   | 0.000935  |
# |    n_updates       | 1613      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.6      |
# |    ep_rew_mean     | 62.7      |
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 56        |
# |    time_elapsed    | 49        |
# |    total_timesteps | 2780      |
# | train/             |           |
# |    actor_loss      | -1.27e+03 |
# |    critic_loss     | 818       |
# |    ent_coef        | 0.288     |
# |    ent_coef_loss   | -36.6     |
# |    learning_rate   | 0.000931  |
# |    n_updates       | 1775      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.6      |
# |    ep_rew_mean     | 68        |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 55        |
# |    time_elapsed    | 53        |
# |    total_timesteps | 2930      |
# | train/             |           |
# |    actor_loss      | -1.32e+03 |
# |    critic_loss     | 799       |
# |    ent_coef        | 0.274     |
# |    ent_coef_loss   | -23.2     |
# |    learning_rate   | 0.000928  |
# |    n_updates       | 1917      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.7      |
# |    ep_rew_mean     | 68.3      |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 54        |
# |    time_elapsed    | 57        |
# |    total_timesteps | 3083      |
# | train/             |           |
# |    actor_loss      | -1.38e+03 |
# |    critic_loss     | 613       |
# |    ent_coef        | 0.263     |
# |    ent_coef_loss   | -20.4     |
# |    learning_rate   | 0.000924  |
# |    n_updates       | 2069      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.6      |
# |    ep_rew_mean     | 67.1      |
# | time/              |           |
# |    episodes        | 88        |
# |    fps             | 52        |
# |    time_elapsed    | 61        |
# |    total_timesteps | 3224      |
# | train/             |           |
# |    actor_loss      | -1.41e+03 |
# |    critic_loss     | 686       |
# |    ent_coef        | 0.254     |
# |    ent_coef_loss   | -19.8     |
# |    learning_rate   | 0.00092   |
# |    n_updates       | 2218      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.6      |
# |    ep_rew_mean     | 66.1      |
# | time/              |           |
# |    episodes        | 92        |
# |    fps             | 52        |
# |    time_elapsed    | 64        |
# |    total_timesteps | 3366      |
# | train/             |           |
# |    actor_loss      | -1.43e+03 |
# |    critic_loss     | 514       |
# |    ent_coef        | 0.246     |
# |    ent_coef_loss   | -15.4     |
# |    learning_rate   | 0.000917  |
# |    n_updates       | 2359      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.5      |
# |    ep_rew_mean     | 63.7      |
# | time/              |           |
# |    episodes        | 96        |
# |    fps             | 51        |
# |    time_elapsed    | 68        |
# |    total_timesteps | 3500      |
# | train/             |           |
# |    actor_loss      | -1.43e+03 |
# |    critic_loss     | 879       |
# |    ent_coef        | 0.24      |
# |    ent_coef_loss   | -11.2     |
# |    learning_rate   | 0.000913  |
# |    n_updates       | 2489      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.4      |
# |    ep_rew_mean     | 63        |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 51        |
# |    time_elapsed    | 71        |
# |    total_timesteps | 3639      |
# | train/             |           |
# |    actor_loss      | -1.46e+03 |
# |    critic_loss     | 604       |
# |    ent_coef        | 0.235     |
# |    ent_coef_loss   | -6.36     |
# |    learning_rate   | 0.00091   |
# |    n_updates       | 2623      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.5      |
# |    ep_rew_mean     | 63.7      |
# | time/              |           |
# |    episodes        | 104       |
# |    fps             | 50        |
# |    time_elapsed    | 75        |
# |    total_timesteps | 3793      |
# | train/             |           |
# |    actor_loss      | -1.47e+03 |
# |    critic_loss     | 588       |
# |    ent_coef        | 0.231     |
# |    ent_coef_loss   | -3.8      |
# |    learning_rate   | 0.000906  |
# |    n_updates       | 2778      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.4      |
# |    ep_rew_mean     | 63.6      |
# | time/              |           |
# |    episodes        | 108       |
# |    fps             | 49        |
# |    time_elapsed    | 78        |
# |    total_timesteps | 3934      |
# | train/             |           |
# |    actor_loss      | -1.48e+03 |
# |    critic_loss     | 540       |
# |    ent_coef        | 0.229     |
# |    ent_coef_loss   | -4.72     |
# |    learning_rate   | 0.000903  |
# |    n_updates       | 2919      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.6     |
# |    ep_rew_mean     | 63.9     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 49       |
# |    time_elapsed    | 83       |
# |    total_timesteps | 4102     |
# | train/             |          |
# |    actor_loss      | -1.5e+03 |
# |    critic_loss     | 629      |
# |    ent_coef        | 0.227    |
# |    ent_coef_loss   | -0.531   |
# |    learning_rate   | 0.000898 |
# |    n_updates       | 3087     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.8      |
# |    ep_rew_mean     | 65.4      |
# | time/              |           |
# |    episodes        | 116       |
# |    fps             | 48        |
# |    time_elapsed    | 88        |
# |    total_timesteps | 4258      |
# | train/             |           |
# |    actor_loss      | -1.52e+03 |
# |    critic_loss     | 456       |
# |    ent_coef        | 0.228     |
# |    ent_coef_loss   | -2.45     |
# |    learning_rate   | 0.000895  |
# |    n_updates       | 3246      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37       |
# |    ep_rew_mean     | 66.7     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 47       |
# |    time_elapsed    | 92       |
# |    total_timesteps | 4417     |
# | train/             |          |
# |    actor_loss      | -1.5e+03 |
# |    critic_loss     | 442      |
# |    ent_coef        | 0.225    |
# |    ent_coef_loss   | -4.09    |
# |    learning_rate   | 0.00089  |
# |    n_updates       | 3407     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37.1     |
# |    ep_rew_mean     | 66.6     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 47       |
# |    time_elapsed    | 96       |
# |    total_timesteps | 4577     |
# | train/             |          |
# |    actor_loss      | -1.5e+03 |
# |    critic_loss     | 647      |
# |    ent_coef        | 0.223    |
# |    ent_coef_loss   | -3.42    |
# |    learning_rate   | 0.000887 |
# |    n_updates       | 3563     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 37        |
# |    ep_rew_mean     | 65.7      |
# | time/              |           |
# |    episodes        | 128       |
# |    fps             | 46        |
# |    time_elapsed    | 100       |
# |    total_timesteps | 4711      |
# | train/             |           |
# |    actor_loss      | -1.47e+03 |
# |    critic_loss     | 600       |
# |    ent_coef        | 0.219     |
# |    ent_coef_loss   | -7.02     |
# |    learning_rate   | 0.000883  |
# |    n_updates       | 3705      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 37        |
# |    ep_rew_mean     | 65        |
# | time/              |           |
# |    episodes        | 132       |
# |    fps             | 46        |
# |    time_elapsed    | 104       |
# |    total_timesteps | 4851      |
# | train/             |           |
# |    actor_loss      | -1.47e+03 |
# |    critic_loss     | 652       |
# |    ent_coef        | 0.217     |
# |    ent_coef_loss   | 2.53      |
# |    learning_rate   | 0.00088   |
# |    n_updates       | 3842      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.9      |
# |    ep_rew_mean     | 63.9      |
# | time/              |           |
# |    episodes        | 136       |
# |    fps             | 46        |
# |    time_elapsed    | 108       |
# |    total_timesteps | 4999      |
# | train/             |           |
# |    actor_loss      | -1.42e+03 |
# |    critic_loss     | 461       |
# |    ent_coef        | 0.214     |
# |    ent_coef_loss   | -9.23     |
# |    learning_rate   | 0.000876  |
# |    n_updates       | 3991      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.7     |
# |    ep_rew_mean     | 61.5     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 46       |
# |    time_elapsed    | 111      |
# |    total_timesteps | 5139     |
# | train/             |          |
# |    actor_loss      | -1.4e+03 |
# |    critic_loss     | 421      |
# |    ent_coef        | 0.208    |
# |    ent_coef_loss   | -5.95    |
# |    learning_rate   | 0.000872 |
# |    n_updates       | 4131     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.9      |
# |    ep_rew_mean     | 60.5      |
# | time/              |           |
# |    episodes        | 144       |
# |    fps             | 45        |
# |    time_elapsed    | 115       |
# |    total_timesteps | 5289      |
# | train/             |           |
# |    actor_loss      | -1.37e+03 |
# |    critic_loss     | 367       |
# |    ent_coef        | 0.203     |
# |    ent_coef_loss   | -3        |
# |    learning_rate   | 0.000869  |
# |    n_updates       | 4283      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.9      |
# |    ep_rew_mean     | 61.2      |
# | time/              |           |
# |    episodes        | 148       |
# |    fps             | 45        |
# |    time_elapsed    | 118       |
# |    total_timesteps | 5419      |
# | train/             |           |
# |    actor_loss      | -1.32e+03 |
# |    critic_loss     | 440       |
# |    ent_coef        | 0.199     |
# |    ent_coef_loss   | -4.24     |
# |    learning_rate   | 0.000865  |
# |    n_updates       | 4411      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 36.8      |
# |    ep_rew_mean     | 64.6      |
# | time/              |           |
# |    episodes        | 152       |
# |    fps             | 45        |
# |    time_elapsed    | 122       |
# |    total_timesteps | 5557      |
# | train/             |           |
# |    actor_loss      | -1.28e+03 |
# |    critic_loss     | 528       |
# |    ent_coef        | 0.192     |
# |    ent_coef_loss   | -5.7      |
# |    learning_rate   | 0.000862  |
# |    n_updates       | 4547      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 37        |
# |    ep_rew_mean     | 69        |
# | time/              |           |
# |    episodes        | 156       |
# |    fps             | 45        |
# |    time_elapsed    | 126       |
# |    total_timesteps | 5726      |
# | train/             |           |
# |    actor_loss      | -1.26e+03 |
# |    critic_loss     | 321       |
# |    ent_coef        | 0.186     |
# |    ent_coef_loss   | -2.9      |
# |    learning_rate   | 0.000858  |
# |    n_updates       | 4706      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 37.2      |
# |    ep_rew_mean     | 72.8      |
# | time/              |           |
# |    episodes        | 160       |
# |    fps             | 45        |
# |    time_elapsed    | 130       |
# |    total_timesteps | 5911      |
# | train/             |           |
# |    actor_loss      | -1.21e+03 |
# |    critic_loss     | 318       |
# |    ent_coef        | 0.182     |
# |    ent_coef_loss   | -4.32     |
# |    learning_rate   | 0.000853  |
# |    n_updates       | 4893      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 37.5      |
# |    ep_rew_mean     | 72.6      |
# | time/              |           |
# |    episodes        | 164       |
# |    fps             | 44        |
# |    time_elapsed    | 135       |
# |    total_timesteps | 6081      |
# | train/             |           |
# |    actor_loss      | -1.16e+03 |
# |    critic_loss     | 254       |
# |    ent_coef        | 0.175     |
# |    ent_coef_loss   | -4.15     |
# |    learning_rate   | 0.000849  |
# |    n_updates       | 5066      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 37.7      |
# |    ep_rew_mean     | 72.9      |
# | time/              |           |
# |    episodes        | 168       |
# |    fps             | 44        |
# |    time_elapsed    | 139       |
# |    total_timesteps | 6254      |
# | train/             |           |
# |    actor_loss      | -1.12e+03 |
# |    critic_loss     | 232       |
# |    ent_coef        | 0.171     |
# |    ent_coef_loss   | -9        |
# |    learning_rate   | 0.000845  |
# |    n_updates       | 5237      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 38        |
# |    ep_rew_mean     | 74.3      |
# | time/              |           |
# |    episodes        | 172       |
# |    fps             | 44        |
# |    time_elapsed    | 144       |
# |    total_timesteps | 6430      |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 222       |
# |    ent_coef        | 0.16      |
# |    ent_coef_loss   | -5.75     |
# |    learning_rate   | 0.00084   |
# |    n_updates       | 5413      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 38        |
# |    ep_rew_mean     | 73        |
# | time/              |           |
# |    episodes        | 176       |
# |    fps             | 44        |
# |    time_elapsed    | 148       |
# |    total_timesteps | 6583      |
# | train/             |           |
# |    actor_loss      | -1.04e+03 |
# |    critic_loss     | 280       |
# |    ent_coef        | 0.155     |
# |    ent_coef_loss   | -3.19     |
# |    learning_rate   | 0.000836  |
# |    n_updates       | 5571      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38       |
# |    ep_rew_mean     | 68.3     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 44       |
# |    time_elapsed    | 152      |
# |    total_timesteps | 6726     |
# | train/             |          |
# |    actor_loss      | -995     |
# |    critic_loss     | 217      |
# |    ent_coef        | 0.15     |
# |    ent_coef_loss   | -9.94    |
# |    learning_rate   | 0.000833 |
# |    n_updates       | 5717     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38       |
# |    ep_rew_mean     | 67.4     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 44       |
# |    time_elapsed    | 156      |
# |    total_timesteps | 6882     |
# | train/             |          |
# |    actor_loss      | -961     |
# |    critic_loss     | 244      |
# |    ent_coef        | 0.144    |
# |    ent_coef_loss   | -4.99    |
# |    learning_rate   | 0.000829 |
# |    n_updates       | 5873     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38       |
# |    ep_rew_mean     | 69.3     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 43       |
# |    time_elapsed    | 160      |
# |    total_timesteps | 7025     |
# | train/             |          |
# |    actor_loss      | -908     |
# |    critic_loss     | 202      |
# |    ent_coef        | 0.135    |
# |    ent_coef_loss   | -7.88    |
# |    learning_rate   | 0.000825 |
# |    n_updates       | 6018     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.2     |
# |    ep_rew_mean     | 73       |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 43       |
# |    time_elapsed    | 164      |
# |    total_timesteps | 7188     |
# | train/             |          |
# |    actor_loss      | -860     |
# |    critic_loss     | 144      |
# |    ent_coef        | 0.127    |
# |    ent_coef_loss   | -5.38    |
# |    learning_rate   | 0.000821 |
# |    n_updates       | 6174     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.5     |
# |    ep_rew_mean     | 77.2     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 43       |
# |    time_elapsed    | 168      |
# |    total_timesteps | 7350     |
# | train/             |          |
# |    actor_loss      | -818     |
# |    critic_loss     | 127      |
# |    ent_coef        | 0.124    |
# |    ent_coef_loss   | -3.01    |
# |    learning_rate   | 0.000817 |
# |    n_updates       | 6338     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.6     |
# |    ep_rew_mean     | 78.6     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 43       |
# |    time_elapsed    | 172      |
# |    total_timesteps | 7501     |
# | train/             |          |
# |    actor_loss      | -777     |
# |    critic_loss     | 113      |
# |    ent_coef        | 0.118    |
# |    ent_coef_loss   | -6.79    |
# |    learning_rate   | 0.000813 |
# |    n_updates       | 6489     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.5     |
# |    ep_rew_mean     | 77.8     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 43       |
# |    time_elapsed    | 176      |
# |    total_timesteps | 7644     |
# | train/             |          |
# |    actor_loss      | -732     |
# |    critic_loss     | 124      |
# |    ent_coef        | 0.113    |
# |    ent_coef_loss   | -5.98    |
# |    learning_rate   | 0.00081  |
# |    n_updates       | 6638     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.9     |
# |    ep_rew_mean     | 78.2     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 43       |
# |    time_elapsed    | 180      |
# |    total_timesteps | 7822     |
# | train/             |          |
# |    actor_loss      | -699     |
# |    critic_loss     | 101      |
# |    ent_coef        | 0.108    |
# |    ent_coef_loss   | -4.12    |
# |    learning_rate   | 0.000806 |
# |    n_updates       | 6802     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.9     |
# |    ep_rew_mean     | 78.8     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 43       |
# |    time_elapsed    | 185      |
# |    total_timesteps | 7991     |
# | train/             |          |
# |    actor_loss      | -653     |
# |    critic_loss     | 79.2     |
# |    ent_coef        | 0.102    |
# |    ent_coef_loss   | -6.42    |
# |    learning_rate   | 0.000801 |
# |    n_updates       | 6981     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.9     |
# |    ep_rew_mean     | 79.1     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 43       |
# |    time_elapsed    | 189      |
# |    total_timesteps | 8149     |
# | train/             |          |
# |    actor_loss      | -609     |
# |    critic_loss     | 81.4     |
# |    ent_coef        | 0.096    |
# |    ent_coef_loss   | -5.84    |
# |    learning_rate   | 0.000797 |
# |    n_updates       | 7134     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.8     |
# |    ep_rew_mean     | 78       |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 42       |
# |    time_elapsed    | 193      |
# |    total_timesteps | 8301     |
# | train/             |          |
# |    actor_loss      | -580     |
# |    critic_loss     | 79.4     |
# |    ent_coef        | 0.0906   |
# |    ent_coef_loss   | -4.38    |
# |    learning_rate   | 0.000793 |
# |    n_updates       | 7288     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.9     |
# |    ep_rew_mean     | 79       |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 42       |
# |    time_elapsed    | 197      |
# |    total_timesteps | 8462     |
# | train/             |          |
# |    actor_loss      | -540     |
# |    critic_loss     | 68.4     |
# |    ent_coef        | 0.086    |
# |    ent_coef_loss   | -5.11    |
# |    learning_rate   | 0.000789 |
# |    n_updates       | 7449     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.7     |
# |    ep_rew_mean     | 85.2     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 42       |
# |    time_elapsed    | 200      |
# |    total_timesteps | 8583     |
# | train/             |          |
# |    actor_loss      | -519     |
# |    critic_loss     | 193      |
# |    ent_coef        | 0.0845   |
# |    ent_coef_loss   | 4        |
# |    learning_rate   | 0.000786 |
# |    n_updates       | 7568     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.3     |
# |    ep_rew_mean     | 89.4     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 42       |
# |    time_elapsed    | 205      |
# |    total_timesteps | 8782     |
# | train/             |          |
# |    actor_loss      | -494     |
# |    critic_loss     | 99.2     |
# |    ent_coef        | 0.0857   |
# |    ent_coef_loss   | -4.23    |
# |    learning_rate   | 0.000782 |
# |    n_updates       | 7757     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.4     |
# |    ep_rew_mean     | 94.2     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 42       |
# |    time_elapsed    | 209      |
# |    total_timesteps | 8939     |
# | train/             |          |
# |    actor_loss      | -473     |
# |    critic_loss     | 58.6     |
# |    ent_coef        | 0.0808   |
# |    ent_coef_loss   | -5.91    |
# |    learning_rate   | 0.000778 |
# |    n_updates       | 7925     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.5     |
# |    ep_rew_mean     | 97.4     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 42       |
# |    time_elapsed    | 213      |
# |    total_timesteps | 9084     |
# | train/             |          |
# |    actor_loss      | -448     |
# |    critic_loss     | 48.9     |
# |    ent_coef        | 0.0759   |
# |    ent_coef_loss   | -7.02    |
# |    learning_rate   | 0.000774 |
# |    n_updates       | 8074     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.5     |
# |    ep_rew_mean     | 99.6     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 42       |
# |    time_elapsed    | 217      |
# |    total_timesteps | 9235     |
# | train/             |          |
# |    actor_loss      | -427     |
# |    critic_loss     | 48.5     |
# |    ent_coef        | 0.0742   |
# |    ent_coef_loss   | -2.71    |
# |    learning_rate   | 0.00077  |
# |    n_updates       | 8223     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40       |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 42       |
# |    time_elapsed    | 221      |
# |    total_timesteps | 9422     |
# | train/             |          |
# |    actor_loss      | -407     |
# |    critic_loss     | 41       |
# |    ent_coef        | 0.0704   |
# |    ent_coef_loss   | -0.427   |
# |    learning_rate   | 0.000766 |
# |    n_updates       | 8399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.8     |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 42       |
# |    time_elapsed    | 227      |
# |    total_timesteps | 9638     |
# | train/             |          |
# |    actor_loss      | -381     |
# |    critic_loss     | 38.8     |
# |    ent_coef        | 0.0695   |
# |    ent_coef_loss   | -2.01    |
# |    learning_rate   | 0.00076  |
# |    n_updates       | 8623     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.8     |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 42       |
# |    time_elapsed    | 231      |
# |    total_timesteps | 9804     |
# | train/             |          |
# |    actor_loss      | -370     |
# |    critic_loss     | 33.9     |
# |    ent_coef        | 0.0667   |
# |    ent_coef_loss   | -7.08    |
# |    learning_rate   | 0.000756 |
# |    n_updates       | 8797     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.5     |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 42       |
# |    time_elapsed    | 235      |
# |    total_timesteps | 9961     |
# | train/             |          |
# |    actor_loss      | -355     |
# |    critic_loss     | 33.2     |
# |    ent_coef        | 0.062    |
# |    ent_coef_loss   | -2.64    |
# |    learning_rate   | 0.000752 |
# |    n_updates       | 8944     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.4     |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 42       |
# |    time_elapsed    | 239      |
# |    total_timesteps | 10125    |
# | train/             |          |
# |    actor_loss      | -342     |
# |    critic_loss     | 29.9     |
# |    ent_coef        | 0.0597   |
# |    ent_coef_loss   | -0.452   |
# |    learning_rate   | 0.000748 |
# |    n_updates       | 9110     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.1     |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 42       |
# |    time_elapsed    | 243      |
# |    total_timesteps | 10260    |
# | train/             |          |
# |    actor_loss      | -330     |
# |    critic_loss     | 30.1     |
# |    ent_coef        | 0.0594   |
# |    ent_coef_loss   | -6.29    |
# |    learning_rate   | 0.000744 |
# |    n_updates       | 9251     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.5     |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 41       |
# |    time_elapsed    | 247      |
# |    total_timesteps | 10383    |
# | train/             |          |
# |    actor_loss      | -319     |
# |    critic_loss     | 53.4     |
# |    ent_coef        | 0.0586   |
# |    ent_coef_loss   | -0.178   |
# |    learning_rate   | 0.000741 |
# |    n_updates       | 9384     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.6     |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 41       |
# |    time_elapsed    | 251      |
# |    total_timesteps | 10548    |
# | train/             |          |
# |    actor_loss      | -309     |
# |    critic_loss     | 28.6     |
# |    ent_coef        | 0.0562   |
# |    ent_coef_loss   | -3.37    |
# |    learning_rate   | 0.000737 |
# |    n_updates       | 9536     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.9     |
# |    ep_rew_mean     | 118      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 41       |
# |    time_elapsed    | 255      |
# |    total_timesteps | 10712    |
# | train/             |          |
# |    actor_loss      | -297     |
# |    critic_loss     | 35.7     |
# |    ent_coef        | 0.0549   |
# |    ent_coef_loss   | 6.59     |
# |    learning_rate   | 0.000733 |
# |    n_updates       | 9703     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.8     |
# |    ep_rew_mean     | 121      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 41       |
# |    time_elapsed    | 259      |
# |    total_timesteps | 10863    |
# | train/             |          |
# |    actor_loss      | -284     |
# |    critic_loss     | 30.5     |
# |    ent_coef        | 0.0548   |
# |    ent_coef_loss   | -2.81    |
# |    learning_rate   | 0.000729 |
# |    n_updates       | 9852     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.9     |
# |    ep_rew_mean     | 122      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 41       |
# |    time_elapsed    | 263      |
# |    total_timesteps | 11011    |
# | train/             |          |
# |    actor_loss      | -277     |
# |    critic_loss     | 24.2     |
# |    ent_coef        | 0.0532   |
# |    ent_coef_loss   | -1.67    |
# |    learning_rate   | 0.000726 |
# |    n_updates       | 9999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.9     |
# |    ep_rew_mean     | 123      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 41       |
# |    time_elapsed    | 267      |
# |    total_timesteps | 11182    |
# | train/             |          |
# |    actor_loss      | -269     |
# |    critic_loss     | 21.6     |
# |    ent_coef        | 0.0517   |
# |    ent_coef_loss   | -1.78    |
# |    learning_rate   | 0.000722 |
# |    n_updates       | 10164    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.2     |
# |    ep_rew_mean     | 126      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 41       |
# |    time_elapsed    | 272      |
# |    total_timesteps | 11372    |
# | train/             |          |
# |    actor_loss      | -257     |
# |    critic_loss     | 20.9     |
# |    ent_coef        | 0.05     |
# |    ent_coef_loss   | -1.45    |
# |    learning_rate   | 0.000717 |
# |    n_updates       | 10353    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.3     |
# |    ep_rew_mean     | 129      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 41       |
# |    time_elapsed    | 276      |
# |    total_timesteps | 11530    |
# | train/             |          |
# |    actor_loss      | -252     |
# |    critic_loss     | 19.2     |
# |    ent_coef        | 0.0485   |
# |    ent_coef_loss   | -2.67    |
# |    learning_rate   | 0.000713 |
# |    n_updates       | 10517    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.6     |
# |    ep_rew_mean     | 134      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 41       |
# |    time_elapsed    | 280      |
# |    total_timesteps | 11700    |
# | train/             |          |
# |    actor_loss      | -242     |
# |    critic_loss     | 18.9     |
# |    ent_coef        | 0.0477   |
# |    ent_coef_loss   | 1.06     |
# |    learning_rate   | 0.000709 |
# |    n_updates       | 10683    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.6     |
# |    ep_rew_mean     | 138      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 41       |
# |    time_elapsed    | 285      |
# |    total_timesteps | 11880    |
# | train/             |          |
# |    actor_loss      | -234     |
# |    critic_loss     | 17.5     |
# |    ent_coef        | 0.0472   |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.000704 |
# |    n_updates       | 10871    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.6     |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 41       |
# |    time_elapsed    | 289      |
# |    total_timesteps | 12048    |
# | train/             |          |
# |    actor_loss      | -226     |
# |    critic_loss     | 16.1     |
# |    ent_coef        | 0.0455   |
# |    ent_coef_loss   | -0.281   |
# |    learning_rate   | 0.0007   |
# |    n_updates       | 11037    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.5     |
# |    ep_rew_mean     | 141      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 41       |
# |    time_elapsed    | 293      |
# |    total_timesteps | 12200    |
# | train/             |          |
# |    actor_loss      | -221     |
# |    critic_loss     | 15.6     |
# |    ent_coef        | 0.0439   |
# |    ent_coef_loss   | 1.42     |
# |    learning_rate   | 0.000696 |
# |    n_updates       | 11184    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.1     |
# |    ep_rew_mean     | 146      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 41       |
# |    time_elapsed    | 299      |
# |    total_timesteps | 12412    |
# | train/             |          |
# |    actor_loss      | -212     |
# |    critic_loss     | 15.3     |
# |    ent_coef        | 0.0438   |
# |    ent_coef_loss   | 0.746    |
# |    learning_rate   | 0.000691 |
# |    n_updates       | 11401    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.9     |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 41       |
# |    time_elapsed    | 303      |
# |    total_timesteps | 12555    |
# | train/             |          |
# |    actor_loss      | -205     |
# |    critic_loss     | 24.8     |
# |    ent_coef        | 0.044    |
# |    ent_coef_loss   | -2.09    |
# |    learning_rate   | 0.000687 |
# |    n_updates       | 11543    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.2     |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 41       |
# |    time_elapsed    | 307      |
# |    total_timesteps | 12704    |
# | train/             |          |
# |    actor_loss      | -202     |
# |    critic_loss     | 15       |
# |    ent_coef        | 0.0441   |
# |    ent_coef_loss   | 2.95     |
# |    learning_rate   | 0.000683 |
# |    n_updates       | 11690    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.8     |
# |    ep_rew_mean     | 151      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 41       |
# |    time_elapsed    | 311      |
# |    total_timesteps | 12857    |
# | train/             |          |
# |    actor_loss      | -200     |
# |    critic_loss     | 16.4     |
# |    ent_coef        | 0.0437   |
# |    ent_coef_loss   | 2.08     |
# |    learning_rate   | 0.00068  |
# |    n_updates       | 11843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.6     |
# |    ep_rew_mean     | 152      |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 41       |
# |    time_elapsed    | 316      |
# |    total_timesteps | 12997    |
# | train/             |          |
# |    actor_loss      | -198     |
# |    critic_loss     | 18.5     |
# |    ent_coef        | 0.043    |
# |    ent_coef_loss   | -4.91    |
# |    learning_rate   | 0.000676 |
# |    n_updates       | 11975    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.1     |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 41       |
# |    time_elapsed    | 321      |
# |    total_timesteps | 13190    |
# | train/             |          |
# |    actor_loss      | -194     |
# |    critic_loss     | 15.1     |
# |    ent_coef        | 0.0418   |
# |    ent_coef_loss   | -1.21    |
# |    learning_rate   | 0.000671 |
# |    n_updates       | 12168    |
# ---------------------------------
# ---------------------------------
# ...
# |    fps             | 38       |
# |    time_elapsed    | 856      |
# |    total_timesteps | 32999    |
# | train/             |          |
# |    actor_loss      | -135     |
# |    critic_loss     | 12.5     |
# |    ent_coef        | 0.0326   |
# |    ent_coef_loss   | 1.65     |
# |    learning_rate   | 0.000177 |
# |    n_updates       | 31949    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.8     |
# |    ep_rew_mean     | 266      |
# | time/              |          |
# |    episodes        | 704      |
# |    fps             | 38       |
# |    time_elapsed    | 864      |
# |    total_timesteps | 33313    |
# | train/             |          |
# |    actor_loss      | -132     |
# |    critic_loss     | 9.41     |
# |    ent_coef        | 0.0321   |
# |    ent_coef_loss   | -0.935   |
# |    learning_rate   | 0.000169 |
# |    n_updates       | 32256    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.5     |
# |    ep_rew_mean     | 270      |
# | time/              |          |
# |    episodes        | 708      |
# |    fps             | 38       |
# |    time_elapsed    | 874      |
# |    total_timesteps | 33684    |
# | train/             |          |
# |    actor_loss      | -132     |
# |    critic_loss     | 8.65     |
# |    ent_coef        | 0.0318   |
# |    ent_coef_loss   | 0.33     |
# |    learning_rate   | 0.000161 |
# |    n_updates       | 32605    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 67       |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 712      |
# |    fps             | 38       |
# |    time_elapsed    | 882      |
# |    total_timesteps | 33951    |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 8.97     |
# |    ent_coef        | 0.0318   |
# |    ent_coef_loss   | 0.942    |
# |    learning_rate   | 0.000153 |
# |    n_updates       | 32904    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.9     |
# |    ep_rew_mean     | 274      |
# | time/              |          |
# |    episodes        | 716      |
# |    fps             | 38       |
# |    time_elapsed    | 889      |
# |    total_timesteps | 34180    |
# | train/             |          |
# |    actor_loss      | -132     |
# |    critic_loss     | 9.93     |
# |    ent_coef        | 0.032    |
# |    ent_coef_loss   | 0.712    |
# |    learning_rate   | 0.000147 |
# |    n_updates       | 33163    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.6     |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    episodes        | 720      |
# |    fps             | 38       |
# |    time_elapsed    | 893      |
# |    total_timesteps | 34361    |
# | train/             |          |
# |    actor_loss      | -133     |
# |    critic_loss     | 9.31     |
# |    ent_coef        | 0.032    |
# |    ent_coef_loss   | -0.968   |
# |    learning_rate   | 0.000142 |
# |    n_updates       | 33341    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66       |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 724      |
# |    fps             | 38       |
# |    time_elapsed    | 898      |
# |    total_timesteps | 34548    |
# | train/             |          |
# |    actor_loss      | -132     |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.0316   |
# |    ent_coef_loss   | -5.08    |
# |    learning_rate   | 0.000138 |
# |    n_updates       | 33522    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.8     |
# |    ep_rew_mean     | 265      |
# | time/              |          |
# |    episodes        | 728      |
# |    fps             | 38       |
# |    time_elapsed    | 904      |
# |    total_timesteps | 34759    |
# | train/             |          |
# |    actor_loss      | -130     |
# |    critic_loss     | 9.35     |
# |    ent_coef        | 0.0313   |
# |    ent_coef_loss   | -0.829   |
# |    learning_rate   | 0.000132 |
# |    n_updates       | 33731    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63.1     |
# |    ep_rew_mean     | 270      |
# | time/              |          |
# |    episodes        | 732      |
# |    fps             | 38       |
# |    time_elapsed    | 910      |
# |    total_timesteps | 34966    |
# | train/             |          |
# |    actor_loss      | -132     |
# |    critic_loss     | 9.38     |
# |    ent_coef        | 0.031    |
# |    ent_coef_loss   | -1.89    |
# |    learning_rate   | 0.000127 |
# |    n_updates       | 33939    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 62.3     |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 736      |
# |    fps             | 38       |
# |    time_elapsed    | 916      |
# |    total_timesteps | 35200    |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 10.7     |
# |    ent_coef        | 0.031    |
# |    ent_coef_loss   | 4.71     |
# |    learning_rate   | 0.000122 |
# |    n_updates       | 34156    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61.8     |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    episodes        | 740      |
# |    fps             | 38       |
# |    time_elapsed    | 922      |
# |    total_timesteps | 35407    |
# | train/             |          |
# |    actor_loss      | -132     |
# |    critic_loss     | 11.3     |
# |    ent_coef        | 0.0313   |
# |    ent_coef_loss   | -2.64    |
# |    learning_rate   | 0.000116 |
# |    n_updates       | 34388    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60.5     |
# |    ep_rew_mean     | 283      |
# | time/              |          |
# |    episodes        | 744      |
# |    fps             | 38       |
# |    time_elapsed    | 927      |
# |    total_timesteps | 35583    |
# | train/             |          |
# |    actor_loss      | -130     |
# |    critic_loss     | 14.9     |
# |    ent_coef        | 0.0312   |
# |    ent_coef_loss   | -1.08    |
# |    learning_rate   | 0.000111 |
# |    n_updates       | 34568    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.4     |
# |    ep_rew_mean     | 288      |
# | time/              |          |
# |    episodes        | 748      |
# |    fps             | 38       |
# |    time_elapsed    | 933      |
# |    total_timesteps | 35816    |
# | train/             |          |
# |    actor_loss      | -130     |
# |    critic_loss     | 16.3     |
# |    ent_coef        | 0.0312   |
# |    ent_coef_loss   | -0.5     |
# |    learning_rate   | 0.000106 |
# |    n_updates       | 34771    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59       |
# |    ep_rew_mean     | 290      |
# | time/              |          |
# |    episodes        | 752      |
# |    fps             | 38       |
# |    time_elapsed    | 940      |
# |    total_timesteps | 36094    |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 15.2     |
# |    ent_coef        | 0.0314   |
# |    ent_coef_loss   | 3.21     |
# |    learning_rate   | 9.94e-05 |
# |    n_updates       | 35049    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60.2     |
# |    ep_rew_mean     | 300      |
# | time/              |          |
# |    episodes        | 756      |
# |    fps             | 38       |
# |    time_elapsed    | 949      |
# |    total_timesteps | 36425    |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.0317   |
# |    ent_coef_loss   | 1.62     |
# |    learning_rate   | 9.12e-05 |
# |    n_updates       | 35378    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60.5     |
# |    ep_rew_mean     | 303      |
# | time/              |          |
# |    episodes        | 760      |
# |    fps             | 38       |
# |    time_elapsed    | 957      |
# |    total_timesteps | 36706    |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 11.1     |
# |    ent_coef        | 0.0318   |
# |    ent_coef_loss   | -2.85    |
# |    learning_rate   | 8.37e-05 |
# |    n_updates       | 35677    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60.6     |
# |    ep_rew_mean     | 305      |
# | time/              |          |
# |    episodes        | 764      |
# |    fps             | 38       |
# |    time_elapsed    | 965      |
# |    total_timesteps | 36984    |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 0.0316   |
# |    ent_coef_loss   | 0.264    |
# |    learning_rate   | 7.69e-05 |
# |    n_updates       | 35951    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61.4     |
# |    ep_rew_mean     | 307      |
# | time/              |          |
# |    episodes        | 768      |
# |    fps             | 38       |
# |    time_elapsed    | 972      |
# |    total_timesteps | 37244    |
# | train/             |          |
# |    actor_loss      | -127     |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.0316   |
# |    ent_coef_loss   | -0.223   |
# |    learning_rate   | 7.07e-05 |
# |    n_updates       | 36196    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 62.9     |
# |    ep_rew_mean     | 307      |
# | time/              |          |
# |    episodes        | 772      |
# |    fps             | 38       |
# |    time_elapsed    | 981      |
# |    total_timesteps | 37579    |
# | train/             |          |
# |    actor_loss      | -128     |
# |    critic_loss     | 12.4     |
# |    ent_coef        | 0.0316   |
# |    ent_coef_loss   | 0.52     |
# |    learning_rate   | 6.27e-05 |
# |    n_updates       | 36518    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.5     |
# |    ep_rew_mean     | 309      |
# | time/              |          |
# |    episodes        | 776      |
# |    fps             | 38       |
# |    time_elapsed    | 990      |
# |    total_timesteps | 37922    |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.0317   |
# |    ent_coef_loss   | -0.41    |
# |    learning_rate   | 5.38e-05 |
# |    n_updates       | 36874    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66       |
# |    ep_rew_mean     | 312      |
# | time/              |          |
# |    episodes        | 780      |
# |    fps             | 38       |
# |    time_elapsed    | 1000     |
# |    total_timesteps | 38279    |
# | train/             |          |
# |    actor_loss      | -127     |
# |    critic_loss     | 14.1     |
# |    ent_coef        | 0.0316   |
# |    ent_coef_loss   | -1.64    |
# |    learning_rate   | 4.55e-05 |
# |    n_updates       | 37207    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.5     |
# |    ep_rew_mean     | 316      |
# | time/              |          |
# |    episodes        | 784      |
# |    fps             | 38       |
# |    time_elapsed    | 1010     |
# |    total_timesteps | 38583    |
# | train/             |          |
# |    actor_loss      | -126     |
# |    critic_loss     | 12.9     |
# |    ent_coef        | 0.0315   |
# |    ent_coef_loss   | -2.1     |
# |    learning_rate   | 3.72e-05 |
# |    n_updates       | 37539    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.1     |
# |    ep_rew_mean     | 315      |
# | time/              |          |
# |    episodes        | 788      |
# |    fps             | 38       |
# |    time_elapsed    | 1017     |
# |    total_timesteps | 38806    |
# | train/             |          |
# |    actor_loss      | -126     |
# |    critic_loss     | 12.9     |
# |    ent_coef        | 0.0314   |
# |    ent_coef_loss   | -5.48    |
# |    learning_rate   | 3.12e-05 |
# |    n_updates       | 37779    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.1     |
# |    ep_rew_mean     | 314      |
# | time/              |          |
# |    episodes        | 792      |
# |    fps             | 38       |
# |    time_elapsed    | 1024     |
# |    total_timesteps | 39005    |
# | train/             |          |
# |    actor_loss      | -125     |
# |    critic_loss     | 12       |
# |    ent_coef        | 0.0312   |
# |    ent_coef_loss   | -5.61    |
# |    learning_rate   | 2.61e-05 |
# |    n_updates       | 37982    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.7     |
# |    ep_rew_mean     | 316      |
# | time/              |          |
# |    episodes        | 796      |
# |    fps             | 38       |
# |    time_elapsed    | 1030     |
# |    total_timesteps | 39199    |
# | train/             |          |
# |    actor_loss      | -125     |
# |    critic_loss     | 13.3     |
# |    ent_coef        | 0.0311   |
# |    ent_coef_loss   | -4.22    |
# |    learning_rate   | 2.12e-05 |
# |    n_updates       | 38176    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64       |
# |    ep_rew_mean     | 318      |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 38       |
# |    time_elapsed    | 1035     |
# |    total_timesteps | 39397    |
# | train/             |          |
# |    actor_loss      | -124     |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.0311   |
# |    ent_coef_loss   | -0.367   |
# |    learning_rate   | 1.63e-05 |
# |    n_updates       | 38372    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63.1     |
# |    ep_rew_mean     | 317      |
# | time/              |          |
# |    episodes        | 804      |
# |    fps             | 38       |
# |    time_elapsed    | 1041     |
# |    total_timesteps | 39626    |
# | train/             |          |
# |    actor_loss      | -127     |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0311   |
# |    ent_coef_loss   | 3.55     |
# |    learning_rate   | 1.09e-05 |
# |    n_updates       | 38589    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61.9     |
# |    ep_rew_mean     | 310      |
# | time/              |          |
# |    episodes        | 808      |
# |    fps             | 38       |
# |    time_elapsed    | 1048     |
# |    total_timesteps | 39874    |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 14.8     |
# |    ent_coef        | 0.0311   |
# |    ent_coef_loss   | 1.8      |
# |    learning_rate   | 4.87e-06 |
# |    n_updates       | 38831    |
# ---------------------------------

# %% [markdown]
# # Step 2.4: Plot results

# %% [markdown]
# We use linear representations (i.e., PCA, ICA, normalization) to approximate SAR. These representations are based directly on the motor neuroscience literature of representing muscle synergies (c.f., [Tresch et al, 2006](https://journals.physiology.org/doi/epdf/10.1152/jn.00222.2005)). Such representations also have the advantages of being highly interpretable and efficient for use as control signals. We also found in practice that nonlinear representations (such as VAE decoder networks) did not lead to strong performance are were far less efficient for training.
#
# Before computing SAR, we first seek to understand how informative each individual muscle synergy is for explaining the initial muscle activation dataset. `find_synergies` returns a dictionary (and optionally, a plot) that shows variance accounted for (VAF) by N synergies from the original muscle activation data. In general, we find that using a number of synergies where VAF > 80% leads to good performance, though this value should be treated as a hyperparameter.

# %% [markdown]
# We use linear representations (i.e., PCA, ICA, normalization) to approximate SAR. These representations are based directly on the motor neuroscience literature of representing muscle synergies (c.f., [Tresch et al, 2006](https://journals.physiology.org/doi/epdf/10.1152/jn.00222.2005)). Such representations also have the advantages of being highly interpretable and efficient for use as control signals. We also found in practice that nonlinear representations (such as VAE decoder networks) did not lead to strong performance are were far less efficient for training.
#
# Before computing SAR, we first seek to understand how informative each individual muscle synergy is for explaining the initial muscle activation dataset. `find_synergies` returns a dictionary (and optionally, a plot) that shows variance accounted for (VAF) by N synergies from the original muscle activation data. In general, we find that using a number of synergies where VAF > 80% leads to good performance, though this value should be treated as a hyperparameter.

# %% [markdown]
# For convenience, a function is defined to automatically plot the results of these runs (ensure the names and seeds are preserved).

# %%
plot_results(experiment='locomotion')
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Latin Modern Roman' not found.
# None

# %% [markdown]
# # Full training example 2: SAR x physiological manipulation

# %% [markdown]
# Now, we turn to using synergies for manipulation rather than locomotion. In this example:
# - a policy is trained on an eight-object reorientation task, `Reorient8-v0`.
# - after training, we collect muscle activation data from policy rollouts
# - variance accounted for (VAF) by N synergies is computed. Here, we select N where VAF > 0.8.
# - SAR is computed at this VAF threshold.
# - SAR is used to train on a 100-object reorientation task, `Reorient100-v0`.
#
# <strong>Note: we also provide the option of using pretrained policies/representations at some of the above steps. Run the code below depending on your preferences.</strong>

# %% [markdown]
# # Step 2.1
#
# First, we acquire our synergistic action representation. We provide two options for this:
#
# <strong>Option A: Get SAR from scratch (i.e., train on `Reorient8` as play period → get muscle activations → compute SAR).</strong>
#
# <strong>Option B: Use the precomputed SAR.</strong>

# %% [markdown]
# ## Option 2.1.A: Get SAR from scratch

# %%
# a policy is trained on an eight-object reorientation task, Reorient8-v0
train(env_name='myoHandReorient8-v0', policy_name='play_period', timesteps=1e6, seed='0')

# %%
# after training, we collect muscle activation data from policy rollouts
muscle_data = get_activations(name='play_period', env_name='myoHandReorient8-v0', seed='0', episodes=10)

# %%
# VAF by N synergies is computed. Here, N is selected where VAF > 0.8
syn_dict = find_synergies(muscle_data, plot=True)
print("VAF by N synergies:", syn_dict)

# %%
# make and load a video of the trained policy

video_name = 'play_period_vid'
get_vid(name='play_period', env_name='myoHandReorient8-v0', seed='0', episodes=10, video_name=video_name)
show_video(f"{video_name}.mp4")

# %%
# SAR is computed at this VAF threshold
ica,pca,normalizer = compute_SAR(muscle_data, 20, save=False)

# %% [markdown]
# ## Option 2.1.B: Use precomputed SAR

# %%
# RUN THIS CELL TO USE PRECOMPUTED SAR
ica,pca,normalizer = load_manipulation_SAR()

# %% [markdown]
# # Step 2.2: Train on Reorient100 with synergies (SAR-RL)

# %%
# SAR is used to train on a 100-object reorientation task, Reorient100-v0
SAR_RL(env_name='myoHandReorient100-v0', policy_name='SAR-RL', timesteps=1.5e6,
       seed='0', ica=ica, pca=pca, normalizer=normalizer, phi=.66)

# %%
# make and load a video of the trained policy

video_name = 'SAR_vid'

get_vid(name='SAR-RL', env_name='myoHandReorient100-v0', seed='0', episodes=10, video_name=video_name,
        determ=True, pca=pca, ica=ica, normalizer=normalizer, phi=.66, is_sar=True, syn_nosyn=True)
show_video(f"{video_name}.mp4")

# %% [markdown]
# # Step 2.3 (optional): Train on Reorient100 with end-to-end RL (RL-E2E)

# %% [markdown]
# We can compare the performance of (A) pretraining for 1M steps on `Reorient8-v0`, getting SAR, and training with SAR-RL on `Reorient100-v0` for 2M steps with (B) training for 3M steps using end-to-end RL ('RL-E2E').

# %%
train(env_name='myoHandReorient100-v0', policy_name='RL-E2E', timesteps=2.5e6, seed='0')

# %%
# make and load a video of the trained policy

video_name = 'RL+E2E_vid'
get_vid('RL-E2E', 'myoHandReorient100-v0', '0', determ=False, episodes=10, video_name=video_name)
show_video(f"{video_name}.mp4")

# %% [markdown]
# # Step 2.4: Plot results

# %% [markdown]
# For convenience, a function is defined to automatically plot the results of these runs (ensure the names and seeds are preserved).

# %%
plot_results(experiment='manipulation')

# %% [markdown]
# # Step 2.5 (optional): zero-shot testing manipulation policies on new unseen objects

# %% [markdown]
# We can optionally test these manipulation policies on unseen objects to determine their generalizability. Here, we implement two test
# environments.
#
# 1. ReorientID-v0—1000 unseen objects generated by sampling from the same dimensions as those for the Reorient100-v0 set. Intuitively, this environment contains new objects with the same kind of shapes as those seen in the training set.
#
# 2. ReorientOOD-v0—1000 unseen objects generated by sampling from different dimensions as those for the Reorient100-v0 set. Intuitively, this environment contains new objects with different kinds of shapes as those seen in the training set.

# %%
def zeroshot_test(name, test_env_name, env_name='myoHandReorient100-v0', seed='0', determ=True, ica=None,
                  pca=None, normalizer=None, phi=.66, episodes=500, is_sar=False, syn_nosyn=False):
    """
    Check zero-shot performance of policies on the test environments.

    name: str; name of the policy to test
    env_name: str; name of gym env the policy to test was trained on (Reorient100-v0).
    seed: str; seed of the policy to test
    test_env_name: str; name of the desired test env
    ica: if testing SAR-RL, the ICA object
    pca: if testing SAR-RL, the PCA object
    normalizer: if testing SAR-RL, the normalizer object
    phi: float; blend parameter between synergistic and nonsynergistic activations
    episodes: int; number of episodes to run on the test environment
    """
    if is_sar:
        if syn_nosyn:
            env = SynNoSynWrapper(gym.make(test_env_name), ica, pca, normalizer, phi)
        else:
            # env = SynergyWrapper(gym.make(test_env_name), ica, pca, normalizer, phi)
            env = SynergyWrapper(gym.make(test_env_name), ica, pca, normalizer)
    else:
        env = gym.make(test_env_name)
    env.reset()

    model = SAC.load(f'{name}_model_{env_name}_{seed}')
    vec = VecNormalize.load(f'{name}_env_{env_name}_{seed}', DummyVecEnv([lambda: env]))
    solved = []
    for i,_ in enumerate(range(episodes)):
        is_solved = []
        env.reset()
        done = False
        while not done:
            o = env.get_obs()
            o = vec.normalize_obs(o)
            a, __ = model.predict(o, deterministic=determ)
            next_o, r, done, *_, info = env.step(a)
            is_solved.append(info['solved'])

        if sum(is_solved) > 0:
            solved.append(1)
        else:
            solved.append(0)

    env.close()
    return np.mean(solved)

# %%
# zero-shot testing RL-E2E policy

name = 'RL-E2E'

e2e_id = zeroshot_test(name, 'myoHandReorientID-v0')

e2e_ood = zeroshot_test(name, 'myoHandReorientOOD-v0')

# %%
# zero-shot testing SAR-RL policy

name = 'SAR-RL'

sar_id = zeroshot_test(name, 'myoHandReorientID-v0', ica=ica, pca=pca,
                       normalizer=normalizer, is_sar=True, syn_nosyn=True)

sar_ood = zeroshot_test(name, 'myoHandReorientOOD-v0', ica=ica, pca=pca,
                        normalizer=normalizer, is_sar=True, syn_nosyn=True)

# %% [markdown]
# We can visualize these zero-shot generalization results by running the cell below.

# %%
# plot results

zeroshot = {"SAR-RL": [sar_id,sar_ood],
            "RL-E2E": [e2e_id,e2e_ood]}

fig, ax = plt.subplots()
plot_zeroshot(ax, zeroshot)
fig.set_size_inches(6, 5)
plt.show()
